# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Read Data file

# %%
GJ_2005 = pd.read_csv('NHIS_OPEN_GJ_2005.CSV')
GJ_2005.head()
# Out:
#    year  identity  sex  age  city  height  weight  visual_left  visual_right  \
# 0  2005    788778    2    1    29     145      40          1.0           1.2
# 1  2005    941394    2    1    41     145      40          0.9           0.9
# 2  2005    734603    2    1    27     145      40          1.0           1.0
# 3  2005    174820    2    1    47     145      40          1.2           0.8
# 4  2005    512802    2    1    41     145      40          0.5           0.8
#
#    auditory_left    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 0            1.0    ...       13    1.0      0.0            1            0.0
# 1            1.0    ...        8    1.0      0.0            1            0.0
# 2            1.0    ...       13    1.0      0.0            0            NaN
# 3            1.0    ...       33    1.0      1.0            1            0.0
# 4            1.0    ...       14    1.0      1.0            0            NaN
#
#    missing_tooth  tooth_abrasion  third_molar  scale  data_year
# 0            0.0             0.0          NaN    1.0   20151220
# 1            0.0             0.0          NaN    0.0   20151220
# 2            NaN             NaN          NaN    NaN   20151220
# 3            0.0             0.0          NaN    0.0   20151220
# 4            NaN             NaN          NaN    NaN   20151220
#
# [5 rows x 29 columns]

# %%
GJ_2006 = pd.read_csv('NHIS_OPEN_GJ_2006.CSV')
GJ_2006.head()
# Out:
#    year  identity  sex  age  city  height  weight  visual_left  visual_right  \
# 0  2006    560035    2    1    44     145      35          1.2           1.2
# 1  2006    723131    2    1    26     145      40          0.9           1.0
# 2  2006    566158    2    1    44     145      40          0.6           0.7
# 3  2006    959915    2    1    11     145      40          1.5           1.1
# 4  2006    871075    2    1    43     145      45          1.2           1.5
#
#    auditory_left    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 0            1.0    ...        9    1.0      0.0            1            0.0
# 1            1.0    ...       11    1.0      0.0            1            1.0
# 2            1.0    ...       14    1.0      1.0            1            1.0
# 3            1.0    ...       14    1.0      1.0            1            1.0
# 4            1.0    ...       11    1.0      0.0            1            0.0
#
#    missing_tooth  tooth_abrasion  third_molar  scale  data_year
# 0            0.0             0.0          NaN    0.0   20151220
# 1            0.0             0.0          NaN    1.0   20151220
# 2            0.0             0.0          NaN    0.0   20151220
# 3            0.0             0.0          NaN    1.0   20151220
# 4            0.0             0.0          NaN    1.0   20151220
#
# [5 rows x 29 columns]

# %%
GJ_2007 = pd.read_csv('NHIS_OPEN_GJ_2007.CSV')
GJ_2007.head()
# Out:
#    year  identity  sex  age  city  height  weight  visual_left  visual_right  \
# 0  2007    852370    2    1    46     140      35          1.5           1.2
# 1  2007    125400    2    1    47     140      35          0.9           0.8
# 2  2007    849638    2    1    30     140      35          1.0           0.8
# 3  2007    999657    2    1    27     145      40          0.3           0.3
# 4  2007    599690    2    1    26     145      40          1.5           1.5
#
#    auditory_left    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 0            1.0    ...       13    1.0      0.0            1            NaN
# 1            1.0    ...       12    1.0      0.0            1            NaN
# 2            1.0    ...       31    1.0      0.0            0            NaN
# 3            1.0    ...       13    1.0      0.0            1            NaN
# 4            1.0    ...       10    1.0      0.0            1            NaN
#
#    missing_tooth  tooth_abrasion  third_molar  scale  data_year
# 0            0.0             0.0          NaN    0.0   20151220
# 1            0.0             0.0          NaN    0.0   20151220
# 2            NaN             NaN          NaN    NaN   20151220
# 3            1.0             0.0          0.0    0.0   20151220
# 4            0.0             0.0          0.0    0.0   20151220
#
# [5 rows x 29 columns]

# %%
GJ_2008 = pd.read_csv('NHIS_OPEN_GJ_2008.CSV')
GJ_2008.head()
# Out:
#    year  identity  sex  age  city  height  weight  waist  visual_left  \
# 0  2008    725676    2    1    48     145      40     58          1.2
# 1  2008    595922    2    1    41     145      40     60          1.2
# 2  2008    209869    2    1    48     145      45     70          0.5
# 3  2008      3099    2    1    41     145      50     71          0.9
# 4  2008    756067    2    1    47     145      50     73          0.7
#
#    visual_right    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 0           1.2    ...       16    1.0      1.0            0            NaN
# 1           1.2    ...       16    1.0      1.0            1            0.0
# 2           0.5    ...       14    1.0      0.0            1            0.0
# 3           0.9    ...       17    1.0      0.0            1            0.0
# 4           0.9    ...       23    1.0      0.0            0            NaN
#
#    missing_tooth  tooth_abrasion  third_molar  scale  data_year
# 0            NaN             NaN          NaN    NaN   20151220
# 1            0.0             0.0          NaN    0.0   20151220
# 2            1.0             0.0          NaN    1.0   20151220
# 3            0.0             0.0          0.0    0.0   20151220
# 4            NaN             NaN          NaN    NaN   20151220
#
# [5 rows x 30 columns]

# %% [markdown]
# # EDA with 건강검진 file

# %% [markdown]
# ## (A) blood press

# %% [markdown]
# ### (1) blood press by sex

# %%
#2005
bp_2005=GJ_2005[['sex','b_press_contract','b_press_relax']]
bp_mean_2005=bp_2005.groupby('sex').mean()
bp_mean_2005
# Out:
#      b_press_contract  b_press_relax
# sex
# 1          125.258418      78.718199
# 2          120.532957      75.005303

# %%
bp_mean_2005.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['sex','b_press_contract','b_press_relax']]
bp_mean_2006=bp_2006.groupby('sex').mean()
bp_mean_2006
# Out:
#      b_press_contract  b_press_relax
# sex
# 1          125.021192      78.578834
# 2          119.931715      74.587956

# %%
bp_mean_2006.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['sex','b_press_contract','b_press_relax']]
bp_mean_2007=bp_2007.groupby('sex').mean()
bp_mean_2007
# Out:
#      b_press_contract  b_press_relax
# sex
# 1          124.871034      78.308616
# 2          120.244531      74.611148

# %%
bp_mean_2007.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['sex','b_press_contract','b_press_relax']]
bp_mean_2008=bp_2008.groupby('sex').mean()
bp_mean_2008
# Out:
#      b_press_contract  b_press_relax
# sex
# 1          124.697222      78.121587
# 2          119.490977      74.109107

# %%
bp_mean_2008.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %% [markdown]
# ### (2) blood press by height

# %%
#2005
bp_2005=GJ_2005[['height','b_press_contract']]
bp_2005 = bp_2005[(bp_2005['height'] > 140) & (bp_2005['height'] < 185)]
boxplotgraph=bp_2005.boxplot(by='height',figsize=((20,10)))
boxplotgraph.set_ylim(60, 250)
# Out:
# (60, 250)

# %%
#2005
bp_2005=GJ_2005[['height','b_press_relax']]
bp_2005 = bp_2005[(bp_2005['height'] > 140) & (bp_2005['height'] < 185)]
boxplotgraph=bp_2005.boxplot(by='height',figsize=((20,10)))

# %%
#2005
bp_2005=GJ_2005[['height','b_press_contract','b_press_relax']]
bp_mean_2005=bp_2005.groupby('height').mean()
bp_mean_2005=bp_mean_2005.iloc[5:13]
bp_mean_2005
# Out:
#         b_press_contract  b_press_relax
# height
# 145           127.448921      77.976747
# 150           123.589709      76.489920
# 155           121.095604      75.486902
# 160           121.916432      76.330329
# 165           123.847416      77.875899
# 170           124.027583      78.241661
# 175           123.810640      78.065620
# 180           123.804844      77.951873

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='height',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['height','b_press_contract','b_press_relax']]
bp_mean_2006=bp_2006.groupby('height').mean()
bp_mean_2006=bp_mean_2006.iloc[4:12]
bp_mean_2006
# Out:
#         b_press_contract  b_press_relax
# height
# 145           127.623721      77.985815
# 150           123.310188      76.278439
# 155           120.319230      74.969826
# 160           121.051221      75.778410
# 165           123.467900      77.624975
# 170           123.866260      78.128722
# 175           123.597706      77.936542
# 180           123.447428      77.657477

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='height',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['height','b_press_contract','b_press_relax']]
bp_mean_2007=bp_2007.groupby('height').mean()
bp_mean_2007=bp_mean_2007.iloc[5:13]
bp_mean_2007
# Out:
#         b_press_contract  b_press_relax
# height
# 145           127.366303      77.688400
# 150           123.343101      76.103187
# 155           120.652857      75.012917
# 160           121.275095      75.722809
# 165           123.345635      77.363787
# 170           123.708878      77.866782
# 175           123.461330      77.760875
# 180           123.456029      77.520640

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='height',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['height','b_press_contract','b_press_relax']]
bp_mean_2008=bp_2008.groupby('height').mean()
bp_mean_2008=bp_mean_2008.iloc[4:12]
bp_mean_2008
# Out:
#         b_press_contract  b_press_relax
# height
# 145           126.701162      77.289879
# 150           122.739910      75.688390
# 155           120.011617      74.550590
# 160           120.478139      75.161952
# 165           122.894330      77.010691
# 170           123.613076      77.709903
# 175           123.452553      77.610665
# 180           123.465536      77.417911

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='height',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (3) blood press by weight

# %%
#2005
bp_2005=GJ_2005[['weight','b_press_contract','b_press_relax']]
bp_mean_2005=bp_2005.groupby('weight').mean()
bp_mean_2005=bp_mean_2005.iloc[3:13]
bp_mean_2005
# Out:
#         b_press_contract  b_press_relax
# weight
# 45            117.063345      72.924359
# 50            118.853183      74.087202
# 55            121.478458      75.679999
# 60            123.615396      77.199376
# 65            124.955970      78.255067
# 70            125.988669      79.240077
# 75            126.995735      80.041715
# 80            127.973031      80.861872
# 85            128.988251      81.747567
# 90            130.315590      82.677859

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='weight',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['weight','b_press_contract','b_press_relax']]
bp_mean_2006=bp_2006.groupby('weight').mean()
bp_mean_2006=bp_mean_2006.iloc[3:13]
bp_mean_2006
# Out:
#         b_press_contract  b_press_relax
# weight
# 45            116.348818      72.471441
# 50            118.312107      73.720728
# 55            121.001828      75.340332
# 60            123.168308      76.862796
# 65            124.533870      78.016292
# 70            125.589495      78.948177
# 75            126.560263      79.801114
# 80            127.614873      80.542421
# 85            128.605464      81.402206
# 90            129.665080      82.078582

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='weight',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['weight','b_press_contract','b_press_relax']]
bp_mean_2007=bp_2007.groupby('weight').mean()
bp_mean_2007=bp_mean_2007.iloc[4:14]
bp_mean_2007
# Out:
#         b_press_contract  b_press_relax
# weight
# 45            116.875448      72.645951
# 50            118.622605      73.731909
# 55            121.101414      75.257208
# 60            123.123376      76.658063
# 65            124.436986      77.731565
# 70            125.383224      78.629733
# 75            126.245360      79.423687
# 80            127.347837      80.243343
# 85            128.352116      80.991030
# 90            129.759016      82.034872

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='weight',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['weight','b_press_contract','b_press_relax']]
bp_mean_2008=bp_2008.groupby('weight').mean()
bp_mean_2008=bp_mean_2008.iloc[3:13]
bp_mean_2008
# Out:
#         b_press_contract  b_press_relax
# weight
# 45            115.767176      72.033482
# 50            117.852267      73.187346
# 55            120.477100      74.776235
# 60            122.703886      76.310527
# 65            124.146186      77.500236
# 70            125.106079      78.340951
# 75            126.087107      79.218286
# 80            127.303728      80.106850
# 85            128.219641      80.786108
# 90            129.457642      81.651366

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='weight',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (4) blood press by age

# %%
#2005
bp_2005=GJ_2005[['age','b_press_contract','b_press_relax']]
bp_mean_2005=bp_2005.groupby('age').mean()
bp_mean_2005=bp_mean_2005.iloc[:12]
bp_mean_2005
# Out:
#      b_press_contract  b_press_relax
# age
# 1          113.999228      71.476243
# 2          117.295178      73.562737
# 3          120.190752      75.712335
# 4          121.327134      76.813164
# 5          120.832771      76.500857
# 6          122.906525      77.798350
# 7          125.116622      78.801853
# 8          127.868342      79.846881
# 9          130.103938      80.007922
# 10         131.797760      79.938399
# 11         133.176635      79.685644
# 12         134.510445      79.797738

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='age',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['age','b_press_contract','b_press_relax']]
bp_mean_2006=bp_2006.groupby('age').mean()
bp_mean_2006=bp_mean_2006.iloc[:12]
bp_mean_2006
# Out:
#      b_press_contract  b_press_relax
# age
# 1          114.362511      71.630625
# 2          116.816795      73.250588
# 3          119.356518      75.103176
# 4          120.308201      76.076831
# 5          120.331232      76.114625
# 6          122.420324      77.469423
# 7          124.648646      78.531134
# 8          127.287023      79.504654
# 9          129.779221      79.770108
# 10         131.796186      79.976023
# 11         133.372032      79.907869
# 12         134.154505      79.605409

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='age',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['age','b_press_contract','b_press_relax']]
bp_mean_2007=bp_2007.groupby('age').mean()
bp_mean_2007=bp_mean_2007.iloc[:12]
bp_mean_2007
# Out:
#      b_press_contract  b_press_relax
# age
# 1          114.125607      71.412841
# 2          117.038534      73.354489
# 3          119.757742      75.291696
# 4          120.849544      76.351034
# 5          120.165053      75.843384
# 6          122.177507      77.144687
# 7          124.012412      77.933759
# 8          126.624631      78.972548
# 9          128.754312      79.177637
# 10         130.823807      79.302847
# 11         132.363292      79.390680
# 12         133.430273      79.285872

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='age',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['age','b_press_contract','b_press_relax']]
bp_mean_2008=bp_2008.groupby('age').mean()
bp_mean_2008=bp_mean_2008.iloc[:12]
bp_mean_2008
# Out:
#      b_press_contract  b_press_relax
# age
# 1          113.907533      71.135169
# 2          116.657377      72.910070
# 3          118.985328      74.667722
# 4          120.069303      75.693571
# 5          119.974896      75.659788
# 6          121.805633      76.856487
# 7          123.711932      77.780658
# 8          125.956681      78.474378
# 9          128.249009      78.749397
# 10         130.623631      79.039557
# 11         131.845875      78.851788
# 12         132.830297      78.823533

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='age',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (5) blood press by city

# %%
#2005
bp_2005=GJ_2005[['city','b_press_contract','b_press_relax']]
bp_mean_2005=bp_2005.groupby('city').mean()
bp_mean_2005
# Out:
#       b_press_contract  b_press_relax
# city
# 11          121.951047      76.658187
# 26          122.941784      77.147711
# 27          123.338735      76.641055
# 28          123.968574      76.950237
# 29          121.545250      76.559426
# 30          123.969945      77.749477
# 31          124.320856      77.412854
# 41          122.760021      76.923350
# 42          124.190321      77.987893
# 43          124.695698      78.459559
# 44          124.859120      78.416525
# 45          124.366139      77.905477
# 46          125.099316      77.686206
# 47          123.965453      76.905536
# 48          123.995124      77.641718
# 49          123.625248      77.765197

# %%
bp_mean_2005.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['city','b_press_contract','b_press_relax']]
bp_mean_2006=bp_2006.groupby('city').mean()
bp_mean_2006
# Out:
#       b_press_contract  b_press_relax
# city
# 11          121.830523      76.325258
# 26          122.718701      76.731129
# 27          122.940973      76.368997
# 28          123.649213      76.867541
# 29          121.590215      76.595306
# 30          123.528674      77.906692
# 31          124.301673      77.352072
# 41          122.530380      76.663209
# 42          123.348084      77.156989
# 43          123.678474      77.703363
# 44          123.997592      78.138812
# 45          123.593826      77.870627
# 46          124.076850      77.336102
# 47          123.444253      76.900679
# 48          122.882984      77.041646
# 49          122.854897      76.961759

# %%
bp_mean_2006.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['city','b_press_contract','b_press_relax']]
bp_mean_2007=bp_2007.groupby('city').mean()
bp_mean_2007
# Out:
#       b_press_contract  b_press_relax
# city
# 11          122.175356      76.265197
# 26          122.704824      76.498252
# 27          122.832983      76.152559
# 28          123.624137      76.842308
# 29          121.291668      76.347833
# 30          123.169434      77.437187
# 31          124.321777      77.569074
# 41          122.670143      76.714072
# 42          123.316057      77.038823
# 43          123.097847      77.165934
# 44          123.193560      77.264577
# 45          123.725650      77.422324
# 46          123.361218      76.855440
# 47          123.912667      76.897959
# 48          123.135544      76.902285
# 49          123.867503      77.182195

# %%
bp_mean_2007.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['city','b_press_contract','b_press_relax']]
bp_mean_2008=bp_2008.groupby('city').mean()
bp_mean_2008
# Out:
#       b_press_contract  b_press_relax
# city
# 11          121.892985      75.957950
# 26          122.093032      75.929608
# 27          122.467045      76.039411
# 28          123.004440      76.833327
# 29          120.954377      75.966089
# 30          122.107369      76.807768
# 31          123.868724      76.711086
# 41          122.329725      76.367744
# 42          123.479808      77.094943
# 43          122.366192      76.837631
# 44          122.514565      77.069520
# 45          122.775299      76.576708
# 46          122.644844      76.557701
# 47          123.198726      76.407408
# 48          122.498162      76.293907
# 49          123.132330      76.811000

# %%
bp_mean_2008.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %% [markdown]
# ### (6) blood press by smoke

# %%
#2005
bp_2005=GJ_2005[['smoke','b_press_contract','b_press_relax']]
bp_mean_2005=bp_2005.groupby('smoke').mean()
bp_mean_2005
# Out:
#        b_press_contract  b_press_relax
# smoke
# 1.0          122.620132      76.559951
# 2.0          125.452873      78.814195
# 3.0          124.197389      78.116526

# %%
bp_mean_2005.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['smoke','b_press_contract','b_press_relax']]
bp_mean_2006=bp_2006.groupby('smoke').mean()
bp_mean_2006
# Out:
#        b_press_contract  b_press_relax
# smoke
# 1.0          122.076156      76.186855
# 2.0          125.307991      78.756013
# 3.0          124.078786      78.043258

# %%
bp_mean_2006.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['smoke','b_press_contract','b_press_relax']]
bp_mean_2007=bp_2007.groupby('smoke').mean()
bp_mean_2007
# Out:
#        b_press_contract  b_press_relax
# smoke
# 1.0          122.219255      76.097709
# 2.0          125.047069      78.430082
# 3.0          123.803866      77.790110

# %%
bp_mean_2007.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['smoke','b_press_contract','b_press_relax']]
bp_mean_2008=bp_2008.groupby('smoke').mean()
bp_mean_2008
# Out:
#        b_press_contract  b_press_relax
# smoke
# 1.0          121.516717      75.599103
# 2.0          124.852973      78.327579
# 3.0          123.617661      77.571370

# %%
bp_mean_2008.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %% [markdown]
# ### (7) blood press by alcohol

# %%
#2005
bp_2005=GJ_2005[['alcohol','b_press_contract','b_press_relax']]
bp_mean_2005=bp_2005.groupby('alcohol').mean()
bp_mean_2005
# Out:
#          b_press_contract  b_press_relax
# alcohol
# 0.0            122.824620      76.476561
# 1.0            123.805643      77.917220

# %%
bp_mean_2005.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['alcohol','b_press_contract','b_press_relax']]
bp_mean_2006=bp_2006.groupby('alcohol').mean()
bp_mean_2006
# Out:
#          b_press_contract  b_press_relax
# alcohol
# 0.0            122.338294      76.141827
# 1.0            123.454962      77.699386

# %%
bp_mean_2006.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['alcohol','b_press_contract','b_press_relax']]
bp_mean_2007=bp_2007.groupby('alcohol').mean()
bp_mean_2007
# Out:
#          b_press_contract  b_press_relax
# alcohol
# 0.0            122.500666      76.060187
# 1.0            123.323108      77.480974

# %%
bp_mean_2007.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['alcohol','b_press_contract','b_press_relax']]
bp_mean_2008=bp_2008.groupby('alcohol').mean()
bp_mean_2008
# Out:
#          b_press_contract  b_press_relax
# alcohol
# 0.0            121.763398      75.537851
# 1.0            122.929478      77.144884

# %%
bp_mean_2008.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %% [markdown]
# ## (B) visual

# %% [markdown]
# ### (1) visual by sex

# %%
#2005
bp_2005=GJ_2005[['sex','visual_left','visual_right']]
bp_mean_2005=bp_2005.groupby('sex').mean()
bp_mean_2005
# Out:
#      visual_left  visual_right
# sex
# 1       1.041568      1.040461
# 2       0.880914      0.880999

# %%
bp_mean_2005.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['sex','visual_left','visual_right']]
bp_mean_2006=bp_2006.groupby('sex').mean()
bp_mean_2006
# Out:
#      visual_left  visual_right
# sex
# 1       1.045352      1.043411
# 2       0.895816      0.894326

# %%
bp_mean_2006.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['sex','visual_left','visual_right']]
bp_mean_2007=bp_2007.groupby('sex').mean()
bp_mean_2007
# Out:
#      visual_left  visual_right
# sex
# 1       1.035532      1.034253
# 2       0.875928      0.874299

# %%
bp_mean_2007.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['sex','visual_left','visual_right']]
bp_mean_2008=bp_2008.groupby('sex').mean()
bp_mean_2008
# Out:
#      visual_left  visual_right
# sex
# 1       1.045320      1.043672
# 2       0.900693      0.898442

# %%
bp_mean_2008.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %% [markdown]
# ### (2) visual by age

# %%
#2005
bp_2005=GJ_2005[['age','visual_left','visual_right']]
bp_mean_2005=bp_2005.groupby('age').mean()
bp_mean_2005=bp_mean_2005.iloc[:12]
bp_mean_2005
# Out:
#      visual_left  visual_right
# age
# 1       0.984803      0.980501
# 2       1.047286      1.043813
# 3       1.101272      1.101861
# 4       1.123002      1.119084
# 5       1.071134      1.066710
# 6       1.005629      1.001462
# 7       0.933228      0.933782
# 8       0.868563      0.872240
# 9       0.782402      0.790641
# 10      0.715991      0.719541
# 11      0.665723      0.673758
# 12      0.624055      0.628993

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='age',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['age','visual_left','visual_right']]
bp_mean_2006=bp_2006.groupby('age').mean()
bp_mean_2006=bp_mean_2006.iloc[:12]
bp_mean_2006
# Out:
#      visual_left  visual_right
# age
# 1       1.018788      1.013326
# 2       1.054089      1.051074
# 3       1.104257      1.102854
# 4       1.123254      1.118762
# 5       1.075802      1.073170
# 6       1.009562      1.007043
# 7       0.946410      0.944874
# 8       0.879187      0.880453
# 9       0.793894      0.796446
# 10      0.719097      0.721527
# 11      0.674249      0.669005
# 12      0.632312      0.632982

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='age',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['age','visual_left','visual_right']]
bp_mean_2007=bp_2007.groupby('age').mean()
bp_mean_2007=bp_mean_2007.iloc[:12]
bp_mean_2007
# Out:
#      visual_left  visual_right
# age
# 1       1.014044      1.013463
# 2       1.051341      1.046748
# 3       1.103191      1.100479
# 4       1.123473      1.120955
# 5       1.070545      1.066532
# 6       1.004289      1.001637
# 7       0.937539      0.938226
# 8       0.876576      0.875144
# 9       0.808237      0.811967
# 10      0.722708      0.730833
# 11      0.687456      0.679963
# 12      0.649326      0.645443

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='age',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['age','visual_left','visual_right']]
bp_mean_2008=bp_2008.groupby('age').mean()
bp_mean_2008=bp_mean_2008.iloc[:12]
bp_mean_2008
# Out:
#      visual_left  visual_right
# age
# 1       1.023385      1.019334
# 2       1.055547      1.051506
# 3       1.105228      1.102831
# 4       1.128598      1.122477
# 5       1.081781      1.077744
# 6       1.008292      1.005014
# 7       0.946964      0.947465
# 8       0.887090      0.889439
# 9       0.815847      0.814675
# 10      0.739131      0.748305
# 11      0.691679      0.688128
# 12      0.666262      0.676215

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='age',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (3) visual by height

# %%
#2005
bp_2005=GJ_2005[['height','visual_left','visual_right']]
bp_mean_2005=bp_2005.groupby('height').mean()
bp_mean_2005=bp_mean_2005.iloc[5:13]
bp_mean_2005
# Out:
#         visual_left  visual_right
# height
# 145        0.747329      0.750741
# 150        0.835612      0.840078
# 155        0.906335      0.902359
# 160        0.959581      0.959672
# 165        1.020048      1.017738
# 170        1.068309      1.066854
# 175        1.097394      1.097509
# 180        1.104933      1.105400

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='height',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['height','visual_left','visual_right']]
bp_mean_2006=bp_2006.groupby('height').mean()
bp_mean_2006=bp_mean_2006.iloc[4:12]
bp_mean_2006
# Out:
#         visual_left  visual_right
# height
# 145        0.752500      0.752177
# 150        0.844705      0.846928
# 155        0.915803      0.913784
# 160        0.970541      0.967005
# 165        1.023316      1.020612
# 170        1.070505      1.068360
# 175        1.101246      1.100142
# 180        1.113537      1.114937

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='height',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['height','visual_left','visual_right']]
bp_mean_2007=bp_2007.groupby('height').mean()
bp_mean_2007=bp_mean_2007.iloc[5:13]
bp_mean_2007
# Out:
#         visual_left  visual_right
# height
# 145        0.741057      0.751278
# 150        0.831836      0.827992
# 155        0.898315      0.895580
# 160        0.951935      0.951402
# 165        1.010781      1.007868
# 170        1.062236      1.062595
# 175        1.094803      1.093594
# 180        1.110509      1.108325

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='height',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['height','visual_left','visual_right']]
bp_mean_2008=bp_2008.groupby('height').mean()
bp_mean_2008=bp_mean_2008.iloc[4:12]
bp_mean_2008
# Out:
#         visual_left  visual_right
# height
# 145        0.754479      0.760481
# 150        0.851903      0.850092
# 155        0.917659      0.916866
# 160        0.967696      0.963253
# 165        1.021452      1.019440
# 170        1.071130      1.069738
# 175        1.099032      1.095897
# 180        1.116085      1.114746

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='height',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (4) visual by weight

# %%
#2005
bp_2005=GJ_2005[['weight','visual_left','visual_right']]
bp_mean_2005=bp_2005.groupby('weight').mean()
bp_mean_2005=bp_mean_2005.iloc[3:13]
bp_mean_2005
# Out:
#         visual_left  visual_right
# weight
# 45         0.883305      0.883732
# 50         0.907945      0.907069
# 55         0.932843      0.932118
# 60         0.965431      0.965966
# 65         1.005810      1.002849
# 70         1.032573      1.034101
# 75         1.055563      1.055143
# 80         1.072071      1.069413
# 85         1.083621      1.080867
# 90         1.092946      1.083262

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='weight',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['weight','visual_left','visual_right']]
bp_mean_2006=bp_2006.groupby('weight').mean()
bp_mean_2006=bp_mean_2006.iloc[3:13]
bp_mean_2006
# Out:
#         visual_left  visual_right
# weight
# 45         0.900422      0.900257
# 50         0.921410      0.915892
# 55         0.934680      0.933709
# 60         0.971345      0.968778
# 65         1.006888      1.007778
# 70         1.034683      1.033838
# 75         1.062885      1.060398
# 80         1.074706      1.076096
# 85         1.094510      1.088533
# 90         1.102545      1.095550

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='weight',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['weight','visual_left','visual_right']]
bp_mean_2007=bp_2007.groupby('weight').mean()
bp_mean_2007=bp_mean_2007.iloc[4:14]
bp_mean_2007
# Out:
#         visual_left  visual_right
# weight
# 45         0.879288      0.878705
# 50         0.903167      0.900540
# 55         0.919228      0.919932
# 60         0.955420      0.953363
# 65         0.991916      0.991978
# 70         1.026954      1.024661
# 75         1.050726      1.049755
# 80         1.070326      1.068398
# 85         1.084462      1.080853
# 90         1.088362      1.081802

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='weight',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['weight','visual_left','visual_right']]
bp_mean_2008=bp_2008.groupby('weight').mean()
bp_mean_2008=bp_mean_2008.iloc[3:13]
bp_mean_2008
# Out:
#         visual_left  visual_right
# weight
# 45         0.909059      0.906273
# 50         0.920529      0.922474
# 55         0.937936      0.933973
# 60         0.967617      0.963464
# 65         1.001812      1.001195
# 70         1.035309      1.034937
# 75         1.056392      1.058477
# 80         1.075797      1.067291
# 85         1.089915      1.086441
# 90         1.097051      1.094067

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='weight',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (5) visual by city

# %%
#2005
bp_2005=GJ_2005[['city','visual_left','visual_right']]
bp_mean_2005=bp_2005.groupby('city').mean()
bp_mean_2005
# Out:
#       visual_left  visual_right
# city
# 11       0.962114      0.960558
# 26       0.942589      0.943614
# 27       0.962063      0.964609
# 28       1.013783      1.010044
# 29       0.983662      0.992483
# 30       0.979374      0.975663
# 31       0.989440      0.993276
# 41       1.006429      1.005054
# 42       0.954494      0.945456
# 43       0.977594      0.974461
# 44       0.981361      0.982877
# 45       0.967563      0.968493
# 46       0.917705      0.925230
# 47       0.958331      0.961695
# 48       0.978694      0.973830
# 49       1.010030      0.988012

# %%
bp_mean_2005.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['city','visual_left','visual_right']]
bp_mean_2006=bp_2006.groupby('city').mean()
bp_mean_2006
# Out:
#       visual_left  visual_right
# city
# 11       0.959171      0.955159
# 26       0.949497      0.949819
# 27       0.981787      0.976562
# 28       1.013620      1.009607
# 29       0.993023      0.989151
# 30       0.985473      0.983885
# 31       0.971908      0.970248
# 41       0.999982      0.997057
# 42       0.990342      0.985767
# 43       0.994993      0.990501
# 44       1.008147      1.005038
# 45       0.996681      0.998891
# 46       0.949227      0.959548
# 47       0.984192      0.986919
# 48       0.978350      0.980478
# 49       0.981909      0.976190

# %%
bp_mean_2006.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['city','visual_left','visual_right']]
bp_mean_2007=bp_2007.groupby('city').mean()
bp_mean_2007
# Out:
#       visual_left  visual_right
# city
# 11       0.943881      0.942041
# 26       0.938300      0.937742
# 27       0.953591      0.955673
# 28       0.992104      0.986108
# 29       0.963584      0.962971
# 30       0.974161      0.976052
# 31       0.958829      0.960076
# 41       0.989108      0.984882
# 42       0.964741      0.964243
# 43       0.986655      0.975387
# 44       0.998378      0.997630
# 45       0.993552      0.991790
# 46       0.942078      0.947716
# 47       0.969610      0.973365
# 48       0.969930      0.971639
# 49       0.949482      0.949016

# %%
bp_mean_2007.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['city','visual_left','visual_right']]
bp_mean_2008=bp_2008.groupby('city').mean()
bp_mean_2008
# Out:
#       visual_left  visual_right
# city
# 11       0.956257      0.954658
# 26       0.944514      0.946942
# 27       0.970822      0.970443
# 28       0.998297      0.995922
# 29       0.988423      0.986609
# 30       1.002197      1.004429
# 31       0.972583      0.969016
# 41       0.999813      0.998095
# 42       0.975570      0.974553
# 43       1.007217      1.001741
# 44       1.020441      1.009341
# 45       0.996648      0.993550
# 46       0.964945      0.963233
# 47       0.992074      0.991169
# 48       0.987793      0.984646
# 49       0.952143      0.945507

# %%
bp_mean_2008.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %% [markdown]
# ### (6) visual by smoke

# %%
#2005
bp_2005=GJ_2005[['smoke','visual_left','visual_right']]
bp_mean_2005=bp_2005.groupby('smoke').mean()
bp_mean_2005
# Out:
#        visual_left  visual_right
# smoke
# 1.0       0.936802      0.937833
# 2.0       1.034257      1.028721
# 3.0       1.050278      1.047628

# %%
bp_mean_2005.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['smoke','visual_left','visual_right']]
bp_mean_2006=bp_2006.groupby('smoke').mean()
bp_mean_2006
# Out:
#        visual_left  visual_right
# smoke
# 1.0       0.947935      0.946548
# 2.0       1.033441      1.030599
# 3.0       1.053607      1.052022

# %%
bp_mean_2006.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['smoke','visual_left','visual_right']]
bp_mean_2007=bp_2007.groupby('smoke').mean()
bp_mean_2007
# Out:
#        visual_left  visual_right
# smoke
# 1.0       0.935408      0.933832
# 2.0       1.026734      1.025349
# 3.0       1.048827      1.046278

# %%
bp_mean_2007.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['smoke','visual_left','visual_right']]
bp_mean_2008=bp_2008.groupby('smoke').mean()
bp_mean_2008
# Out:
#        visual_left  visual_right
# smoke
# 1.0       0.947758      0.946236
# 2.0       1.029996      1.029400
# 3.0       1.055437      1.052365

# %%
bp_mean_2008.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %% [markdown]
# ### (7) visual by alcohol

# %%
#2005
bp_2005=GJ_2005[['alcohol','visual_left','visual_right']]
bp_mean_2005=bp_2005.groupby('alcohol').mean()
bp_mean_2005
# Out:
#          visual_left  visual_right
# alcohol
# 0.0         0.924876      0.925904
# 1.0         1.029030      1.026613

# %%
bp_mean_2005.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['alcohol','visual_left','visual_right']]
bp_mean_2006=bp_2006.groupby('alcohol').mean()
bp_mean_2006
# Out:
#          visual_left  visual_right
# alcohol
# 0.0         0.933002      0.933047
# 1.0         1.035430      1.032042

# %%
bp_mean_2006.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['alcohol','visual_left','visual_right']]
bp_mean_2007=bp_2007.groupby('alcohol').mean()
bp_mean_2007
# Out:
#          visual_left  visual_right
# alcohol
# 0.0         0.921801      0.919853
# 1.0         1.026550      1.024929

# %%
bp_mean_2007.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['alcohol','visual_left','visual_right']]
bp_mean_2008=bp_2008.groupby('alcohol').mean()
bp_mean_2008
# Out:
#          visual_left  visual_right
# alcohol
# 0.0         0.932979      0.931911
# 1.0         1.031557      1.028985

# %%
bp_mean_2008.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %% [markdown]
# ## (C) blood sugar

# %% [markdown]
# ### (1) blood sugar by sex

# %%
#2005
bp_2005=GJ_2005[['sex','b_sugar']]
bp_mean_2005=bp_2005.groupby('sex').mean()
bp_mean_2005
# Out:
#        b_sugar
# sex
# 1    96.258965
# 2    93.005493

# %%
bp_mean_2005.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['sex','b_sugar']]
bp_mean_2006=bp_2006.groupby('sex').mean()
bp_mean_2006
# Out:
#        b_sugar
# sex
# 1    96.441611
# 2    92.597619

# %%
bp_mean_2006.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['sex','b_sugar']]
bp_mean_2007=bp_2007.groupby('sex').mean()
bp_mean_2007
# Out:
#        b_sugar
# sex
# 1    97.069975
# 2    93.731673

# %%
bp_mean_2007.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['sex','b_sugar']]
bp_mean_2008=bp_2008.groupby('sex').mean()
bp_mean_2008
# Out:
#        b_sugar
# sex
# 1    97.694648
# 2    93.590446

# %%
bp_mean_2008.plot.bar(y='b_sugar',figsize=((10,5)))

# %% [markdown]
# ### (2) blood sugar by age

# %%
#2005
bp_2005=GJ_2005[['age','b_sugar']]
bp_mean_2005=bp_2005.groupby('age').mean()
bp_mean_2005=bp_mean_2005.iloc[:12]
bp_mean_2005
# Out:
#         b_sugar
# age
# 1     86.455509
# 2     87.560444
# 3     90.095698
# 4     92.579452
# 5     94.162965
# 6     96.001833
# 7     98.072420
# 8     99.932588
# 9    101.015722
# 10   101.953579
# 11   102.000221
# 12   103.415487

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='age',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['age','b_sugar']]
bp_mean_2006=bp_2006.groupby('age').mean()
bp_mean_2006=bp_mean_2006.iloc[:12]
bp_mean_2006
# Out:
#         b_sugar
# age
# 1     85.715018
# 2     87.240256
# 3     89.821489
# 4     92.216383
# 5     93.917823
# 6     95.870331
# 7     98.050941
# 8    100.189179
# 9    100.995127
# 10   101.946455
# 11   102.204771
# 12   102.747065

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='age',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['age','b_sugar']]
bp_mean_2007=bp_2007.groupby('age').mean()
bp_mean_2007=bp_mean_2007.iloc[:12]
bp_mean_2007
# Out:
#         b_sugar
# age
# 1     86.009858
# 2     87.655115
# 3     90.407671
# 4     92.935364
# 5     94.708278
# 6     96.554400
# 7     98.716453
# 8    100.875543
# 9    101.530512
# 10   102.265911
# 11   102.626417
# 12   103.830221

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='age',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['age','b_sugar']]
bp_mean_2008=bp_2008.groupby('age').mean()
bp_mean_2008=bp_mean_2008.iloc[:12]
bp_mean_2008
# Out:
#         b_sugar
# age
# 1     86.237608
# 2     87.921853
# 3     90.583361
# 4     92.850051
# 5     94.938183
# 6     96.919919
# 7     98.999397
# 8    101.200491
# 9    101.904319
# 10   102.844745
# 11   102.780965
# 12   103.030435

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='age',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (3) blood sugar by weight

# %%
#2005
bp_2005=GJ_2005[['weight','b_sugar']]
bp_mean_2005=bp_2005.groupby('weight').mean()
bp_mean_2005=bp_mean_2005.iloc[3:13]
bp_mean_2005
# Out:
#           b_sugar
# weight
# 45      91.050198
# 50      92.254344
# 55      93.641295
# 60      95.216421
# 65      95.998454
# 70      96.757742
# 75      97.152899
# 80      97.855886
# 85      97.710660
# 90      98.247722

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='weight',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['weight','b_sugar']]
bp_mean_2006=bp_2006.groupby('weight').mean()
bp_mean_2006=bp_mean_2006.iloc[3:13]
bp_mean_2006
# Out:
#           b_sugar
# weight
# 45      90.486062
# 50      91.590947
# 55      93.438207
# 60      95.166114
# 65      96.147982
# 70      96.936958
# 75      97.235544
# 80      97.861933
# 85      97.996079
# 90      98.092375

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='weight',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['weight','b_sugar']]
bp_mean_2007=bp_2007.groupby('weight').mean()
bp_mean_2007=bp_mean_2007.iloc[4:14]
bp_mean_2007
# Out:
#           b_sugar
# weight
# 45      91.583410
# 50      92.630697
# 55      94.384188
# 60      95.928803
# 65      96.938786
# 70      97.514006
# 75      97.956363
# 80      98.323566
# 85      98.646705
# 90      99.617785

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='weight',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['weight','b_sugar']]
bp_mean_2008=bp_2008.groupby('weight').mean()
bp_mean_2008=bp_mean_2008.iloc[3:13]
bp_mean_2008
# Out:
#           b_sugar
# weight
# 45      91.260605
# 50      92.425081
# 55      94.451759
# 60      96.166810
# 65      97.438911
# 70      98.185247
# 75      98.394531
# 80      99.151309
# 85      99.310557
# 90      99.773340

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='weight',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (4) blood sugar by height

# %%
#2005
bp_2005=GJ_2005[['height','b_sugar']]
bp_mean_2005=bp_2005.groupby('height').mean()
bp_mean_2005=bp_mean_2005.iloc[5:13]
bp_mean_2005
# Out:
#           b_sugar
# height
# 145     97.295369
# 150     95.185622
# 155     93.681641
# 160     94.781710
# 165     95.921684
# 170     95.140112
# 175     93.817239
# 180     92.137530

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='height',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['height','b_sugar']]
bp_mean_2006=bp_2006.groupby('height').mean()
bp_mean_2006=bp_mean_2006.iloc[4:12]
bp_mean_2006
# Out:
#           b_sugar
# height
# 145     97.428664
# 150     94.886027
# 155     93.423313
# 160     94.281145
# 165     96.056260
# 170     95.313806
# 175     93.814881
# 180     92.618039

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='height',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['height','b_sugar']]
bp_mean_2007=bp_2007.groupby('height').mean()
bp_mean_2007=bp_mean_2007.iloc[5:13]
bp_mean_2007
# Out:
#           b_sugar
# height
# 145     98.166781
# 150     95.999072
# 155     94.557278
# 160     95.371925
# 165     96.831782
# 170     95.881829
# 175     94.290552
# 180     92.759080

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='height',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['height','b_sugar']]
bp_mean_2008=bp_2008.groupby('height').mean()
bp_mean_2008=bp_mean_2008.iloc[4:12]
bp_mean_2008
# Out:
#           b_sugar
# height
# 145     98.285526
# 150     95.962790
# 155     94.380120
# 160     95.341439
# 165     97.240255
# 170     96.626190
# 175     95.009510
# 180     93.530699

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='height',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (5) blood sugar by city

# %%
#2005
bp_2005=GJ_2005[['city','b_sugar']]
bp_mean_2005=bp_2005.groupby('city').mean()
bp_mean_2005=bp_mean_2005.sort_values('b_sugar',ascending=True)
bp_mean_2005
# Out:
#         b_sugar
# city
# 11    93.379349
# 27    94.181263
# 41    94.202079
# 31    94.831749
# 43    94.892206
# 44    95.104678
# 45    95.281395
# 47    95.320932
# 30    95.383210
# 48    95.451065
# 28    95.534582
# 26    96.297102
# 42    96.479174
# 29    96.692121
# 49    96.901669
# 46    97.508994

# %%
bp_mean_2005.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['city','b_sugar']]
bp_mean_2006=bp_2006.groupby('city').mean()
bp_mean_2006=bp_mean_2006.sort_values('b_sugar',ascending=True)
bp_mean_2006
# Out:
#         b_sugar
# city
# 27    93.668921
# 11    93.993922
# 47    94.399432
# 43    94.407131
# 41    94.422131
# 44    94.544438
# 42    94.823972
# 28    94.959801
# 30    95.068025
# 45    95.171519
# 49    95.228186
# 48    95.254616
# 31    95.449105
# 26    96.160620
# 29    97.203901
# 46    97.365365

# %%
bp_mean_2006.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['city','b_sugar']]
bp_mean_2007=bp_2007.groupby('city').mean()
bp_mean_2007=bp_mean_2007.sort_values('b_sugar',ascending=True)
bp_mean_2007
# Out:
#         b_sugar
# city
# 43    94.607273
# 27    94.642348
# 11    94.870395
# 41    95.035734
# 44    95.082144
# 49    95.505286
# 47    95.582371
# 30    95.722878
# 28    96.272558
# 45    96.290128
# 48    96.297602
# 42    96.417302
# 26    96.700350
# 31    96.781367
# 46    98.202618
# 29    98.219197

# %%
bp_mean_2007.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['city','b_sugar']]
bp_mean_2008=bp_2008.groupby('city').mean()
bp_mean_2008=bp_mean_2008.sort_values('b_sugar',ascending=True)
bp_mean_2008
# Out:
#         b_sugar
# city
# 43    94.529182
# 27    94.984811
# 30    95.140257
# 11    95.262854
# 41    95.413607
# 47    95.658091
# 45    95.723415
# 44    95.749152
# 49    96.242227
# 28    96.288005
# 48    96.464277
# 42    96.466451
# 31    96.647075
# 26    97.410331
# 29    97.792749
# 46    98.536527

# %%
bp_mean_2008.plot.bar(y='b_sugar',figsize=((10,5)))

# %% [markdown]
# ### (6) blood sugar by smoke

# %%
#2005
bp_2005=GJ_2005[['smoke','b_sugar']]
bp_mean_2005=bp_2005.groupby('smoke').mean()
bp_mean_2005
# Out:
#          b_sugar
# smoke
# 1.0    94.348769
# 2.0    96.701171
# 3.0    95.703469

# %%
bp_mean_2005.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['smoke','b_sugar']]
bp_mean_2006=bp_2006.groupby('smoke').mean()
bp_mean_2006
# Out:
#          b_sugar
# smoke
# 1.0    94.105323
# 2.0    96.970866
# 3.0    95.919640

# %%
bp_mean_2006.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['smoke','b_sugar']]
bp_mean_2007=bp_2007.groupby('smoke').mean()
bp_mean_2007
# Out:
#          b_sugar
# smoke
# 1.0    95.116078
# 2.0    97.737052
# 3.0    96.043416

# %%
bp_mean_2007.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['smoke','b_sugar']]
bp_mean_2008=bp_2008.groupby('smoke').mean()
bp_mean_2008
# Out:
#          b_sugar
# smoke
# 1.0    95.030727
# 2.0    98.356333
# 3.0    96.813123

# %%
bp_mean_2008.plot.bar(y='b_sugar',figsize=((10,5)))

# %% [markdown]
# ### (7) blood sugar by alcohol

# %%
#2005
bp_2005=GJ_2005[['alcohol','b_sugar']]
bp_mean_2005=bp_2005.groupby('alcohol').mean()
bp_mean_2005
# Out:
#            b_sugar
# alcohol
# 0.0      94.865608
# 1.0      95.005723

# %%
bp_mean_2005.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['alcohol','b_sugar']]
bp_mean_2006=bp_2006.groupby('alcohol').mean()
bp_mean_2006
# Out:
#            b_sugar
# alcohol
# 0.0      94.574543
# 1.0      95.106084

# %%
bp_mean_2006.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['alcohol','b_sugar']]
bp_mean_2007=bp_2007.groupby('alcohol').mean()
bp_mean_2007
# Out:
#            b_sugar
# alcohol
# 0.0      95.676073
# 1.0      95.546445

# %%
bp_mean_2007.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['alcohol','b_sugar']]
bp_mean_2008=bp_2008.groupby('alcohol').mean()
bp_mean_2008
# Out:
#            b_sugar
# alcohol
# 0.0      95.554388
# 1.0      96.009838

# %%
bp_mean_2008.plot.bar(y='b_sugar',figsize=((10,5)))

# %% [markdown]
# ## (D) cholesterol

# %% [markdown]
# ### (1) cholesterol by sex

# %%
#2005
bp_2005=GJ_2005[['sex','cholesterol']]
bp_mean_2005=bp_2005.groupby('sex').mean()
bp_mean_2005
# Out:
#      cholesterol
# sex
# 1     192.129694
# 2     192.708157

# %%
bp_mean_2005.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['sex','cholesterol']]
bp_mean_2006=bp_2006.groupby('sex').mean()
bp_mean_2006
# Out:
#      cholesterol
# sex
# 1     193.188697
# 2     192.708955

# %%
bp_mean_2006.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['sex','cholesterol']]
bp_mean_2007=bp_2007.groupby('sex').mean()
bp_mean_2007
# Out:
#      cholesterol
# sex
# 1     192.378019
# 2     193.452604

# %%
bp_mean_2007.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['sex','cholesterol']]
bp_mean_2008=bp_2008.groupby('sex').mean()
bp_mean_2008
# Out:
#      cholesterol
# sex
# 1     192.580402
# 2     192.431246

# %%
bp_mean_2008.plot.bar(y='cholesterol',figsize=((10,5)))

# %% [markdown]
# ### (2) cholesterol by age

# %%
#2005
bp_2005=GJ_2005[['age','cholesterol']]
bp_mean_2005=bp_2005.groupby('age').mean()
bp_mean_2005=bp_mean_2005.iloc[:12]
bp_mean_2005
# Out:
#      cholesterol
# age
# 1     170.386644
# 2     178.092292
# 3     186.920927
# 4     190.467406
# 5     191.431053
# 6     195.414512
# 7     201.054621
# 8     202.333437
# 9     201.051416
# 10    199.124578
# 11    198.754560
# 12    198.206837

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='age',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['age','cholesterol']]
bp_mean_2006=bp_2006.groupby('age').mean()
bp_mean_2006=bp_mean_2006.iloc[:12]
bp_mean_2006
# Out:
#      cholesterol
# age
# 1     170.869095
# 2     178.573126
# 3     186.967440
# 4     190.679402
# 5     191.895169
# 6     196.103362
# 7     201.405500
# 8     202.778551
# 9     201.821937
# 10    199.845863
# 11    199.029202
# 12    199.879521

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='age',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['age','cholesterol']]
bp_mean_2007=bp_2007.groupby('age').mean()
bp_mean_2007=bp_mean_2007.iloc[:12]
bp_mean_2007
# Out:
#      cholesterol
# age
# 1     170.197127
# 2     178.316984
# 3     187.438964
# 4     190.907578
# 5     191.714926
# 6     195.856263
# 7     201.053912
# 8     201.910541
# 9     201.033140
# 10    198.617276
# 11    197.738803
# 12    198.294397

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='age',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['age','cholesterol']]
bp_mean_2008=bp_2008.groupby('age').mean()
bp_mean_2008=bp_mean_2008.iloc[:12]
bp_mean_2008
# Out:
#      cholesterol
# age
# 1     169.987477
# 2     178.193126
# 3     186.596073
# 4     190.461417
# 5     191.835554
# 6     195.846914
# 7     200.545543
# 8     201.493101
# 9     199.787401
# 10    197.981564
# 11    196.227942
# 12    196.523810

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='age',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (3) cholesterol by weight

# %%
#2005
bp_2005=GJ_2005[['weight','cholesterol']]
bp_mean_2005=bp_2005.groupby('weight').mean()
bp_mean_2005=bp_mean_2005.iloc[3:13]
bp_mean_2005
# Out:
#         cholesterol
# weight
# 45       184.591320
# 50       187.313691
# 55       190.018494
# 60       192.064197
# 65       193.573469
# 70       195.648624
# 75       197.628305
# 80       200.057741
# 85       201.760707
# 90       202.791074

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='weight',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['weight','cholesterol']]
bp_mean_2006=bp_2006.groupby('weight').mean()
bp_mean_2006=bp_mean_2006.iloc[3:13]
bp_mean_2006
# Out:
#         cholesterol
# weight
# 45       185.241994
# 50       187.838550
# 55       190.855618
# 60       192.774926
# 65       194.312524
# 70       196.177599
# 75       197.994063
# 80       199.790344
# 85       201.735942
# 90       202.717727

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='weight',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['weight','cholesterol']]
bp_mean_2007=bp_2007.groupby('weight').mean()
bp_mean_2007=bp_mean_2007.iloc[4:14]
bp_mean_2007
# Out:
#         cholesterol
# weight
# 45       185.827783
# 50       188.481267
# 55       190.946811
# 60       192.589789
# 65       193.853941
# 70       195.476704
# 75       197.218724
# 80       198.915293
# 85       200.754938
# 90       202.402313

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='weight',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['weight','cholesterol']]
bp_mean_2008=bp_2008.groupby('weight').mean()
bp_mean_2008=bp_mean_2008.iloc[3:13]
bp_mean_2008
# Out:
#         cholesterol
# weight
# 45       184.939361
# 50       187.903974
# 55       190.768682
# 60       192.381825
# 65       193.798298
# 70       195.303251
# 75       196.853719
# 80       198.687697
# 85       200.322863
# 90       202.550743

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='weight',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (4) cholesterol by height

# %%
#2005
bp_2005=GJ_2005[['height','cholesterol']]
bp_mean_2005=bp_2005.groupby('height').mean()
bp_mean_2005=bp_mean_2005.iloc[5:13]
bp_mean_2005
# Out:
#         cholesterol
# height
# 145      204.114499
# 150      198.560695
# 155      192.395352
# 160      189.754798
# 165      191.356745
# 170      191.431630
# 175      189.500249
# 180      186.682638

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='height',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['height','cholesterol']]
bp_mean_2006=bp_2006.groupby('height').mean()
bp_mean_2006=bp_mean_2006.iloc[4:12]
bp_mean_2006
# Out:
#         cholesterol
# height
# 145      204.606749
# 150      198.841763
# 155      192.841760
# 160      189.920832
# 165      192.229067
# 170      192.441493
# 175      190.464287
# 180      187.845841

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='height',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['height','cholesterol']]
bp_mean_2007=bp_2007.groupby('height').mean()
bp_mean_2007=bp_mean_2007.iloc[5:13]
bp_mean_2007
# Out:
#         cholesterol
# height
# 145      204.157703
# 150      199.320204
# 155      193.300621
# 160      190.126589
# 165      191.495754
# 170      191.869243
# 175      189.876489
# 180      186.948899

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='height',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['height','cholesterol']]
bp_mean_2008=bp_2008.groupby('height').mean()
bp_mean_2008=bp_mean_2008.iloc[4:12]
bp_mean_2008
# Out:
#         cholesterol
# height
# 145      203.341887
# 150      198.489100
# 155      192.650558
# 160      189.595870
# 165      191.481298
# 170      192.120390
# 175      190.208169
# 180      187.310304

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='height',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (5) cholesterol by city

# %%
#2005
bp_2005=GJ_2005[['city','cholesterol']]
bp_mean_2005=bp_2005.groupby('city').mean()
bp_mean_2005
# Out:
#       cholesterol
# city
# 11     193.306421
# 26     193.810991
# 27     191.394550
# 28     192.110599
# 29     190.037445
# 30     192.358760
# 31     193.775104
# 41     192.545200
# 42     191.690355
# 43     191.401113
# 44     191.754352
# 45     191.571826
# 46     191.957298
# 47     190.805177
# 48     192.261879
# 49     192.348927

# %%
bp_mean_2005.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['city','cholesterol']]
bp_mean_2006=bp_2006.groupby('city').mean()
bp_mean_2006
# Out:
#       cholesterol
# city
# 11     193.772115
# 26     195.182796
# 27     192.212224
# 28     191.614955
# 29     190.711949
# 30     192.658989
# 31     194.181681
# 41     193.409001
# 42     192.128171
# 43     191.210337
# 44     191.403195
# 45     192.043133
# 46     192.361634
# 47     192.987039
# 48     192.612382
# 49     191.546346

# %%
bp_mean_2006.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['city','cholesterol']]
bp_mean_2007=bp_2007.groupby('city').mean()
bp_mean_2007
# Out:
#       cholesterol
# city
# 11     194.086602
# 26     194.345616
# 27     191.848747
# 28     192.025429
# 29     191.238958
# 30     191.867574
# 31     194.379104
# 41     193.080511
# 42     192.554339
# 43     191.920819
# 44     190.391089
# 45     192.005249
# 46     192.323285
# 47     192.966071
# 48     191.267651
# 49     192.578797

# %%
bp_mean_2007.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['city','cholesterol']]
bp_mean_2008=bp_2008.groupby('city').mean()
bp_mean_2008
# Out:
#       cholesterol
# city
# 11     193.467445
# 26     193.585427
# 27     191.111594
# 28     192.380841
# 29     190.887636
# 30     191.680362
# 31     191.473586
# 41     192.889043
# 42     191.625067
# 43     192.686059
# 44     191.154074
# 45     190.894275
# 46     192.878262
# 47     192.890164
# 48     191.497406
# 49     192.896989

# %%
bp_mean_2008.plot.bar(y='cholesterol',figsize=((10,5)))

# %% [markdown]
# ### (6) cholesterol by smoke

# %%
#2005
bp_2005=GJ_2005[['smoke','cholesterol']]
bp_mean_2005=bp_2005.groupby('smoke').mean()
bp_mean_2005
# Out:
#        cholesterol
# smoke
# 1.0     192.314222
# 2.0     194.139547
# 3.0     191.996717

# %%
bp_mean_2005.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['smoke','cholesterol']]
bp_mean_2006=bp_2006.groupby('smoke').mean()
bp_mean_2006
# Out:
#        cholesterol
# smoke
# 1.0     192.703499
# 2.0     195.132176
# 3.0     193.072460

# %%
bp_mean_2006.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['smoke','cholesterol']]
bp_mean_2007=bp_2007.groupby('smoke').mean()
bp_mean_2007
# Out:
#        cholesterol
# smoke
# 1.0     192.887529
# 2.0     194.376150
# 3.0     192.035793

# %%
bp_mean_2007.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['smoke','cholesterol']]
bp_mean_2008=bp_2008.groupby('smoke').mean()
bp_mean_2008
# Out:
#        cholesterol
# smoke
# 1.0     192.193512
# 2.0     194.518230
# 3.0     192.311130

# %%
bp_mean_2008.plot.bar(y='cholesterol',figsize=((10,5)))

# %% [markdown]
# ### (7) cholesterol by alcohol

# %%
#2005
bp_2005=GJ_2005[['alcohol','cholesterol']]
bp_mean_2005=bp_2005.groupby('alcohol').mean()
bp_mean_2005
# Out:
#          cholesterol
# alcohol
# 0.0       193.637436
# 1.0       191.144096

# %%
bp_mean_2005.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['alcohol','cholesterol']]
bp_mean_2006=bp_2006.groupby('alcohol').mean()
bp_mean_2006
# Out:
#          cholesterol
# alcohol
# 0.0       194.036939
# 1.0       191.978464

# %%
bp_mean_2006.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['alcohol','cholesterol']]
bp_mean_2007=bp_2007.groupby('alcohol').mean()
bp_mean_2007
# Out:
#          cholesterol
# alcohol
# 0.0       194.177929
# 1.0       191.443336

# %%
bp_mean_2007.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['alcohol','cholesterol']]
bp_mean_2008=bp_2008.groupby('alcohol').mean()
bp_mean_2008
# Out:
#          cholesterol
# alcohol
# 0.0       193.422453
# 1.0       191.460580

# %%
bp_mean_2008.plot.bar(y='cholesterol',figsize=((10,5)))

# %% [markdown]
# ## (E) liver function

# %% [markdown]
# ### (1) liver function by sex

# %%
#2005
bp_2005=GJ_2005[['sex','got_ast','got_alt','gtp']]
bp_mean_2005=bp_2005.groupby('sex').mean()
bp_mean_2005
# Out:
#        got_ast    got_alt        gtp
# sex
# 1    27.861271  30.093165  46.299963
# 2    23.105724  19.635230  20.352532

# %%
bp_mean_2005.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['sex','got_ast','got_alt','gtp']]
bp_mean_2006=bp_2006.groupby('sex').mean()
bp_mean_2006
# Out:
#        got_ast    got_alt        gtp
# sex
# 1    27.475521  29.942015  46.947577
# 2    22.643987  19.401845  20.456498

# %%
bp_mean_2006.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['sex','got_ast','got_alt','gtp']]
bp_mean_2007=bp_2007.groupby('sex').mean()
bp_mean_2007
# Out:
#        got_ast    got_alt        gtp
# sex
# 1    26.991345  29.317016  47.079781
# 2    22.648970  19.650844  21.350448

# %%
bp_mean_2007.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['sex','got_ast','got_alt','gtp']]
bp_mean_2008=bp_2008.groupby('sex').mean()
bp_mean_2008
# Out:
#        got_ast    got_alt        gtp
# sex
# 1    27.216548  29.891727  48.130204
# 2    22.643854  19.792413  21.502818

# %%
bp_mean_2008.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((10,5)))

# %% [markdown]
# ### (2) liver function by age

# %%
#2005
bp_2005=GJ_2005[['age','got_ast','got_alt','gtp']]
bp_mean_2005=bp_2005.groupby('age').mean()
bp_mean_2005=bp_mean_2005.iloc[:12]
bp_mean_2005
# Out:
#        got_ast    got_alt        gtp
# age
# 1    20.809456  17.687495  18.449001
# 2    23.115983  23.298252  26.379940
# 3    25.394226  28.911655  35.871939
# 4    26.078972  29.197745  39.947834
# 5    25.441593  26.083573  37.103578
# 6    26.039315  25.889561  38.937394
# 7    27.089727  26.362780  39.004302
# 8    27.691149  26.246733  39.137465
# 9    27.953078  25.300306  37.269817
# 10   28.017932  24.318261  35.916855
# 11   27.380200  22.618167  32.644128
# 12   26.997928  20.923688  28.799465

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='age',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['age','got_ast','got_alt','gtp']]
bp_mean_2006=bp_2006.groupby('age').mean()
bp_mean_2006=bp_mean_2006.iloc[:12]
bp_mean_2006
# Out:
#        got_ast    got_alt        gtp
# age
# 1    21.003699  17.960661  19.340796
# 2    22.690101  22.846629  26.273494
# 3    24.658513  27.868327  34.935801
# 4    25.323772  28.227328  38.764649
# 5    25.000000  25.856475  37.205527
# 6    25.665815  25.777829  39.271650
# 7    26.667304  26.465376  39.947884
# 8    27.291089  26.286629  39.583624
# 9    27.238599  25.105714  37.021760
# 10   27.316627  24.035203  36.150866
# 11   27.084151  22.608144  33.316178
# 12   26.480409  20.550603  28.892766

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='age',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['age','got_ast','got_alt','gtp']]
bp_mean_2007=bp_2007.groupby('age').mean()
bp_mean_2007=bp_mean_2007.iloc[:12]
bp_mean_2007
# Out:
#        got_ast    got_alt        gtp
# age
# 1    20.835569  17.739911  19.441778
# 2    22.531329  22.802811  27.035741
# 3    24.386575  27.783656  36.202645
# 4    25.119470  28.245838  40.619152
# 5    24.410979  25.354561  37.134687
# 6    25.205255  25.355772  39.099193
# 7    26.297734  26.106891  39.797645
# 8    26.988244  26.097598  40.002037
# 9    26.993066  25.223146  37.550937
# 10   26.965621  23.957782  36.392175
# 11   26.690485  22.599052  33.514658
# 12   26.236546  20.738058  29.586842

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='age',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['age','got_ast','got_alt','gtp']]
bp_mean_2008=bp_2008.groupby('age').mean()
bp_mean_2008=bp_mean_2008.iloc[:12]
bp_mean_2008
# Out:
#        got_ast    got_alt        gtp
# age
# 1    20.764681  17.795703  19.506670
# 2    22.481140  22.645021  26.798788
# 3    24.237482  27.447370  35.065729
# 4    24.868526  27.853823  39.186149
# 5    24.565047  25.719289  37.501839
# 6    25.342002  25.747169  39.435774
# 7    26.499715  26.548531  40.966989
# 8    27.195139  26.768603  41.068130
# 9    27.122911  25.726454  38.327711
# 10   27.238019  24.567710  36.981967
# 11   26.638187  22.760384  34.296148
# 12   26.337888  21.160732  30.953347

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='age',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (3) liver function by city

# %%
#2005
bp_2005=GJ_2005[['city','got_ast','got_alt','gtp']]
bp_mean_2005=bp_2005.groupby('city').mean()
bp_mean_2005
# Out:
#         got_ast    got_alt        gtp
# city
# 11    25.200428  25.274403  34.553571
# 26    26.191856  25.533165  36.229642
# 27    25.230665  25.414052  35.009852
# 28    25.816839  26.013650  37.139224
# 29    25.446502  25.919845  34.573969
# 30    26.170054  25.625584  34.549721
# 31    26.285337  26.803757  36.831650
# 41    25.454973  26.072806  35.646436
# 42    26.723791  26.405259  38.893655
# 43    26.793923  25.732739  35.380708
# 44    26.416503  25.752589  35.191769
# 45    26.002915  25.808803  34.631502
# 46    27.744777  26.137066  37.627773
# 47    26.673934  25.705077  35.445567
# 48    26.207338  25.950010  35.702829
# 49    25.623460  25.493246  36.231228

# %%
bp_mean_2005.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((20,10)))

# %%
#2006
bp_2006=GJ_2006[['city','got_ast','got_alt','gtp']]
bp_mean_2006=bp_2006.groupby('city').mean()
bp_mean_2006
# Out:
#         got_ast    got_alt        gtp
# city
# 11    24.833230  24.632730  34.212462
# 26    25.944593  25.580561  36.324106
# 27    24.721693  25.218595  33.544143
# 28    24.907551  25.477426  36.520315
# 29    24.865127  25.224526  35.675376
# 30    25.475920  25.628414  35.162506
# 31    26.378930  26.870428  36.228830
# 41    25.164341  25.590754  35.681755
# 42    26.113841  26.533494  39.778681
# 43    26.101204  25.668480  36.703160
# 44    25.709589  25.539692  35.944253
# 45    25.623148  25.528715  35.811003
# 46    27.099877  26.271826  39.213760
# 47    25.922466  25.449536  35.309988
# 48    25.708380  25.774090  36.149698
# 49    25.497913  25.885082  36.053480

# %%
bp_mean_2006.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((20,10)))

# %%
#2007
bp_2007=GJ_2007[['city','got_ast','got_alt','gtp']]
bp_mean_2007=bp_2007.groupby('city').mean()
bp_mean_2007
# Out:
#         got_ast    got_alt        gtp
# city
# 11    24.609028  24.550130  34.890003
# 26    25.462493  25.091070  36.461326
# 27    24.727980  25.202350  34.845434
# 28    24.874700  25.261182  37.980683
# 29    24.829650  24.759779  35.308904
# 30    25.319231  25.219685  35.602654
# 31    26.252811  26.533803  36.381240
# 41    24.861639  25.463372  36.011807
# 42    25.702481  26.124063  39.193657
# 43    25.905519  25.205821  35.859587
# 44    25.336775  25.004205  37.190205
# 45    25.287038  24.740139  36.128536
# 46    26.633088  26.045107  38.131580
# 47    25.487344  24.858381  35.954196
# 48    25.331241  25.521513  36.434441
# 49    25.450692  25.120937  36.343741

# %%
bp_mean_2007.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((20,10)))

# %%
#2008
bp_2008=GJ_2008[['city','got_ast','got_alt','gtp']]
bp_mean_2008=bp_2008.groupby('city').mean()
bp_mean_2008
# Out:
#         got_ast    got_alt        gtp
# city
# 11    24.669063  24.880011  35.025623
# 26    25.532665  25.243133  37.193611
# 27    24.833594  25.372049  35.105109
# 28    25.184266  25.923015  37.709278
# 29    25.082889  25.093556  35.255685
# 30    24.881900  25.011617  35.033331
# 31    25.032235  25.529245  36.186936
# 41    25.097029  25.826610  36.496134
# 42    25.930450  26.241648  39.890977
# 43    25.851097  25.795029  37.104874
# 44    25.124726  25.274687  36.873012
# 45    25.457173  25.506150  36.457537
# 46    26.758079  26.109873  38.785700
# 47    25.672061  25.321034  36.673435
# 48    25.375836  25.471673  36.868950
# 49    25.252288  25.156745  36.741047

# %%
bp_mean_2008.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((20,10)))

# %% [markdown]
# ### (4) liver function by weight

# %%
#2005
bp_2005=GJ_2005[['weight','got_ast','got_alt','gtp']]
bp_mean_2005=bp_2005.groupby('weight').mean()
bp_mean_2005=bp_mean_2005.iloc[3:13]
bp_mean_2005
# Out:
#           got_ast    got_alt        gtp
# weight
# 45      23.107001  17.660566  21.081407
# 50      23.595684  19.075630  23.753238
# 55      24.525601  21.288194  28.045943
# 60      25.438253  23.947594  33.378577
# 65      26.238355  26.741820  38.845688
# 70      27.197852  30.137671  44.274307
# 75      28.291399  33.663799  49.309699
# 80      29.737704  37.753652  53.536606
# 85      30.937797  41.677026  57.706444
# 90      32.809807  46.621046  61.058962

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='weight',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['weight','got_ast','got_alt','gtp']]
bp_mean_2006=bp_2006.groupby('weight').mean()
bp_mean_2006=bp_mean_2006.iloc[3:13]
bp_mean_2006
# Out:
#           got_ast    got_alt        gtp
# weight
# 45      22.484474  17.379915  20.766494
# 50      23.042478  18.804267  23.386178
# 55      23.963693  20.870619  27.496915
# 60      24.977707  23.643400  33.655284
# 65      25.888661  26.577499  39.080424
# 70      26.754758  29.650348  44.682956
# 75      27.810644  33.035634  49.277532
# 80      29.137393  37.140654  54.264752
# 85      30.500388  41.110402  57.943982
# 90      32.004177  45.467606  60.659835

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='weight',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['weight','got_ast','got_alt','gtp']]
bp_mean_2007=bp_2007.groupby('weight').mean()
bp_mean_2007=bp_mean_2007.iloc[4:14]
bp_mean_2007
# Out:
#           got_ast    got_alt        gtp
# weight
# 45      22.520477  17.471874  21.705846
# 50      22.989096  18.892012  24.169401
# 55      23.801469  20.831938  28.211152
# 60      24.698921  23.350359  33.885505
# 65      25.408053  26.008645  39.151484
# 70      26.338723  29.135098  44.706403
# 75      27.331722  32.368460  49.097568
# 80      28.510830  36.262814  53.933691
# 85      29.777637  40.311139  57.934681
# 90      31.649812  45.120400  61.621088

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='weight',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['weight','got_ast','got_alt','gtp']]
bp_mean_2008=bp_2008.groupby('weight').mean()
bp_mean_2008=bp_mean_2008.iloc[3:13]
bp_mean_2008
# Out:
#           got_ast    got_alt        gtp
# weight
# 45      22.221639  17.337231  20.929945
# 50      22.779731  18.829952  23.860854
# 55      23.713219  20.900486  28.244385
# 60      24.776031  23.515780  34.100880
# 65      25.551970  26.350106  39.749709
# 70      26.549130  29.545619  45.344542
# 75      27.500633  32.718638  50.130164
# 80      28.913303  36.789981  55.028625
# 85      30.467050  41.113301  58.628603
# 90      32.043309  45.738330  62.927818

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='weight',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (5) liver function by height

# %%
#2005
bp_2005=GJ_2005[['height','got_ast','got_alt','gtp']]
bp_mean_2005=bp_2005.groupby('height').mean()
bp_mean_2005=bp_mean_2005.iloc[5:13]
bp_mean_2005
# Out:
#           got_ast    got_alt        gtp
# height
# 145     25.587132  21.823993  23.636735
# 150     24.532547  21.290945  23.082624
# 155     24.039812  20.992206  25.275871
# 160     25.268347  23.719395  34.267806
# 165     26.983155  28.043009  43.071651
# 170     27.173672  29.879413  44.154600
# 175     26.911203  30.674088  42.553606
# 180     26.425126  30.366830  40.201088

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='height',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['height','got_ast','got_alt','gtp']]
bp_mean_2006=bp_2006.groupby('height').mean()
bp_mean_2006=bp_mean_2006.iloc[4:12]
bp_mean_2006
# Out:
#           got_ast    got_alt        gtp
# height
# 145     25.069432  21.567454  23.731006
# 150     24.040002  21.049047  23.335945
# 155     23.466277  20.718546  24.985690
# 160     24.658000  23.217496  33.552980
# 165     26.522349  27.733669  43.288583
# 170     26.853230  29.781140  44.942394
# 175     26.600106  30.222016  43.134167
# 180     26.072240  30.232727  40.882439

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='height',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['height','got_ast','got_alt','gtp']]
bp_mean_2007=bp_2007.groupby('height').mean()
bp_mean_2007=bp_mean_2007.iloc[5:13]
bp_mean_2007
# Out:
#           got_ast    got_alt        gtp
# height
# 145     24.956455  21.660126  24.613910
# 150     24.006057  21.286421  24.279319
# 155     23.373087  20.797975  25.822044
# 160     24.462908  23.054806  34.127477
# 165     26.085243  27.131460  43.484846
# 170     26.428892  29.246598  45.124682
# 175     26.116229  29.851805  43.680545
# 180     25.583488  29.619905  40.567792

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='height',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['height','got_ast','got_alt','gtp']]
bp_mean_2008=bp_2008.groupby('height').mean()
bp_mean_2008=bp_mean_2008.iloc[4:12]
bp_mean_2008
# Out:
#           got_ast    got_alt        gtp
# height
# 145     25.119530  22.073750  25.230759
# 150     24.076275  21.494410  24.377180
# 155     23.447227  21.070658  25.800009
# 160     24.343852  23.041993  33.834671
# 165     26.145708  27.379117  43.881002
# 170     26.602930  29.710743  46.070118
# 175     26.392068  30.341169  44.343827
# 180     25.897670  30.140720  41.937218

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='height',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (6) liver function by smoke

# %%
#2005
bp_2005=GJ_2005[['smoke','got_ast','got_alt','gtp']]
bp_mean_2005=bp_2005.groupby('smoke').mean()
bp_mean_2005
# Out:
#          got_ast    got_alt        gtp
# smoke
# 1.0    24.851882  23.356848  28.293603
# 2.0    27.687929  29.668381  43.691510
# 3.0    27.797730  30.214197  50.368375

# %%
bp_mean_2005.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['smoke','got_ast','got_alt','gtp']]
bp_mean_2006=bp_2006.groupby('smoke').mean()
bp_mean_2006
# Out:
#          got_ast    got_alt        gtp
# smoke
# 1.0    24.367026  23.045724  28.447312
# 2.0    27.317364  29.499036  44.534331
# 3.0    27.516623  30.253871  51.451148

# %%
bp_mean_2006.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['smoke','got_ast','got_alt','gtp']]
bp_mean_2007=bp_2007.groupby('smoke').mean()
bp_mean_2007
# Out:
#          got_ast    got_alt        gtp
# smoke
# 1.0    24.271045  22.987506  28.876444
# 2.0    26.872884  28.954159  44.946919
# 3.0    26.782640  29.346049  50.843840

# %%
bp_mean_2007.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['smoke','got_ast','got_alt','gtp']]
bp_mean_2008=bp_2008.groupby('smoke').mean()
bp_mean_2008
# Out:
#          got_ast    got_alt        gtp
# smoke
# 1.0    24.218164  23.133219  28.894504
# 2.0    27.152355  29.564390  45.889829
# 3.0    27.034699  29.976069  52.233735

# %%
bp_mean_2008.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))

# %% [markdown]
# ### (7) liver function by alcohol

# %%
#2005
bp_2005=GJ_2005[['alcohol','got_ast','got_alt','gtp']]
bp_mean_2005=bp_2005.groupby('alcohol').mean()
bp_mean_2005
# Out:
#            got_ast    got_alt        gtp
# alcohol
# 0.0      24.880124  23.905521  26.455296
# 1.0      26.951886  27.708845  45.062665

# %%
bp_mean_2005.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2006[['alcohol','got_ast','got_alt','gtp']]
bp_mean_2006=bp_2006.groupby('alcohol').mean()
bp_mean_2006
# Out:
#            got_ast    got_alt        gtp
# alcohol
# 0.0      24.374991  23.509945  26.730610
# 1.0      26.563991  27.559317  45.361144

# %%
bp_mean_2006.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2007[['alcohol','got_ast','got_alt','gtp']]
bp_mean_2007=bp_2007.groupby('alcohol').mean()
bp_mean_2007
# Out:
#            got_ast    got_alt        gtp
# alcohol
# 0.0      24.295189  23.528871  27.151427
# 1.0      26.068694  26.955304  45.371844

# %%
bp_mean_2007.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2008[['alcohol','got_ast','got_alt','gtp']]
bp_mean_2008=bp_2008.groupby('alcohol').mean()
bp_mean_2008
# Out:
#            got_ast    got_alt        gtp
# alcohol
# 0.0      24.249621  23.698753  26.989662
# 1.0      26.139979  27.204322  45.672546

# %%
bp_mean_2008.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))
