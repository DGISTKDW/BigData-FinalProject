# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
GJ_2009 = pd.read_csv('NHIS_OPEN_GJ_2009.CSV')
GJ_2009 = GJ_2009[GJ_2009['age'] < 13]
GJ_2009 = GJ_2009[GJ_2009['height'] <= 180]
GJ_2009 = GJ_2009[GJ_2009['height'] >= 145]
GJ_2009 = GJ_2009[GJ_2009['weight'] <= 90]
GJ_2009 = GJ_2009[GJ_2009['weight'] >= 45]
GJ_2009.head()
# Out:
#    year  identity  sex  age  city  height  weight  waist  visual_left  \
# 5  2009    856304    2    1    43     145      45     64          1.5
# 6  2009    929881    2    1    41     145      45     68          0.2
# 7  2009    797895    2    1    44     145      50     68          1.5
# 8  2009    714243    2    1    26     145      50     75          1.5
# 9  2009    944774    2    1    41     145      50     79          0.6
#
#    visual_right    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 5           1.5    ...       10    1.0      1.0            1            NaN
# 6           0.1    ...       13    1.0      1.0            0            NaN
# 7           1.5    ...       12    1.0      0.0            1            1.0
# 8           1.5    ...        7    1.0      0.0            1            1.0
# 9           0.6    ...       10    1.0      0.0            1            1.0
#
#    missing_tooth  tooth_abrasion  third_molar  scale  data_year
# ...

# %%
GJ_2010 = pd.read_csv('NHIS_OPEN_GJ_2010.CSV')
GJ_2010 = GJ_2010[GJ_2010['age'] < 13]
GJ_2010 = GJ_2010[GJ_2010['height'] <= 180]
GJ_2010 = GJ_2010[GJ_2010['height'] >= 145]
GJ_2010 = GJ_2010[GJ_2010['weight'] <= 90]
GJ_2010 = GJ_2010[GJ_2010['weight'] >= 45]
GJ_2010.head()
# Out:
#     year  identity  sex  age  city  height  weight  waist  visual_left  \
# 17  2010    267175    2    1    44     145      45     68          1.5
# 18  2010     76146    2    1    28     145      45     60          1.0
# 19  2010     95998    2    1    41     145      45     66          0.8
# 39  2010    211499    2    1    41     150      45     73          0.2
# 40  2010    767814    2    1    47     150      45     58          1.0
#
#     visual_right    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 17           1.5    ...       21    1.0      0.0            1            NaN
# 18           1.5    ...        9    1.0      1.0            1            NaN
# 19           0.9    ...       22    1.0      1.0            1            NaN
# 39           0.4    ...        9    1.0      0.0            0            NaN
# 40           1.5    ...       12    1.0      0.0            1            NaN
#
#     missing_tooth  tooth_abrasion  third_molar  scale  data_year
# ...

# %%
GJ_2011 = pd.read_csv('NHIS_OPEN_GJ_2011.CSV')
GJ_2011 = GJ_2011[GJ_2011['age'] < 13]
GJ_2011 = GJ_2011[GJ_2011['height'] <= 180]
GJ_2011 = GJ_2011[GJ_2011['height'] >= 145]
GJ_2011 = GJ_2011[GJ_2011['weight'] <= 90]
GJ_2011 = GJ_2011[GJ_2011['weight'] >= 45]
GJ_2011.head()
# Out:
#     year  identity  sex  age  city  height  weight  waist  visual_left  \
# 1   2011     56745    2    1    26     145      45     68          0.9
# 2   2011    171067    2    1    26     145      45     65          1.0
# 3   2011    196496    2    1    27     145      45     68          0.9
# 34  2011    273008    2    1    26     150      45     69          0.9
# 35  2011    603760    2    1    42     150      45     64          0.7
#
#     visual_right    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 1            1.0    ...       12    1.0      0.0            0            NaN
# 2            1.5    ...       16    1.0      0.0            0            NaN
# 3            0.9    ...       23    1.0      0.0            1            NaN
# 34           1.0    ...        6    1.0      0.0            0            NaN
# 35           0.8    ...        7    1.0      0.0            1            NaN
#
#     missing_tooth  tooth_abrasion  third_molar  scale  data_year
# ...

# %%
GJ_2012 = pd.read_csv('NHIS_OPEN_GJ_2012.CSV')
GJ_2012 = GJ_2012[GJ_2012['age'] < 13]
GJ_2012 = GJ_2012[GJ_2012['height'] <= 180]
GJ_2012 = GJ_2012[GJ_2012['height'] >= 145]
GJ_2012 = GJ_2012[GJ_2012['weight'] <= 90]
GJ_2012 = GJ_2012[GJ_2012['weight'] >= 45]
GJ_2012.head()
# Out:
#     year  identity  sex  age  city  height  weight  waist  visual_left  \
# 14  2012    923646    1    1    28     145      45     66          0.9
# 15  2012    301712    2    1    44     145      45     69          0.9
# 16  2012    996872    2    1    43     145      45     72          1.2
# 17  2012     84122    2    1    46     145      45     64          1.2
# 38  2012     21159    2    1    11     150      45     65          0.6
#
#     visual_right    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 14           0.8    ...       33    1.0      0.0            1            0.0
# 15           1.2    ...       10    1.0      0.0            1            0.0
# 16           1.2    ...       19    1.0      0.0            1            1.0
# 17           1.2    ...       12    1.0      1.0            0            NaN
# 38           1.2    ...       13    1.0      0.0            1            0.0
#
#     missing_tooth  tooth_abrasion  third_molar  scale  data_year
# ...

# %% [markdown]
# ## Blood Press EDA with alcohol and age

# %%
#2009
bp_2009 = GJ_2009[['alcohol','age','b_press_contract','b_press_relax']]
bp_2009_0=bp_2009[bp_2009.alcohol==0]
bp_2009_1=bp_2009[bp_2009.alcohol==1]
bp_2009_mean_0 = bp_2009_0.groupby('age').mean()
bp_2009_mean_1 = bp_2009_1.groupby('age').mean()
bp_2009_mean_0 = bp_2009_mean_0.rename(columns={'b_press_contract': 'No_alcohol_contract', 'b_press_relax': 'No_alcohol_relax'})
bp_2009_mean_1 = bp_2009_mean_1.rename(columns={'b_press_contract': 'Alcohol_contract', 'b_press_relax': 'Alcohol_relax'})
bp_2009_mean_0 = bp_2009_mean_0.drop('alcohol', axis = 1)
bp_2009_mean_1 = bp_2009_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2009_smoke = pd.concat([bp_2009_mean_0, bp_2009_mean_1], axis=1, join='inner')
c_bp_mean_2009_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['alcohol','age','b_press_contract','b_press_relax']]
bp_2010_0=bp_2010[bp_2010.alcohol==0]
bp_2010_1=bp_2010[bp_2010.alcohol==1]
bp_2010_mean_0 = bp_2010_0.groupby('age').mean()
bp_2010_mean_1 = bp_2010_1.groupby('age').mean()
bp_2010_mean_0 = bp_2010_mean_0.rename(columns={'b_press_contract': 'No_alcohol_contract', 'b_press_relax': 'No_alcohol_relax'})
bp_2010_mean_1 = bp_2010_mean_1.rename(columns={'b_press_contract': 'Alcohol_contract', 'b_press_relax': 'Alcohol_relax'})
bp_2010_mean_0 = bp_2010_mean_0.drop('alcohol', axis = 1)
bp_2010_mean_1 = bp_2010_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2010_smoke = pd.concat([bp_2010_mean_0, bp_2010_mean_1], axis=1, join='inner')
c_bp_mean_2010_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011 = GJ_2011[['alcohol','age','b_press_contract','b_press_relax']]
bp_2011_0=bp_2011[bp_2011.alcohol==0]
bp_2011_1=bp_2011[bp_2011.alcohol==1]
bp_2011_mean_0 = bp_2011_0.groupby('age').mean()
bp_2011_mean_1 = bp_2011_1.groupby('age').mean()
bp_2011_mean_0 = bp_2011_mean_0.rename(columns={'b_press_contract': 'No_alcohol_contract', 'b_press_relax': 'No_alcohol_relax'})
bp_2011_mean_1 = bp_2011_mean_1.rename(columns={'b_press_contract': 'Alcohol_contract', 'b_press_relax': 'Alcohol_relax'})
bp_2011_mean_0 = bp_2011_mean_0.drop('alcohol', axis = 1)
bp_2011_mean_1 = bp_2011_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2011_smoke = pd.concat([bp_2011_mean_0, bp_2011_mean_1], axis=1, join='inner')
c_bp_mean_2011_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['alcohol','age','b_press_contract','b_press_relax']]
bp_2012_0=bp_2012[bp_2012.alcohol==0]
bp_2012_1=bp_2012[bp_2012.alcohol==1]
bp_2012_mean_0 = bp_2012_0.groupby('age').mean()
bp_2012_mean_1 = bp_2012_1.groupby('age').mean()
bp_2012_mean_0 = bp_2012_mean_0.rename(columns={'b_press_contract': 'No_alcohol_contract', 'b_press_relax': 'No_alcohol_relax'})
bp_2012_mean_1 = bp_2012_mean_1.rename(columns={'b_press_contract': 'Alcohol_contract', 'b_press_relax': 'Alcohol_relax'})
bp_2012_mean_0 = bp_2012_mean_0.drop('alcohol', axis = 1)
bp_2012_mean_1 = bp_2012_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2012_smoke = pd.concat([bp_2012_mean_0, bp_2012_mean_1], axis=1, join='inner')
c_bp_mean_2012_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Blood Press EDA with alcohol and weight

# %%
#2009
bp_2009 = GJ_2009[['alcohol','weight','b_press_contract','b_press_relax']]
bp_2009_0=bp_2009[bp_2009.alcohol==0]
bp_2009_1=bp_2009[bp_2009.alcohol==1]
bp_2009_mean_0 = bp_2009_0.groupby('weight').mean()
bp_2009_mean_1 = bp_2009_1.groupby('weight').mean()
bp_2009_mean_0 = bp_2009_mean_0.rename(columns={'b_press_contract': 'No_alcohol_contract', 'b_press_relax': 'No_alcohol_relax'})
bp_2009_mean_1 = bp_2009_mean_1.rename(columns={'b_press_contract': 'Alcohol_contract', 'b_press_relax': 'Alcohol_relax'})
bp_2009_mean_0 = bp_2009_mean_0.drop('alcohol', axis = 1)
bp_2009_mean_1 = bp_2009_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2009_smoke = pd.concat([bp_2009_mean_0, bp_2009_mean_1], axis=1, join='inner')
c_bp_mean_2009_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['alcohol','weight','b_press_contract','b_press_relax']]
bp_2010_0=bp_2010[bp_2010.alcohol==0]
bp_2010_1=bp_2010[bp_2010.alcohol==1]
bp_2010_mean_0 = bp_2010_0.groupby('weight').mean()
bp_2010_mean_1 = bp_2010_1.groupby('weight').mean()
bp_2010_mean_0 = bp_2010_mean_0.rename(columns={'b_press_contract': 'No_alcohol_contract', 'b_press_relax': 'No_alcohol_relax'})
bp_2010_mean_1 = bp_2010_mean_1.rename(columns={'b_press_contract': 'Alcohol_contract', 'b_press_relax': 'Alcohol_relax'})
bp_2010_mean_0 = bp_2010_mean_0.drop('alcohol', axis = 1)
bp_2010_mean_1 = bp_2010_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2010_smoke = pd.concat([bp_2010_mean_0, bp_2010_mean_1], axis=1, join='inner')
c_bp_mean_2010_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011 = GJ_2011[['alcohol','weight','b_press_contract','b_press_relax']]
bp_2011_0=bp_2011[bp_2011.alcohol==0]
bp_2011_1=bp_2011[bp_2011.alcohol==1]
bp_2011_mean_0 = bp_2011_0.groupby('weight').mean()
bp_2011_mean_1 = bp_2011_1.groupby('weight').mean()
bp_2011_mean_0 = bp_2011_mean_0.rename(columns={'b_press_contract': 'No_alcohol_contract', 'b_press_relax': 'No_alcohol_relax'})
bp_2011_mean_1 = bp_2011_mean_1.rename(columns={'b_press_contract': 'Alcohol_contract', 'b_press_relax': 'Alcohol_relax'})
bp_2011_mean_0 = bp_2011_mean_0.drop('alcohol', axis = 1)
bp_2011_mean_1 = bp_2011_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2011_smoke = pd.concat([bp_2011_mean_0, bp_2011_mean_1], axis=1, join='inner')
c_bp_mean_2011_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['alcohol','weight','b_press_contract','b_press_relax']]
bp_2012_0=bp_2012[bp_2012.alcohol==0]
bp_2012_1=bp_2012[bp_2012.alcohol==1]
bp_2012_mean_0 = bp_2012_0.groupby('weight').mean()
bp_2012_mean_1 = bp_2012_1.groupby('weight').mean()
bp_2012_mean_0 = bp_2012_mean_0.rename(columns={'b_press_contract': 'No_alcohol_contract', 'b_press_relax': 'No_alcohol_relax'})
bp_2012_mean_1 = bp_2012_mean_1.rename(columns={'b_press_contract': 'Alcohol_contract', 'b_press_relax': 'Alcohol_relax'})
bp_2012_mean_0 = bp_2012_mean_0.drop('alcohol', axis = 1)
bp_2012_mean_1 = bp_2012_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2012_smoke = pd.concat([bp_2012_mean_0, bp_2012_mean_1], axis=1, join='inner')
c_bp_mean_2012_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Blood Press EDA with alcohol and height

# %%
#2009
bp_2009 = GJ_2009[['alcohol','height','b_press_contract','b_press_relax']]
bp_2009_0=bp_2009[bp_2009.alcohol==0]
bp_2009_1=bp_2009[bp_2009.alcohol==1]
bp_2009_mean_0 = bp_2009_0.groupby('height').mean()
bp_2009_mean_1 = bp_2009_1.groupby('height').mean()
bp_2009_mean_0 = bp_2009_mean_0.rename(columns={'b_press_contract': 'No_alcohol_contract', 'b_press_relax': 'No_alcohol_relax'})
bp_2009_mean_1 = bp_2009_mean_1.rename(columns={'b_press_contract': 'Alcohol_contract', 'b_press_relax': 'Alcohol_relax'})
bp_2009_mean_0 = bp_2009_mean_0.drop('alcohol', axis = 1)
bp_2009_mean_1 = bp_2009_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2009_smoke = pd.concat([bp_2009_mean_0, bp_2009_mean_1], axis=1, join='inner')
c_bp_mean_2009_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['alcohol','height','b_press_contract','b_press_relax']]
bp_2010_0=bp_2010[bp_2010.alcohol==0]
bp_2010_1=bp_2010[bp_2010.alcohol==1]
bp_2010_mean_0 = bp_2010_0.groupby('height').mean()
bp_2010_mean_1 = bp_2010_1.groupby('height').mean()
bp_2010_mean_0 = bp_2010_mean_0.rename(columns={'b_press_contract': 'No_alcohol_contract', 'b_press_relax': 'No_alcohol_relax'})
bp_2010_mean_1 = bp_2010_mean_1.rename(columns={'b_press_contract': 'Alcohol_contract', 'b_press_relax': 'Alcohol_relax'})
bp_2010_mean_0 = bp_2010_mean_0.drop('alcohol', axis = 1)
bp_2010_mean_1 = bp_2010_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2010_smoke = pd.concat([bp_2010_mean_0, bp_2010_mean_1], axis=1, join='inner')
c_bp_mean_2010_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011 = GJ_2011[['alcohol','height','b_press_contract','b_press_relax']]
bp_2011_0=bp_2011[bp_2011.alcohol==0]
bp_2011_1=bp_2011[bp_2011.alcohol==1]
bp_2011_mean_0 = bp_2011_0.groupby('height').mean()
bp_2011_mean_1 = bp_2011_1.groupby('height').mean()
bp_2011_mean_0 = bp_2011_mean_0.rename(columns={'b_press_contract': 'No_alcohol_contract', 'b_press_relax': 'No_alcohol_relax'})
bp_2011_mean_1 = bp_2011_mean_1.rename(columns={'b_press_contract': 'Alcohol_contract', 'b_press_relax': 'Alcohol_relax'})
bp_2011_mean_0 = bp_2011_mean_0.drop('alcohol', axis = 1)
bp_2011_mean_1 = bp_2011_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2011_smoke = pd.concat([bp_2011_mean_0, bp_2011_mean_1], axis=1, join='inner')
c_bp_mean_2011_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['alcohol','height','b_press_contract','b_press_relax']]
bp_2012_0=bp_2012[bp_2012.alcohol==0]
bp_2012_1=bp_2012[bp_2012.alcohol==1]
bp_2012_mean_0 = bp_2012_0.groupby('height').mean()
bp_2012_mean_1 = bp_2012_1.groupby('height').mean()
bp_2012_mean_0 = bp_2012_mean_0.rename(columns={'b_press_contract': 'No_alcohol_contract', 'b_press_relax': 'No_alcohol_relax'})
bp_2012_mean_1 = bp_2012_mean_1.rename(columns={'b_press_contract': 'Alcohol_contract', 'b_press_relax': 'Alcohol_relax'})
bp_2012_mean_0 = bp_2012_mean_0.drop('alcohol', axis = 1)
bp_2012_mean_1 = bp_2012_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2012_smoke = pd.concat([bp_2012_mean_0, bp_2012_mean_1], axis=1, join='inner')
c_bp_mean_2012_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Visual EDA with alcohol and age

# %%
#2009
bp_2009 = GJ_2009[['alcohol','age','visual_left','visual_right']]
bp_2009_0=bp_2009[bp_2009.alcohol==0]
bp_2009_1=bp_2009[bp_2009.alcohol==1]
bp_2009_mean_0 = bp_2009_0.groupby('age').mean()
bp_2009_mean_1 = bp_2009_1.groupby('age').mean()
bp_2009_mean_0 = bp_2009_mean_0.rename(columns={'visual_left': 'No_alcohol_visual_left', 'visual_right': 'No_alcohol_visual_right'})
bp_2009_mean_1 = bp_2009_mean_1.rename(columns={'visual_left': 'Alcohol_visual_left', 'visual_right': 'Alcohol_visual_right'})
bp_2009_mean_0 = bp_2009_mean_0.drop('alcohol', axis = 1)
bp_2009_mean_1 = bp_2009_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2009_smoke = pd.concat([bp_2009_mean_0, bp_2009_mean_1], axis=1, join='inner')
c_bp_mean_2009_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['alcohol','age','visual_left','visual_right']]
bp_2010_0=bp_2010[bp_2010.alcohol==0]
bp_2010_1=bp_2010[bp_2010.alcohol==1]
bp_2010_mean_0 = bp_2010_0.groupby('age').mean()
bp_2010_mean_1 = bp_2010_1.groupby('age').mean()
bp_2010_mean_0 = bp_2010_mean_0.rename(columns={'visual_left': 'No_alcohol_visual_left', 'visual_right': 'No_alcohol_visual_right'})
bp_2010_mean_1 = bp_2010_mean_1.rename(columns={'visual_left': 'Alcohol_visual_left', 'visual_right': 'Alcohol_visual_right'})
bp_2010_mean_0 = bp_2010_mean_0.drop('alcohol', axis = 1)
bp_2010_mean_1 = bp_2010_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2010_smoke = pd.concat([bp_2010_mean_0, bp_2010_mean_1], axis=1, join='inner')
c_bp_mean_2010_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011 = GJ_2011[['alcohol','age','visual_left','visual_right']]
bp_2011_0=bp_2011[bp_2011.alcohol==0]
bp_2011_1=bp_2011[bp_2011.alcohol==1]
bp_2011_mean_0 = bp_2011_0.groupby('age').mean()
bp_2011_mean_1 = bp_2011_1.groupby('age').mean()
bp_2011_mean_0 = bp_2011_mean_0.rename(columns={'visual_left': 'No_alcohol_visual_left', 'visual_right': 'No_alcohol_visual_right'})
bp_2011_mean_1 = bp_2011_mean_1.rename(columns={'visual_left': 'Alcohol_visual_left', 'visual_right': 'Alcohol_visual_right'})
bp_2011_mean_0 = bp_2011_mean_0.drop('alcohol', axis = 1)
bp_2011_mean_1 = bp_2011_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2011_smoke = pd.concat([bp_2011_mean_0, bp_2011_mean_1], axis=1, join='inner')
c_bp_mean_2011_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['alcohol','age','visual_left','visual_right']]
bp_2012_0=bp_2012[bp_2012.alcohol==0]
bp_2012_1=bp_2012[bp_2012.alcohol==1]
bp_2012_mean_0 = bp_2012_0.groupby('age').mean()
bp_2012_mean_1 = bp_2012_1.groupby('age').mean()
bp_2012_mean_0 = bp_2012_mean_0.rename(columns={'visual_left': 'No_alcohol_visual_left', 'visual_right': 'No_alcohol_visual_right'})
bp_2012_mean_1 = bp_2012_mean_1.rename(columns={'visual_left': 'Alcohol_visual_left', 'visual_right': 'Alcohol_visual_right'})
bp_2012_mean_0 = bp_2012_mean_0.drop('alcohol', axis = 1)
bp_2012_mean_1 = bp_2012_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2012_smoke = pd.concat([bp_2012_mean_0, bp_2012_mean_1], axis=1, join='inner')
c_bp_mean_2012_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Visual EDA with alcohol and weight

# %%
#2009
bp_2009 = GJ_2009[['alcohol','weight','visual_left','visual_right']]
bp_2009_0=bp_2009[bp_2009.alcohol==0]
bp_2009_1=bp_2009[bp_2009.alcohol==1]
bp_2009_mean_0 = bp_2009_0.groupby('weight').mean()
bp_2009_mean_1 = bp_2009_1.groupby('weight').mean()
bp_2009_mean_0 = bp_2009_mean_0.rename(columns={'visual_left': 'No_alcohol_visual_left', 'visual_right': 'No_alcohol_visual_right'})
bp_2009_mean_1 = bp_2009_mean_1.rename(columns={'visual_left': 'Alcohol_visual_left', 'visual_right': 'Alcohol_visual_right'})
bp_2009_mean_0 = bp_2009_mean_0.drop('alcohol', axis = 1)
bp_2009_mean_1 = bp_2009_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2009_smoke = pd.concat([bp_2009_mean_0, bp_2009_mean_1], axis=1, join='inner')
c_bp_mean_2009_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['alcohol','weight','visual_left','visual_right']]
bp_2010_0=bp_2010[bp_2010.alcohol==0]
bp_2010_1=bp_2010[bp_2010.alcohol==1]
bp_2010_mean_0 = bp_2010_0.groupby('weight').mean()
bp_2010_mean_1 = bp_2010_1.groupby('weight').mean()
bp_2010_mean_0 = bp_2010_mean_0.rename(columns={'visual_left': 'No_alcohol_visual_left', 'visual_right': 'No_alcohol_visual_right'})
bp_2010_mean_1 = bp_2010_mean_1.rename(columns={'visual_left': 'Alcohol_visual_left', 'visual_right': 'Alcohol_visual_right'})
bp_2010_mean_0 = bp_2010_mean_0.drop('alcohol', axis = 1)
bp_2010_mean_1 = bp_2010_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2010_smoke = pd.concat([bp_2010_mean_0, bp_2010_mean_1], axis=1, join='inner')
c_bp_mean_2010_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011 = GJ_2011[['alcohol','weight','visual_left','visual_right']]
bp_2011_0=bp_2011[bp_2011.alcohol==0]
bp_2011_1=bp_2011[bp_2011.alcohol==1]
bp_2011_mean_0 = bp_2011_0.groupby('weight').mean()
bp_2011_mean_1 = bp_2011_1.groupby('weight').mean()
bp_2011_mean_0 = bp_2011_mean_0.rename(columns={'visual_left': 'No_alcohol_visual_left', 'visual_right': 'No_alcohol_visual_right'})
bp_2011_mean_1 = bp_2011_mean_1.rename(columns={'visual_left': 'Alcohol_visual_left', 'visual_right': 'Alcohol_visual_right'})
bp_2011_mean_0 = bp_2011_mean_0.drop('alcohol', axis = 1)
bp_2011_mean_1 = bp_2011_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2011_smoke = pd.concat([bp_2011_mean_0, bp_2011_mean_1], axis=1, join='inner')
c_bp_mean_2011_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['alcohol','weight','visual_left','visual_right']]
bp_2012_0=bp_2012[bp_2012.alcohol==0]
bp_2012_1=bp_2012[bp_2012.alcohol==1]
bp_2012_mean_0 = bp_2012_0.groupby('weight').mean()
bp_2012_mean_1 = bp_2012_1.groupby('weight').mean()
bp_2012_mean_0 = bp_2012_mean_0.rename(columns={'visual_left': 'No_alcohol_visual_left', 'visual_right': 'No_alcohol_visual_right'})
bp_2012_mean_1 = bp_2012_mean_1.rename(columns={'visual_left': 'Alcohol_visual_left', 'visual_right': 'Alcohol_visual_right'})
bp_2012_mean_0 = bp_2012_mean_0.drop('alcohol', axis = 1)
bp_2012_mean_1 = bp_2012_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2012_smoke = pd.concat([bp_2012_mean_0, bp_2012_mean_1], axis=1, join='inner')
c_bp_mean_2012_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Visual Press EDA with alcohol and height

# %%
#2009
bp_2009 = GJ_2009[['alcohol','height','visual_left','visual_right']]
bp_2009_0=bp_2009[bp_2009.alcohol==0]
bp_2009_1=bp_2009[bp_2009.alcohol==1]
bp_2009_mean_0 = bp_2009_0.groupby('height').mean()
bp_2009_mean_1 = bp_2009_1.groupby('height').mean()
bp_2009_mean_0 = bp_2009_mean_0.rename(columns={'visual_left': 'No_alcohol_visual_left', 'visual_right': 'No_alcohol_visual_right'})
bp_2009_mean_1 = bp_2009_mean_1.rename(columns={'visual_left': 'Alcohol_visual_left', 'visual_right': 'Alcohol_visual_right'})
bp_2009_mean_0 = bp_2009_mean_0.drop('alcohol', axis = 1)
bp_2009_mean_1 = bp_2009_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2009_smoke = pd.concat([bp_2009_mean_0, bp_2009_mean_1], axis=1, join='inner')
c_bp_mean_2009_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['alcohol','height','visual_left','visual_right']]
bp_2010_0=bp_2010[bp_2010.alcohol==0]
bp_2010_1=bp_2010[bp_2010.alcohol==1]
bp_2010_mean_0 = bp_2010_0.groupby('height').mean()
bp_2010_mean_1 = bp_2010_1.groupby('height').mean()
bp_2010_mean_0 = bp_2010_mean_0.rename(columns={'visual_left': 'No_alcohol_visual_left', 'visual_right': 'No_alcohol_visual_right'})
bp_2010_mean_1 = bp_2010_mean_1.rename(columns={'visual_left': 'Alcohol_visual_left', 'visual_right': 'Alcohol_visual_right'})
bp_2010_mean_0 = bp_2010_mean_0.drop('alcohol', axis = 1)
bp_2010_mean_1 = bp_2010_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2010_smoke = pd.concat([bp_2010_mean_0, bp_2010_mean_1], axis=1, join='inner')
c_bp_mean_2010_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011 = GJ_2011[['alcohol','height','visual_left','visual_right']]
bp_2011_0=bp_2011[bp_2011.alcohol==0]
bp_2011_1=bp_2011[bp_2011.alcohol==1]
bp_2011_mean_0 = bp_2011_0.groupby('height').mean()
bp_2011_mean_1 = bp_2011_1.groupby('height').mean()
bp_2011_mean_0 = bp_2011_mean_0.rename(columns={'visual_left': 'No_alcohol_visual_left', 'visual_right': 'No_alcohol_visual_right'})
bp_2011_mean_1 = bp_2011_mean_1.rename(columns={'visual_left': 'Alcohol_visual_left', 'visual_right': 'Alcohol_visual_right'})
bp_2011_mean_0 = bp_2011_mean_0.drop('alcohol', axis = 1)
bp_2011_mean_1 = bp_2011_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2011_smoke = pd.concat([bp_2011_mean_0, bp_2011_mean_1], axis=1, join='inner')
c_bp_mean_2011_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['alcohol','height','visual_left','visual_right']]
bp_2012_0=bp_2012[bp_2012.alcohol==0]
bp_2012_1=bp_2012[bp_2012.alcohol==1]
bp_2012_mean_0 = bp_2012_0.groupby('height').mean()
bp_2012_mean_1 = bp_2012_1.groupby('height').mean()
bp_2012_mean_0 = bp_2012_mean_0.rename(columns={'visual_left': 'No_alcohol_visual_left', 'visual_right': 'No_alcohol_visual_right'})
bp_2012_mean_1 = bp_2012_mean_1.rename(columns={'visual_left': 'Alcohol_visual_left', 'visual_right': 'Alcohol_visual_right'})
bp_2012_mean_0 = bp_2012_mean_0.drop('alcohol', axis = 1)
bp_2012_mean_1 = bp_2012_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2012_smoke = pd.concat([bp_2012_mean_0, bp_2012_mean_1], axis=1, join='inner')
c_bp_mean_2012_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Blood sugar EDA with alcohol and age

# %%
#2009
bp_2009 = GJ_2009[['alcohol','age','b_sugar']]
bp_2009_0=bp_2009[bp_2009.alcohol==0]
bp_2009_1=bp_2009[bp_2009.alcohol==1]
bp_2009_mean_0 = bp_2009_0.groupby('age').mean()
bp_2009_mean_1 = bp_2009_1.groupby('age').mean()
bp_2009_mean_0 = bp_2009_mean_0.rename(columns={'b_sugar': 'No_alcohol_b_sugar'})
bp_2009_mean_1 = bp_2009_mean_1.rename(columns={'b_sugar': 'Alcohol_b_sugar'})
bp_2009_mean_0 = bp_2009_mean_0.drop('alcohol', axis = 1)
bp_2009_mean_1 = bp_2009_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2009_smoke = pd.concat([bp_2009_mean_0, bp_2009_mean_1], axis=1, join='inner')
c_bp_mean_2009_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['alcohol','age','b_sugar']]
bp_2010_0=bp_2010[bp_2010.alcohol==0]
bp_2010_1=bp_2010[bp_2010.alcohol==1]
bp_2010_mean_0 = bp_2010_0.groupby('age').mean()
bp_2010_mean_1 = bp_2010_1.groupby('age').mean()
bp_2010_mean_0 = bp_2010_mean_0.rename(columns={'b_sugar': 'No_alcohol_b_sugar'})
bp_2010_mean_1 = bp_2010_mean_1.rename(columns={'b_sugar': 'Alcohol_b_sugar'})
bp_2010_mean_0 = bp_2010_mean_0.drop('alcohol', axis = 1)
bp_2010_mean_1 = bp_2010_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2010_smoke = pd.concat([bp_2010_mean_0, bp_2010_mean_1], axis=1, join='inner')
c_bp_mean_2010_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011 = GJ_2011[['alcohol','age','b_sugar']]
bp_2011_0=bp_2011[bp_2011.alcohol==0]
bp_2011_1=bp_2011[bp_2011.alcohol==1]
bp_2011_mean_0 = bp_2011_0.groupby('age').mean()
bp_2011_mean_1 = bp_2011_1.groupby('age').mean()
bp_2011_mean_0 = bp_2011_mean_0.rename(columns={'b_sugar': 'No_alcohol_b_sugar'})
bp_2011_mean_1 = bp_2011_mean_1.rename(columns={'b_sugar': 'Alcohol_b_sugar'})
bp_2011_mean_0 = bp_2011_mean_0.drop('alcohol', axis = 1)
bp_2011_mean_1 = bp_2011_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2011_smoke = pd.concat([bp_2011_mean_0, bp_2011_mean_1], axis=1, join='inner')
c_bp_mean_2011_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['alcohol','age','b_sugar']]
bp_2012_0=bp_2012[bp_2012.alcohol==0]
bp_2012_1=bp_2012[bp_2012.alcohol==1]
bp_2012_mean_0 = bp_2012_0.groupby('age').mean()
bp_2012_mean_1 = bp_2012_1.groupby('age').mean()
bp_2012_mean_0 = bp_2012_mean_0.rename(columns={'b_sugar': 'No_alcohol_b_sugar'})
bp_2012_mean_1 = bp_2012_mean_1.rename(columns={'b_sugar': 'Alcohol_b_sugar'})
bp_2012_mean_0 = bp_2012_mean_0.drop('alcohol', axis = 1)
bp_2012_mean_1 = bp_2012_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2012_smoke = pd.concat([bp_2012_mean_0, bp_2012_mean_1], axis=1, join='inner')
c_bp_mean_2012_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Blood sugar EDA with alcohol and weight

# %%
#2009
bp_2009 = GJ_2009[['alcohol','weight','b_sugar']]
bp_2009_0=bp_2009[bp_2009.alcohol==0]
bp_2009_1=bp_2009[bp_2009.alcohol==1]
bp_2009_mean_0 = bp_2009_0.groupby('weight').mean()
bp_2009_mean_1 = bp_2009_1.groupby('weight').mean()
bp_2009_mean_0 = bp_2009_mean_0.rename(columns={'b_sugar': 'No_alcohol_b_sugar'})
bp_2009_mean_1 = bp_2009_mean_1.rename(columns={'b_sugar': 'Alcohol_b_sugar'})
bp_2009_mean_0 = bp_2009_mean_0.drop('alcohol', axis = 1)
bp_2009_mean_1 = bp_2009_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2009_smoke = pd.concat([bp_2009_mean_0, bp_2009_mean_1], axis=1, join='inner')
c_bp_mean_2009_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['alcohol','weight','b_sugar']]
bp_2010_0=bp_2010[bp_2010.alcohol==0]
bp_2010_1=bp_2010[bp_2010.alcohol==1]
bp_2010_mean_0 = bp_2010_0.groupby('weight').mean()
bp_2010_mean_1 = bp_2010_1.groupby('weight').mean()
bp_2010_mean_0 = bp_2010_mean_0.rename(columns={'b_sugar': 'No_alcohol_b_sugar'})
bp_2010_mean_1 = bp_2010_mean_1.rename(columns={'b_sugar': 'Alcohol_b_sugar'})
bp_2010_mean_0 = bp_2010_mean_0.drop('alcohol', axis = 1)
bp_2010_mean_1 = bp_2010_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2010_smoke = pd.concat([bp_2010_mean_0, bp_2010_mean_1], axis=1, join='inner')
c_bp_mean_2010_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011 = GJ_2011[['alcohol','weight','b_sugar']]
bp_2011_0=bp_2011[bp_2011.alcohol==0]
bp_2011_1=bp_2011[bp_2011.alcohol==1]
bp_2011_mean_0 = bp_2011_0.groupby('weight').mean()
bp_2011_mean_1 = bp_2011_1.groupby('weight').mean()
bp_2011_mean_0 = bp_2011_mean_0.rename(columns={'b_sugar': 'No_alcohol_b_sugar'})
bp_2011_mean_1 = bp_2011_mean_1.rename(columns={'b_sugar': 'Alcohol_b_sugar'})
bp_2011_mean_0 = bp_2011_mean_0.drop('alcohol', axis = 1)
bp_2011_mean_1 = bp_2011_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2011_smoke = pd.concat([bp_2011_mean_0, bp_2011_mean_1], axis=1, join='inner')
c_bp_mean_2011_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['alcohol','weight','b_sugar']]
bp_2012_0=bp_2012[bp_2012.alcohol==0]
bp_2012_1=bp_2012[bp_2012.alcohol==1]
bp_2012_mean_0 = bp_2012_0.groupby('weight').mean()
bp_2012_mean_1 = bp_2012_1.groupby('weight').mean()
bp_2012_mean_0 = bp_2012_mean_0.rename(columns={'b_sugar': 'No_alcohol_b_sugar'})
bp_2012_mean_1 = bp_2012_mean_1.rename(columns={'b_sugar': 'Alcohol_b_sugar'})
bp_2012_mean_0 = bp_2012_mean_0.drop('alcohol', axis = 1)
bp_2012_mean_1 = bp_2012_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2012_smoke = pd.concat([bp_2012_mean_0, bp_2012_mean_1], axis=1, join='inner')
c_bp_mean_2012_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Blood sugar EDA with alcohol and height

# %%
#2009
bp_2009 = GJ_2009[['alcohol','height','b_sugar']]
bp_2009_0=bp_2009[bp_2009.alcohol==0]
bp_2009_1=bp_2009[bp_2009.alcohol==1]
bp_2009_mean_0 = bp_2009_0.groupby('height').mean()
bp_2009_mean_1 = bp_2009_1.groupby('height').mean()
bp_2009_mean_0 = bp_2009_mean_0.rename(columns={'b_sugar': 'No_alcohol_b_sugar'})
bp_2009_mean_1 = bp_2009_mean_1.rename(columns={'b_sugar': 'Alcohol_b_sugar'})
bp_2009_mean_0 = bp_2009_mean_0.drop('alcohol', axis = 1)
bp_2009_mean_1 = bp_2009_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2009_smoke = pd.concat([bp_2009_mean_0, bp_2009_mean_1], axis=1, join='inner')
c_bp_mean_2009_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['alcohol','height','b_sugar']]
bp_2010_0=bp_2010[bp_2010.alcohol==0]
bp_2010_1=bp_2010[bp_2010.alcohol==1]
bp_2010_mean_0 = bp_2010_0.groupby('height').mean()
bp_2010_mean_1 = bp_2010_1.groupby('height').mean()
bp_2010_mean_0 = bp_2010_mean_0.rename(columns={'b_sugar': 'No_alcohol_b_sugar'})
bp_2010_mean_1 = bp_2010_mean_1.rename(columns={'b_sugar': 'Alcohol_b_sugar'})
bp_2010_mean_0 = bp_2010_mean_0.drop('alcohol', axis = 1)
bp_2010_mean_1 = bp_2010_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2010_smoke = pd.concat([bp_2010_mean_0, bp_2010_mean_1], axis=1, join='inner')
c_bp_mean_2010_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011 = GJ_2011[['alcohol','height','b_sugar']]
bp_2011_0=bp_2011[bp_2011.alcohol==0]
bp_2011_1=bp_2011[bp_2011.alcohol==1]
bp_2011_mean_0 = bp_2011_0.groupby('height').mean()
bp_2011_mean_1 = bp_2011_1.groupby('height').mean()
bp_2011_mean_0 = bp_2011_mean_0.rename(columns={'b_sugar': 'No_alcohol_b_sugar'})
bp_2011_mean_1 = bp_2011_mean_1.rename(columns={'b_sugar': 'Alcohol_b_sugar'})
bp_2011_mean_0 = bp_2011_mean_0.drop('alcohol', axis = 1)
bp_2011_mean_1 = bp_2011_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2011_smoke = pd.concat([bp_2011_mean_0, bp_2011_mean_1], axis=1, join='inner')
c_bp_mean_2011_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['alcohol','height','b_sugar']]
bp_2012_0=bp_2012[bp_2012.alcohol==0]
bp_2012_1=bp_2012[bp_2012.alcohol==1]
bp_2012_mean_0 = bp_2012_0.groupby('height').mean()
bp_2012_mean_1 = bp_2012_1.groupby('height').mean()
bp_2012_mean_0 = bp_2012_mean_0.rename(columns={'b_sugar': 'No_alcohol_b_sugar'})
bp_2012_mean_1 = bp_2012_mean_1.rename(columns={'b_sugar': 'Alcohol_b_sugar'})
bp_2012_mean_0 = bp_2012_mean_0.drop('alcohol', axis = 1)
bp_2012_mean_1 = bp_2012_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2012_smoke = pd.concat([bp_2012_mean_0, bp_2012_mean_1], axis=1, join='inner')
c_bp_mean_2012_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Cholesterol EDA with alcohol and age

# %%
#2009
bp_2009 = GJ_2009[['alcohol','age','cholesterol']]
bp_2009_0=bp_2009[bp_2009.alcohol==0]
bp_2009_1=bp_2009[bp_2009.alcohol==1]
bp_2009_mean_0 = bp_2009_0.groupby('age').mean()
bp_2009_mean_1 = bp_2009_1.groupby('age').mean()
bp_2009_mean_0 = bp_2009_mean_0.rename(columns={'cholesterol': 'No_alcohol_cholesterol'})
bp_2009_mean_1 = bp_2009_mean_1.rename(columns={'cholesterol': 'Alcohol_cholesterol'})
bp_2009_mean_0 = bp_2009_mean_0.drop('alcohol', axis = 1)
bp_2009_mean_1 = bp_2009_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2009_smoke = pd.concat([bp_2009_mean_0, bp_2009_mean_1], axis=1, join='inner')
c_bp_mean_2009_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['alcohol','age','cholesterol']]
bp_2010_0=bp_2010[bp_2010.alcohol==0]
bp_2010_1=bp_2010[bp_2010.alcohol==1]
bp_2010_mean_0 = bp_2010_0.groupby('age').mean()
bp_2010_mean_1 = bp_2010_1.groupby('age').mean()
bp_2010_mean_0 = bp_2010_mean_0.rename(columns={'cholesterol': 'No_alcohol_cholesterol'})
bp_2010_mean_1 = bp_2010_mean_1.rename(columns={'cholesterol': 'Alcohol_cholesterol'})
bp_2010_mean_0 = bp_2010_mean_0.drop('alcohol', axis = 1)
bp_2010_mean_1 = bp_2010_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2010_smoke = pd.concat([bp_2010_mean_0, bp_2010_mean_1], axis=1, join='inner')
c_bp_mean_2010_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011 = GJ_2011[['alcohol','age','cholesterol']]
bp_2011_0=bp_2011[bp_2011.alcohol==0]
bp_2011_1=bp_2011[bp_2011.alcohol==1]
bp_2011_mean_0 = bp_2011_0.groupby('age').mean()
bp_2011_mean_1 = bp_2011_1.groupby('age').mean()
bp_2011_mean_0 = bp_2011_mean_0.rename(columns={'cholesterol': 'No_alcohol_cholesterol'})
bp_2011_mean_1 = bp_2011_mean_1.rename(columns={'cholesterol': 'Alcohol_cholesterol'})
bp_2011_mean_0 = bp_2011_mean_0.drop('alcohol', axis = 1)
bp_2011_mean_1 = bp_2011_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2011_smoke = pd.concat([bp_2011_mean_0, bp_2011_mean_1], axis=1, join='inner')
c_bp_mean_2011_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['alcohol','age','cholesterol']]
bp_2012_0=bp_2012[bp_2012.alcohol==0]
bp_2012_1=bp_2012[bp_2012.alcohol==1]
bp_2012_mean_0 = bp_2012_0.groupby('age').mean()
bp_2012_mean_1 = bp_2012_1.groupby('age').mean()
bp_2012_mean_0 = bp_2012_mean_0.rename(columns={'cholesterol': 'No_alcohol_cholesterol'})
bp_2012_mean_1 = bp_2012_mean_1.rename(columns={'cholesterol': 'Alcohol_cholesterol'})
bp_2012_mean_0 = bp_2012_mean_0.drop('alcohol', axis = 1)
bp_2012_mean_1 = bp_2012_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2012_smoke = pd.concat([bp_2012_mean_0, bp_2012_mean_1], axis=1, join='inner')
c_bp_mean_2012_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Cholesterol EDA with alcohol and weight

# %%
#2009
bp_2009 = GJ_2009[['alcohol','weight','cholesterol']]
bp_2009_0=bp_2009[bp_2009.alcohol==0]
bp_2009_1=bp_2009[bp_2009.alcohol==1]
bp_2009_mean_0 = bp_2009_0.groupby('weight').mean()
bp_2009_mean_1 = bp_2009_1.groupby('weight').mean()
bp_2009_mean_0 = bp_2009_mean_0.rename(columns={'cholesterol': 'No_alcohol_cholesterol'})
bp_2009_mean_1 = bp_2009_mean_1.rename(columns={'cholesterol': 'Alcohol_cholesterol'})
bp_2009_mean_0 = bp_2009_mean_0.drop('alcohol', axis = 1)
bp_2009_mean_1 = bp_2009_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2009_smoke = pd.concat([bp_2009_mean_0, bp_2009_mean_1], axis=1, join='inner')
c_bp_mean_2009_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['alcohol','weight','cholesterol']]
bp_2010_0=bp_2010[bp_2010.alcohol==0]
bp_2010_1=bp_2010[bp_2010.alcohol==1]
bp_2010_mean_0 = bp_2010_0.groupby('weight').mean()
bp_2010_mean_1 = bp_2010_1.groupby('weight').mean()
bp_2010_mean_0 = bp_2010_mean_0.rename(columns={'cholesterol': 'No_alcohol_cholesterol'})
bp_2010_mean_1 = bp_2010_mean_1.rename(columns={'cholesterol': 'Alcohol_cholesterol'})
bp_2010_mean_0 = bp_2010_mean_0.drop('alcohol', axis = 1)
bp_2010_mean_1 = bp_2010_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2010_smoke = pd.concat([bp_2010_mean_0, bp_2010_mean_1], axis=1, join='inner')
c_bp_mean_2010_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011 = GJ_2011[['alcohol','weight','cholesterol']]
bp_2011_0=bp_2011[bp_2011.alcohol==0]
bp_2011_1=bp_2011[bp_2011.alcohol==1]
bp_2011_mean_0 = bp_2011_0.groupby('weight').mean()
bp_2011_mean_1 = bp_2011_1.groupby('weight').mean()
bp_2011_mean_0 = bp_2011_mean_0.rename(columns={'cholesterol': 'No_alcohol_cholesterol'})
bp_2011_mean_1 = bp_2011_mean_1.rename(columns={'cholesterol': 'Alcohol_cholesterol'})
bp_2011_mean_0 = bp_2011_mean_0.drop('alcohol', axis = 1)
bp_2011_mean_1 = bp_2011_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2011_smoke = pd.concat([bp_2011_mean_0, bp_2011_mean_1], axis=1, join='inner')
c_bp_mean_2011_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['alcohol','weight','cholesterol']]
bp_2012_0=bp_2012[bp_2012.alcohol==0]
bp_2012_1=bp_2012[bp_2012.alcohol==1]
bp_2012_mean_0 = bp_2012_0.groupby('weight').mean()
bp_2012_mean_1 = bp_2012_1.groupby('weight').mean()
bp_2012_mean_0 = bp_2012_mean_0.rename(columns={'cholesterol': 'No_alcohol_cholesterol'})
bp_2012_mean_1 = bp_2012_mean_1.rename(columns={'cholesterol': 'Alcohol_cholesterol'})
bp_2012_mean_0 = bp_2012_mean_0.drop('alcohol', axis = 1)
bp_2012_mean_1 = bp_2012_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2012_smoke = pd.concat([bp_2012_mean_0, bp_2012_mean_1], axis=1, join='inner')
c_bp_mean_2012_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Cholesterol EDA with alcohol and height

# %%
#2009
bp_2009 = GJ_2009[['alcohol','height','cholesterol']]
bp_2009_0=bp_2009[bp_2009.alcohol==0]
bp_2009_1=bp_2009[bp_2009.alcohol==1]
bp_2009_mean_0 = bp_2009_0.groupby('height').mean()
bp_2009_mean_1 = bp_2009_1.groupby('height').mean()
bp_2009_mean_0 = bp_2009_mean_0.rename(columns={'cholesterol': 'No_alcohol_cholesterol'})
bp_2009_mean_1 = bp_2009_mean_1.rename(columns={'cholesterol': 'Alcohol_cholesterol'})
bp_2009_mean_0 = bp_2009_mean_0.drop('alcohol', axis = 1)
bp_2009_mean_1 = bp_2009_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2009_smoke = pd.concat([bp_2009_mean_0, bp_2009_mean_1], axis=1, join='inner')
c_bp_mean_2009_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['alcohol','height','cholesterol']]
bp_2010_0=bp_2010[bp_2010.alcohol==0]
bp_2010_1=bp_2010[bp_2010.alcohol==1]
bp_2010_mean_0 = bp_2010_0.groupby('height').mean()
bp_2010_mean_1 = bp_2010_1.groupby('height').mean()
bp_2010_mean_0 = bp_2010_mean_0.rename(columns={'cholesterol': 'No_alcohol_cholesterol'})
bp_2010_mean_1 = bp_2010_mean_1.rename(columns={'cholesterol': 'Alcohol_cholesterol'})
bp_2010_mean_0 = bp_2010_mean_0.drop('alcohol', axis = 1)
bp_2010_mean_1 = bp_2010_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2010_smoke = pd.concat([bp_2010_mean_0, bp_2010_mean_1], axis=1, join='inner')
c_bp_mean_2010_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011 = GJ_2011[['alcohol','height','cholesterol']]
bp_2011_0=bp_2011[bp_2011.alcohol==0]
bp_2011_1=bp_2011[bp_2011.alcohol==1]
bp_2011_mean_0 = bp_2011_0.groupby('height').mean()
bp_2011_mean_1 = bp_2011_1.groupby('height').mean()
bp_2011_mean_0 = bp_2011_mean_0.rename(columns={'cholesterol': 'No_alcohol_cholesterol'})
bp_2011_mean_1 = bp_2011_mean_1.rename(columns={'cholesterol': 'Alcohol_cholesterol'})
bp_2011_mean_0 = bp_2011_mean_0.drop('alcohol', axis = 1)
bp_2011_mean_1 = bp_2011_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2011_smoke = pd.concat([bp_2011_mean_0, bp_2011_mean_1], axis=1, join='inner')
c_bp_mean_2011_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['alcohol','height','cholesterol']]
bp_2012_0=bp_2012[bp_2012.alcohol==0]
bp_2012_1=bp_2012[bp_2012.alcohol==1]
bp_2012_mean_0 = bp_2012_0.groupby('height').mean()
bp_2012_mean_1 = bp_2012_1.groupby('height').mean()
bp_2012_mean_0 = bp_2012_mean_0.rename(columns={'cholesterol': 'No_alcohol_cholesterol'})
bp_2012_mean_1 = bp_2012_mean_1.rename(columns={'cholesterol': 'Alcohol_cholesterol'})
bp_2012_mean_0 = bp_2012_mean_0.drop('alcohol', axis = 1)
bp_2012_mean_1 = bp_2012_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2012_smoke = pd.concat([bp_2012_mean_0, bp_2012_mean_1], axis=1, join='inner')
c_bp_mean_2012_smoke.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Liver function EDA with alcohol and age

# %%
#2009
bp_2009 = GJ_2009[['alcohol','age','got_ast', 'got_alt', 'gtp']]
bp_2009_0=bp_2009[bp_2009.alcohol==0]
bp_2009_1=bp_2009[bp_2009.alcohol==1]
bp_2009_mean_0 = bp_2009_0.groupby('age').mean()
bp_2009_mean_1 = bp_2009_1.groupby('age').mean()
bp_2009_mean_0 = bp_2009_mean_0.rename(columns={'got_ast': 'No_alcohol_got_ast', 'got_alt': 'No_alcohol_got_alt', 'gtp': 'No_alcohol_gtp'})
bp_2009_mean_1 = bp_2009_mean_1.rename(columns={'got_ast': 'Alcohol_got_ast', 'got_alt': 'Alcohol_got_alt', 'gtp': 'Alcohol_gtp'})
bp_2009_mean_0 = bp_2009_mean_0.drop('alcohol', axis = 1)
bp_2009_mean_1 = bp_2009_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2009_smoke = pd.concat([bp_2009_mean_0, bp_2009_mean_1], axis=1, join='inner')
c_bp_mean_2009_smoke.plot(linestyle = '-', marker = 'o', figsize = (14, 8))

# %%
#2010
bp_2010 = GJ_2010[['alcohol','age','got_ast', 'got_alt', 'gtp']]
bp_2010_0=bp_2010[bp_2010.alcohol==0]
bp_2010_1=bp_2010[bp_2010.alcohol==1]
bp_2010_mean_0 = bp_2010_0.groupby('age').mean()
bp_2010_mean_1 = bp_2010_1.groupby('age').mean()
bp_2010_mean_0 = bp_2010_mean_0.rename(columns={'got_ast': 'No_alcohol_got_ast', 'got_alt': 'No_alcohol_got_alt', 'gtp': 'No_alcohol_gtp'})
bp_2010_mean_1 = bp_2010_mean_1.rename(columns={'got_ast': 'Alcohol_got_ast', 'got_alt': 'Alcohol_got_alt', 'gtp': 'Alcohol_gtp'})
bp_2010_mean_0 = bp_2010_mean_0.drop('alcohol', axis = 1)
bp_2010_mean_1 = bp_2010_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2010_smoke = pd.concat([bp_2010_mean_0, bp_2010_mean_1], axis=1, join='inner')
c_bp_mean_2010_smoke.plot(linestyle = '-', marker = 'o', figsize = (14, 8))

# %%
#2011
bp_2011 = GJ_2011[['alcohol','age','got_ast', 'got_alt', 'gtp']]
bp_2011_0=bp_2011[bp_2011.alcohol==0]
bp_2011_1=bp_2011[bp_2011.alcohol==1]
bp_2011_mean_0 = bp_2011_0.groupby('age').mean()
bp_2011_mean_1 = bp_2011_1.groupby('age').mean()
bp_2011_mean_0 = bp_2011_mean_0.rename(columns={'got_ast': 'No_alcohol_got_ast', 'got_alt': 'No_alcohol_got_alt', 'gtp': 'No_alcohol_gtp'})
bp_2011_mean_1 = bp_2011_mean_1.rename(columns={'got_ast': 'Alcohol_got_ast', 'got_alt': 'Alcohol_got_alt', 'gtp': 'Alcohol_gtp'})
bp_2011_mean_0 = bp_2011_mean_0.drop('alcohol', axis = 1)
bp_2011_mean_1 = bp_2011_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2011_smoke = pd.concat([bp_2011_mean_0, bp_2011_mean_1], axis=1, join='inner')
c_bp_mean_2011_smoke.plot(linestyle = '-', marker = 'o', figsize = (14, 8))

# %%
#2012
bp_2012 = GJ_2012[['alcohol','age','got_ast', 'got_alt', 'gtp']]
bp_2012_0=bp_2012[bp_2012.alcohol==0]
bp_2012_1=bp_2012[bp_2012.alcohol==1]
bp_2012_mean_0 = bp_2012_0.groupby('age').mean()
bp_2012_mean_1 = bp_2012_1.groupby('age').mean()
bp_2012_mean_0 = bp_2012_mean_0.rename(columns={'got_ast': 'No_alcohol_got_ast', 'got_alt': 'No_alcohol_got_alt', 'gtp': 'No_alcohol_gtp'})
bp_2012_mean_1 = bp_2012_mean_1.rename(columns={'got_ast': 'Alcohol_got_ast', 'got_alt': 'Alcohol_got_alt', 'gtp': 'Alcohol_gtp'})
bp_2012_mean_0 = bp_2012_mean_0.drop('alcohol', axis = 1)
bp_2012_mean_1 = bp_2012_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2012_smoke = pd.concat([bp_2012_mean_0, bp_2012_mean_1], axis=1, join='inner')
c_bp_mean_2012_smoke.plot(linestyle = '-', marker = 'o', figsize = (14, 8))

# %% [markdown]
# ## Liver function EDA with alcohol and weight

# %%
#2009
bp_2009 = GJ_2009[['alcohol','weight','got_ast', 'got_alt', 'gtp']]
bp_2009_0=bp_2009[bp_2009.alcohol==0]
bp_2009_1=bp_2009[bp_2009.alcohol==1]
bp_2009_mean_0 = bp_2009_0.groupby('weight').mean()
bp_2009_mean_1 = bp_2009_1.groupby('weight').mean()
bp_2009_mean_0 = bp_2009_mean_0.rename(columns={'got_ast': 'No_alcohol_got_ast', 'got_alt': 'No_alcohol_got_alt', 'gtp': 'No_alcohol_gtp'})
bp_2009_mean_1 = bp_2009_mean_1.rename(columns={'got_ast': 'Alcohol_got_ast', 'got_alt': 'Alcohol_got_alt', 'gtp': 'Alcohol_gtp'})
bp_2009_mean_0 = bp_2009_mean_0.drop('alcohol', axis = 1)
bp_2009_mean_1 = bp_2009_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2009_smoke = pd.concat([bp_2009_mean_0, bp_2009_mean_1], axis=1, join='inner')
c_bp_mean_2009_smoke.plot(linestyle = '-', marker = 'o', figsize = (14, 8))

# %%
#2010
bp_2010 = GJ_2010[['alcohol','weight','got_ast', 'got_alt', 'gtp']]
bp_2010_0=bp_2010[bp_2010.alcohol==0]
bp_2010_1=bp_2010[bp_2010.alcohol==1]
bp_2010_mean_0 = bp_2010_0.groupby('weight').mean()
bp_2010_mean_1 = bp_2010_1.groupby('weight').mean()
bp_2010_mean_0 = bp_2010_mean_0.rename(columns={'got_ast': 'No_alcohol_got_ast', 'got_alt': 'No_alcohol_got_alt', 'gtp': 'No_alcohol_gtp'})
bp_2010_mean_1 = bp_2010_mean_1.rename(columns={'got_ast': 'Alcohol_got_ast', 'got_alt': 'Alcohol_got_alt', 'gtp': 'Alcohol_gtp'})
bp_2010_mean_0 = bp_2010_mean_0.drop('alcohol', axis = 1)
bp_2010_mean_1 = bp_2010_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2010_smoke = pd.concat([bp_2010_mean_0, bp_2010_mean_1], axis=1, join='inner')
c_bp_mean_2010_smoke.plot(linestyle = '-', marker = 'o', figsize = (14, 8))

# %%
#2011
bp_2011 = GJ_2011[['alcohol','weight','got_ast', 'got_alt', 'gtp']]
bp_2011_0=bp_2011[bp_2011.alcohol==0]
bp_2011_1=bp_2011[bp_2011.alcohol==1]
bp_2011_mean_0 = bp_2011_0.groupby('weight').mean()
bp_2011_mean_1 = bp_2011_1.groupby('weight').mean()
bp_2011_mean_0 = bp_2011_mean_0.rename(columns={'got_ast': 'No_alcohol_got_ast', 'got_alt': 'No_alcohol_got_alt', 'gtp': 'No_alcohol_gtp'})
bp_2011_mean_1 = bp_2011_mean_1.rename(columns={'got_ast': 'Alcohol_got_ast', 'got_alt': 'Alcohol_got_alt', 'gtp': 'Alcohol_gtp'})
bp_2011_mean_0 = bp_2011_mean_0.drop('alcohol', axis = 1)
bp_2011_mean_1 = bp_2011_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2011_smoke = pd.concat([bp_2011_mean_0, bp_2011_mean_1], axis=1, join='inner')
c_bp_mean_2011_smoke.plot(linestyle = '-', marker = 'o', figsize = (14, 8))

# %%
#2012
bp_2012 = GJ_2012[['alcohol','weight','got_ast', 'got_alt', 'gtp']]
bp_2012_0=bp_2012[bp_2012.alcohol==0]
bp_2012_1=bp_2012[bp_2012.alcohol==1]
bp_2012_mean_0 = bp_2012_0.groupby('weight').mean()
bp_2012_mean_1 = bp_2012_1.groupby('weight').mean()
bp_2012_mean_0 = bp_2012_mean_0.rename(columns={'got_ast': 'No_alcohol_got_ast', 'got_alt': 'No_alcohol_got_alt', 'gtp': 'No_alcohol_gtp'})
bp_2012_mean_1 = bp_2012_mean_1.rename(columns={'got_ast': 'Alcohol_got_ast', 'got_alt': 'Alcohol_got_alt', 'gtp': 'Alcohol_gtp'})
bp_2012_mean_0 = bp_2012_mean_0.drop('alcohol', axis = 1)
bp_2012_mean_1 = bp_2012_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2012_smoke = pd.concat([bp_2012_mean_0, bp_2012_mean_1], axis=1, join='inner')
c_bp_mean_2012_smoke.plot(linestyle = '-', marker = 'o', figsize = (14, 8))

# %% [markdown]
# ## Liver function EDA with alcohol and height

# %%
#2009
bp_2009 = GJ_2009[['alcohol','height','got_ast', 'got_alt', 'gtp']]
bp_2009_0=bp_2009[bp_2009.alcohol==0]
bp_2009_1=bp_2009[bp_2009.alcohol==1]
bp_2009_mean_0 = bp_2009_0.groupby('height').mean()
bp_2009_mean_1 = bp_2009_1.groupby('height').mean()
bp_2009_mean_0 = bp_2009_mean_0.rename(columns={'got_ast': 'No_alcohol_got_ast', 'got_alt': 'No_alcohol_got_alt', 'gtp': 'No_alcohol_gtp'})
bp_2009_mean_1 = bp_2009_mean_1.rename(columns={'got_ast': 'Alcohol_got_ast', 'got_alt': 'Alcohol_got_alt', 'gtp': 'Alcohol_gtp'})
bp_2009_mean_0 = bp_2009_mean_0.drop('alcohol', axis = 1)
bp_2009_mean_1 = bp_2009_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2009_smoke = pd.concat([bp_2009_mean_0, bp_2009_mean_1], axis=1, join='inner')
c_bp_mean_2009_smoke.plot(linestyle = '-', marker = 'o', figsize = (14, 8))

# %%
#2010
bp_2010 = GJ_2010[['alcohol','height','got_ast', 'got_alt', 'gtp']]
bp_2010_0=bp_2010[bp_2010.alcohol==0]
bp_2010_1=bp_2010[bp_2010.alcohol==1]
bp_2010_mean_0 = bp_2010_0.groupby('height').mean()
bp_2010_mean_1 = bp_2010_1.groupby('height').mean()
bp_2010_mean_0 = bp_2010_mean_0.rename(columns={'got_ast': 'No_alcohol_got_ast', 'got_alt': 'No_alcohol_got_alt', 'gtp': 'No_alcohol_gtp'})
bp_2010_mean_1 = bp_2010_mean_1.rename(columns={'got_ast': 'Alcohol_got_ast', 'got_alt': 'Alcohol_got_alt', 'gtp': 'Alcohol_gtp'})
bp_2010_mean_0 = bp_2010_mean_0.drop('alcohol', axis = 1)
bp_2010_mean_1 = bp_2010_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2010_smoke = pd.concat([bp_2010_mean_0, bp_2010_mean_1], axis=1, join='inner')
c_bp_mean_2010_smoke.plot(linestyle = '-', marker = 'o', figsize = (14, 8))

# %%
#2011
bp_2011 = GJ_2011[['alcohol','height','got_ast', 'got_alt', 'gtp']]
bp_2011_0=bp_2011[bp_2011.alcohol==0]
bp_2011_1=bp_2011[bp_2011.alcohol==1]
bp_2011_mean_0 = bp_2011_0.groupby('height').mean()
bp_2011_mean_1 = bp_2011_1.groupby('height').mean()
bp_2011_mean_0 = bp_2011_mean_0.rename(columns={'got_ast': 'No_alcohol_got_ast', 'got_alt': 'No_alcohol_got_alt', 'gtp': 'No_alcohol_gtp'})
bp_2011_mean_1 = bp_2011_mean_1.rename(columns={'got_ast': 'Alcohol_got_ast', 'got_alt': 'Alcohol_got_alt', 'gtp': 'Alcohol_gtp'})
bp_2011_mean_0 = bp_2011_mean_0.drop('alcohol', axis = 1)
bp_2011_mean_1 = bp_2011_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2011_smoke = pd.concat([bp_2011_mean_0, bp_2011_mean_1], axis=1, join='inner')
c_bp_mean_2011_smoke.plot(linestyle = '-', marker = 'o', figsize = (14, 8))

# %%
#2012
bp_2012 = GJ_2012[['alcohol','height','got_ast', 'got_alt', 'gtp']]
bp_2012_0=bp_2012[bp_2012.alcohol==0]
bp_2012_1=bp_2012[bp_2012.alcohol==1]
bp_2012_mean_0 = bp_2012_0.groupby('height').mean()
bp_2012_mean_1 = bp_2012_1.groupby('height').mean()
bp_2012_mean_0 = bp_2012_mean_0.rename(columns={'got_ast': 'No_alcohol_got_ast', 'got_alt': 'No_alcohol_got_alt', 'gtp': 'No_alcohol_gtp'})
bp_2012_mean_1 = bp_2012_mean_1.rename(columns={'got_ast': 'Alcohol_got_ast', 'got_alt': 'Alcohol_got_alt', 'gtp': 'Alcohol_gtp'})
bp_2012_mean_0 = bp_2012_mean_0.drop('alcohol', axis = 1)
bp_2012_mean_1 = bp_2012_mean_1.drop('alcohol', axis = 1)
c_bp_mean_2012_smoke = pd.concat([bp_2012_mean_0, bp_2012_mean_1], axis=1, join='inner')
c_bp_mean_2012_smoke.plot(linestyle = '-', marker = 'o', figsize = (14, 8))
