# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## EDA with two columns

# %%
GJ_2009 = pd.read_csv('NHIS_OPEN_GJ_2009.CSV')
GJ_2009 = GJ_2009[GJ_2009['age'] < 13]
GJ_2009 = GJ_2009[GJ_2009['height'] <= 180]
GJ_2009 = GJ_2009[GJ_2009['height'] >= 145]
GJ_2009 = GJ_2009[GJ_2009['weight'] <= 90]
GJ_2009 = GJ_2009[GJ_2009['weight'] >= 45]
GJ_2009.head()
# Out:
#    year  identity  sex  age  city  height  weight  waist  visual_left  \
# 5  2009    856304    2    1    43     145      45     64          1.5
# 6  2009    929881    2    1    41     145      45     68          0.2
# 7  2009    797895    2    1    44     145      50     68          1.5
# 8  2009    714243    2    1    26     145      50     75          1.5
# 9  2009    944774    2    1    41     145      50     79          0.6
#
#    visual_right    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 5           1.5    ...       10    1.0      1.0            1            NaN
# 6           0.1    ...       13    1.0      1.0            0            NaN
# 7           1.5    ...       12    1.0      0.0            1            1.0
# 8           1.5    ...        7    1.0      0.0            1            1.0
# 9           0.6    ...       10    1.0      0.0            1            1.0
#
#    missing_tooth  tooth_abrasion  third_molar  scale  data_year
# ...

# %%
GJ_2010 = pd.read_csv('NHIS_OPEN_GJ_2010.CSV')
GJ_2010 = GJ_2010[GJ_2010['age'] < 13]
GJ_2010 = GJ_2010[GJ_2010['height'] <= 180]
GJ_2010 = GJ_2010[GJ_2010['height'] >= 145]
GJ_2010 = GJ_2010[GJ_2010['weight'] <= 90]
GJ_2010 = GJ_2010[GJ_2010['weight'] >= 45]
GJ_2010.head()
# Out:
#     year  identity  sex  age  city  height  weight  waist  visual_left  \
# 17  2010    267175    2    1    44     145      45     68          1.5
# 18  2010     76146    2    1    28     145      45     60          1.0
# 19  2010     95998    2    1    41     145      45     66          0.8
# 39  2010    211499    2    1    41     150      45     73          0.2
# 40  2010    767814    2    1    47     150      45     58          1.0
#
#     visual_right    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 17           1.5    ...       21    1.0      0.0            1            NaN
# 18           1.5    ...        9    1.0      1.0            1            NaN
# 19           0.9    ...       22    1.0      1.0            1            NaN
# 39           0.4    ...        9    1.0      0.0            0            NaN
# 40           1.5    ...       12    1.0      0.0            1            NaN
#
#     missing_tooth  tooth_abrasion  third_molar  scale  data_year
# ...

# %%
GJ_2011 = pd.read_csv('NHIS_OPEN_GJ_2011.CSV')
GJ_2011 = GJ_2011[GJ_2011['age'] < 13]
GJ_2011 = GJ_2011[GJ_2011['height'] <= 180]
GJ_2011 = GJ_2011[GJ_2011['height'] >= 145]
GJ_2011 = GJ_2011[GJ_2011['weight'] <= 90]
GJ_2011 = GJ_2011[GJ_2011['weight'] >= 45]
GJ_2011.head()
# Out:
#     year  identity  sex  age  city  height  weight  waist  visual_left  \
# 1   2011     56745    2    1    26     145      45     68          0.9
# 2   2011    171067    2    1    26     145      45     65          1.0
# 3   2011    196496    2    1    27     145      45     68          0.9
# 34  2011    273008    2    1    26     150      45     69          0.9
# 35  2011    603760    2    1    42     150      45     64          0.7
#
#     visual_right    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 1            1.0    ...       12    1.0      0.0            0            NaN
# 2            1.5    ...       16    1.0      0.0            0            NaN
# 3            0.9    ...       23    1.0      0.0            1            NaN
# 34           1.0    ...        6    1.0      0.0            0            NaN
# 35           0.8    ...        7    1.0      0.0            1            NaN
#
#     missing_tooth  tooth_abrasion  third_molar  scale  data_year
# ...

# %%
GJ_2012 = pd.read_csv('NHIS_OPEN_GJ_2012.CSV')
GJ_2012 = GJ_2012[GJ_2012['age'] < 13]
GJ_2012 = GJ_2012[GJ_2012['height'] <= 180]
GJ_2012 = GJ_2012[GJ_2012['height'] >= 145]
GJ_2012 = GJ_2012[GJ_2012['weight'] <= 90]
GJ_2012 = GJ_2012[GJ_2012['weight'] >= 45]
GJ_2012.head()
# Out:
#     year  identity  sex  age  city  height  weight  waist  visual_left  \
# 14  2012    923646    1    1    28     145      45     66          0.9
# 15  2012    301712    2    1    44     145      45     69          0.9
# 16  2012    996872    2    1    43     145      45     72          1.2
# 17  2012     84122    2    1    46     145      45     64          1.2
# 38  2012     21159    2    1    11     150      45     65          0.6
#
#     visual_right    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 14           0.8    ...       33    1.0      0.0            1            0.0
# 15           1.2    ...       10    1.0      0.0            1            0.0
# 16           1.2    ...       19    1.0      0.0            1            1.0
# 17           1.2    ...       12    1.0      1.0            0            NaN
# 38           1.2    ...       13    1.0      0.0            1            0.0
#
#     missing_tooth  tooth_abrasion  third_molar  scale  data_year
# ...

# %% [markdown]
# ## Blood Press EDA with age and sex

# %%
#2009
bp_2009 = GJ_2009[['sex','age','b_press_contract','b_press_relax']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('age').mean()
bp_mean_2009_female=bp_2009_female.groupby('age').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['sex','age','b_press_contract','b_press_relax']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('age').mean()
bp_mean_2010_female=bp_2010_female.groupby('age').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011= GJ_2011[['sex','age','b_press_contract','b_press_relax']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('age').mean()
bp_mean_2011_female=bp_2011_female.groupby('age').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['sex','age','b_press_contract','b_press_relax']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('age').mean()
bp_mean_2012_female=bp_2012_female.groupby('age').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Blood Press EDA with sex and weight

# %%
#2009
bp_2009 = GJ_2009[['sex','weight','b_press_contract','b_press_relax']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('weight').mean()
bp_mean_2009_female=bp_2009_female.groupby('weight').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['sex','weight','b_press_contract','b_press_relax']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('weight').mean()
bp_mean_2010_female=bp_2010_female.groupby('weight').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011= GJ_2011[['sex','weight','b_press_contract','b_press_relax']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('weight').mean()
bp_mean_2011_female=bp_2011_female.groupby('weight').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['sex','weight','b_press_contract','b_press_relax']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('weight').mean()
bp_mean_2012_female=bp_2012_female.groupby('weight').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Blood Press EDA with sex and height

# %%
#2009
bp_2009 = GJ_2009[['sex','height','b_press_contract','b_press_relax']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('height').mean()
bp_mean_2009_female=bp_2009_female.groupby('height').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['sex','height','b_press_contract','b_press_relax']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('height').mean()
bp_mean_2010_female=bp_2010_female.groupby('height').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011= GJ_2011[['sex','height','b_press_contract','b_press_relax']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('height').mean()
bp_mean_2011_female=bp_2011_female.groupby('height').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['sex','height','b_press_contract','b_press_relax']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('height').mean()
bp_mean_2012_female=bp_2012_female.groupby('height').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Blood Press EDA with sex and smoke

# %%
#2009
bp_2009 = GJ_2009[['sex','smoke','b_press_contract','b_press_relax']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('smoke').mean()
bp_mean_2009_female=bp_2009_female.groupby('smoke').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(kind = 'bar',figsize = (14, 8))

# %%
#2010
bp_2010 = GJ_2010[['sex','smoke','b_press_contract','b_press_relax']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('smoke').mean()
bp_mean_2010_female=bp_2010_female.groupby('smoke').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(kind = 'bar',figsize = (14, 8))

# %%
#2011
bp_2011= GJ_2011[['sex','smoke','b_press_contract','b_press_relax']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('smoke').mean()
bp_mean_2011_female=bp_2011_female.groupby('smoke').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(kind = 'bar',figsize = (14, 8))

# %%
#2012
bp_2012 = GJ_2012[['sex','smoke','b_press_contract','b_press_relax']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('smoke').mean()
bp_mean_2012_female=bp_2012_female.groupby('smoke').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(kind = 'bar',figsize = (14, 8))

# %% [markdown]
# ## Blood Press EDA with sex and alcohol

# %%
#2009
bp_2009 = GJ_2009[['sex','alcohol','b_press_contract','b_press_relax']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('alcohol').mean()
bp_mean_2009_female=bp_2009_female.groupby('alcohol').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(kind = 'bar',figsize = (14, 8))

# %%
#2010
bp_2010 = GJ_2010[['sex','alcohol','b_press_contract','b_press_relax']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('alcohol').mean()
bp_mean_2010_female=bp_2010_female.groupby('alcohol').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(kind = 'bar',figsize = (14, 8))

# %%
#2011
bp_2011= GJ_2011[['sex','alcohol','b_press_contract','b_press_relax']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('alcohol').mean()
bp_mean_2011_female=bp_2011_female.groupby('alcohol').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2012
bp_2012 = GJ_2012[['sex','alcohol','b_press_contract','b_press_relax']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('alcohol').mean()
bp_mean_2012_female=bp_2012_female.groupby('alcohol').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(kind = 'bar', figsize = (14, 8))

# %% [markdown]
# ## Visual EDA with sex and age

# %%
#2009
bp_2009 = GJ_2009[['sex','age','visual_left','visual_right']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('age').mean()
bp_mean_2009_female=bp_2009_female.groupby('age').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['sex','age','visual_left','visual_right']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('age').mean()
bp_mean_2010_female=bp_2010_female.groupby('age').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011= GJ_2011[['sex','age','visual_left','visual_right']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('age').mean()
bp_mean_2011_female=bp_2011_female.groupby('age').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['sex','age','visual_left','visual_right']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('age').mean()
bp_mean_2012_female=bp_2012_female.groupby('age').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Visual EDA with sex and weight

# %%
#2009
bp_2009 = GJ_2009[['sex','weight','visual_left','visual_right']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('weight').mean()
bp_mean_2009_female=bp_2009_female.groupby('weight').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['sex','weight','visual_left','visual_right']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('weight').mean()
bp_mean_2010_female=bp_2010_female.groupby('weight').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'visual_left':'female_visual_left', 'visual_left':'female_visual_left'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011= GJ_2011[['sex','weight','visual_left','visual_right']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('weight').mean()
bp_mean_2011_female=bp_2011_female.groupby('weight').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['sex','weight','visual_left','visual_right']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('weight').mean()
bp_mean_2012_female=bp_2012_female.groupby('weight').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Visual EDA with sex and height

# %%
#2009
bp_2009 = GJ_2009[['sex','height','visual_left','visual_right']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('height').mean()
bp_mean_2009_female=bp_2009_female.groupby('height').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['sex','height','visual_left','visual_right']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('height').mean()
bp_mean_2010_female=bp_2010_female.groupby('height').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'visual_left':'female_visual_left', 'visual_left':'female_visual_left'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011= GJ_2011[['sex','height','visual_left','visual_right']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('height').mean()
bp_mean_2011_female=bp_2011_female.groupby('height').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['sex','height','visual_left','visual_right']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('height').mean()
bp_mean_2012_female=bp_2012_female.groupby('height').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Visual EDA with sex and smoke

# %%
#2009
bp_2009 = GJ_2009[['sex','smoke','visual_left','visual_right']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('smoke').mean()
bp_mean_2009_female=bp_2009_female.groupby('smoke').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2010
bp_2010 = GJ_2010[['sex','smoke','visual_left','visual_right']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('smoke').mean()
bp_mean_2010_female=bp_2010_female.groupby('smoke').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'visual_left':'female_visual_left', 'visual_left':'female_visual_left'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2011
bp_2011= GJ_2011[['sex','smoke','visual_left','visual_right']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('smoke').mean()
bp_mean_2011_female=bp_2011_female.groupby('smoke').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2012
bp_2012 = GJ_2012[['sex','smoke','visual_left','visual_right']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('smoke').mean()
bp_mean_2012_female=bp_2012_female.groupby('smoke').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(kind = 'bar', figsize = (14, 8))

# %% [markdown]
# ## Visual EDA with sex and alcohol

# %%
#2009
bp_2009 = GJ_2009[['sex','alcohol','visual_left','visual_right']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('alcohol').mean()
bp_mean_2009_female=bp_2009_female.groupby('alcohol').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2010
bp_2010 = GJ_2010[['sex','alcohol','visual_left','visual_right']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('alcohol').mean()
bp_mean_2010_female=bp_2010_female.groupby('alcohol').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2011
bp_2011= GJ_2011[['sex','alcohol','visual_left','visual_right']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('alcohol').mean()
bp_mean_2011_female=bp_2011_female.groupby('alcohol').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2012
bp_2012 = GJ_2012[['sex','alcohol','visual_left','visual_right']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('alcohol').mean()
bp_mean_2012_female=bp_2012_female.groupby('alcohol').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'visual_left':'male_visual_left','visual_right':'male_visual_right'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'visual_left':'female_visual_left', 'visual_right':'female_visual_right'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(kind = 'bar', figsize = (14, 8))

# %% [markdown]
# ## Blood sugar EDA with sex and age

# %%
#2009
bp_2009 = GJ_2009[['sex','age','b_sugar']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('age').mean()
bp_mean_2009_female=bp_2009_female.groupby('age').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['sex','age','b_sugar']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('age').mean()
bp_mean_2010_female=bp_2010_female.groupby('age').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011= GJ_2011[['sex','age','b_sugar']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('age').mean()
bp_mean_2011_female=bp_2011_female.groupby('age').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['sex','age','b_sugar']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('age').mean()
bp_mean_2012_female=bp_2012_female.groupby('age').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Blood sugar EDA with sex and weight

# %%
#2009
bp_2009 = GJ_2009[['sex','weight','b_sugar']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('weight').mean()
bp_mean_2009_female=bp_2009_female.groupby('weight').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['sex','weight','b_sugar']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('weight').mean()
bp_mean_2010_female=bp_2010_female.groupby('weight').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011= GJ_2011[['sex','weight','b_sugar']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('weight').mean()
bp_mean_2011_female=bp_2011_female.groupby('weight').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['sex','weight','b_sugar']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('weight').mean()
bp_mean_2012_female=bp_2012_female.groupby('weight').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Blood sugar EDA with sex and height

# %%
#2009
bp_2009 = GJ_2009[['sex','height','b_sugar']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('height').mean()
bp_mean_2009_female=bp_2009_female.groupby('height').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['sex','height','b_sugar']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('height').mean()
bp_mean_2010_female=bp_2010_female.groupby('height').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011= GJ_2011[['sex','height','b_sugar']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('height').mean()
bp_mean_2011_female=bp_2011_female.groupby('height').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['sex','height','b_sugar']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('height').mean()
bp_mean_2012_female=bp_2012_female.groupby('height').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Blood sugar EDA with sex and smoke

# %%
#2009
bp_2009 = GJ_2009[['sex','smoke','b_sugar']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('smoke').mean()
bp_mean_2009_female=bp_2009_female.groupby('smoke').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2010
bp_2010 = GJ_2010[['sex','smoke','b_sugar']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('smoke').mean()
bp_mean_2010_female=bp_2010_female.groupby('smoke').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2011
bp_2011= GJ_2011[['sex','smoke','b_sugar']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('smoke').mean()
bp_mean_2011_female=bp_2011_female.groupby('smoke').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2012
bp_2012 = GJ_2012[['sex','smoke','b_sugar']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('smoke').mean()
bp_mean_2012_female=bp_2012_female.groupby('smoke').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(kind = 'bar', figsize = (14, 8))

# %% [markdown]
# ## Blood sugar EDA with sex and alcohol

# %%
#2009
bp_2009 = GJ_2009[['sex','alcohol','b_sugar']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('alcohol').mean()
bp_mean_2009_female=bp_2009_female.groupby('alcohol').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2010
bp_2010 = GJ_2010[['sex','alcohol','b_sugar']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('alcohol').mean()
bp_mean_2010_female=bp_2010_female.groupby('alcohol').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2011
bp_2011= GJ_2011[['sex','alcohol','b_sugar']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('alcohol').mean()
bp_mean_2011_female=bp_2011_female.groupby('alcohol').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2012
bp_2012 = GJ_2012[['sex','alcohol','b_sugar']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('alcohol').mean()
bp_mean_2012_female=bp_2012_female.groupby('alcohol').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'b_sugar':'male_b_sugar'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'b_sugar':'female_b_sugar'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(kind = 'bar', figsize = (14, 8))

# %% [markdown]
# ## Cholesterol EDA with sex and age

# %%
#2009
bp_2009 = GJ_2009[['sex','age','cholesterol']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('age').mean()
bp_mean_2009_female=bp_2009_female.groupby('age').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['sex','age','cholesterol']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('age').mean()
bp_mean_2010_female=bp_2010_female.groupby('age').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011= GJ_2011[['sex','age','cholesterol']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('age').mean()
bp_mean_2011_female=bp_2011_female.groupby('age').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['sex','age','cholesterol']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('age').mean()
bp_mean_2012_female=bp_2012_female.groupby('age').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Cholesterol EDA with sex and weight

# %%
#2009
bp_2009 = GJ_2009[['sex','weight','cholesterol']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('weight').mean()
bp_mean_2009_female=bp_2009_female.groupby('weight').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['sex','weight','cholesterol']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('weight').mean()
bp_mean_2010_female=bp_2010_female.groupby('weight').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011= GJ_2011[['sex','weight','cholesterol']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('weight').mean()
bp_mean_2011_female=bp_2011_female.groupby('weight').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['sex','weight','cholesterol']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('weight').mean()
bp_mean_2012_female=bp_2012_female.groupby('weight').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Cholesterol EDA with sex and height

# %%
#2009
bp_2009 = GJ_2009[['sex','height','cholesterol']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('height').mean()
bp_mean_2009_female=bp_2009_female.groupby('height').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['sex','height','cholesterol']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('height').mean()
bp_mean_2010_female=bp_2010_female.groupby('height').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011= GJ_2011[['sex','height','cholesterol']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('height').mean()
bp_mean_2011_female=bp_2011_female.groupby('height').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['sex','height','cholesterol']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('height').mean()
bp_mean_2012_female=bp_2012_female.groupby('height').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Cholesterol EDA with sex and smoke

# %%
#2009
bp_2009 = GJ_2009[['sex','smoke','cholesterol']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('smoke').mean()
bp_mean_2009_female=bp_2009_female.groupby('smoke').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2010
bp_2010 = GJ_2010[['sex','smoke','cholesterol']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('smoke').mean()
bp_mean_2010_female=bp_2010_female.groupby('smoke').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2011
bp_2011= GJ_2011[['sex','smoke','cholesterol']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('smoke').mean()
bp_mean_2011_female=bp_2011_female.groupby('smoke').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2012
bp_2012 = GJ_2012[['sex','smoke','cholesterol']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('smoke').mean()
bp_mean_2012_female=bp_2012_female.groupby('smoke').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(kind = 'bar', figsize = (14, 8))

# %% [markdown]
# ## Cholesterol EDA with sex and alcohol

# %%
#2009
bp_2009 = GJ_2009[['sex','alcohol','cholesterol']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('alcohol').mean()
bp_mean_2009_female=bp_2009_female.groupby('alcohol').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2010
bp_2010 = GJ_2010[['sex','alcohol','cholesterol']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('alcohol').mean()
bp_mean_2010_female=bp_2010_female.groupby('alcohol').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2011
bp_2011= GJ_2011[['sex','alcohol','cholesterol']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('alcohol').mean()
bp_mean_2011_female=bp_2011_female.groupby('alcohol').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2012
bp_2012 = GJ_2012[['sex','alcohol','cholesterol']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('alcohol').mean()
bp_mean_2012_female=bp_2012_female.groupby('alcohol').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'cholesterol':'male_cholesterol'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'cholesterol':'female_cholesterol'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(kind = 'bar', figsize = (14, 8))

# %% [markdown]
# ## Liver function EDA with sex and age

# %%
#2009
bp_2009 = GJ_2009[['sex','age','got_ast', 'got_alt', 'gtp']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('age').mean()
bp_mean_2009_female=bp_2009_female.groupby('age').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['sex','age','got_ast', 'got_alt', 'gtp']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('age').mean()
bp_mean_2010_female=bp_2010_female.groupby('age').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011= GJ_2011[['sex','age','got_ast', 'got_alt', 'gtp']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('age').mean()
bp_mean_2011_female=bp_2011_female.groupby('age').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['sex','age','got_ast', 'got_alt', 'gtp']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('age').mean()
bp_mean_2012_female=bp_2012_female.groupby('age').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(linestyle = '-', marker = 'o', figsize = (10,5))

# %% [markdown]
# ## Liver function EDA with sex and weight

# %%
#2009
bp_2009 = GJ_2009[['sex','age','got_ast', 'got_alt', 'gtp']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('age').mean()
bp_mean_2009_female=bp_2009_female.groupby('age').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'b_press_contract':'male_contract','b_press_relax':'male_relax'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'b_press_contract':'female_contract', 'b_press_relax':'female_relax'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['sex','weight','got_ast', 'got_alt', 'gtp']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('weight').mean()
bp_mean_2010_female=bp_2010_female.groupby('weight').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011= GJ_2011[['sex','weight','got_ast', 'got_alt', 'gtp']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('weight').mean()
bp_mean_2011_female=bp_2011_female.groupby('weight').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['sex','weight','got_ast', 'got_alt', 'gtp']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('weight').mean()
bp_mean_2012_female=bp_2012_female.groupby('weight').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Liver function EDA with sex and height

# %%
#2009
bp_2009 = GJ_2009[['sex','height','got_ast', 'got_alt', 'gtp']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('height').mean()
bp_mean_2009_female=bp_2009_female.groupby('height').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2010
bp_2010 = GJ_2010[['sex','height','got_ast', 'got_alt', 'gtp']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('height').mean()
bp_mean_2010_female=bp_2010_female.groupby('height').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2011
bp_2011= GJ_2011[['sex','height','got_ast', 'got_alt', 'gtp']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('height').mean()
bp_mean_2011_female=bp_2011_female.groupby('height').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %%
#2012
bp_2012 = GJ_2012[['sex','height','got_ast', 'got_alt', 'gtp']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('height').mean()
bp_mean_2012_female=bp_2012_female.groupby('height').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(linestyle = '-', marker = 'o', figsize = (10, 5))

# %% [markdown]
# ## Liver function EDA with sex and smoke

# %%
#2009
bp_2009 = GJ_2009[['sex','smoke','got_ast', 'got_alt', 'gtp']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('smoke').mean()
bp_mean_2009_female=bp_2009_female.groupby('smoke').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2010
bp_2010 = GJ_2010[['sex','smoke','got_ast', 'got_alt', 'gtp']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('smoke').mean()
bp_mean_2010_female=bp_2010_female.groupby('smoke').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2011
bp_2011= GJ_2011[['sex','smoke','got_ast', 'got_alt', 'gtp']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('smoke').mean()
bp_mean_2011_female=bp_2011_female.groupby('smoke').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2012
bp_2012 = GJ_2012[['sex','smoke','got_ast', 'got_alt', 'gtp']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('smoke').mean()
bp_mean_2012_female=bp_2012_female.groupby('smoke').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(kind = 'bar', figsize = (14, 8))

# %% [markdown]
# ## Liver function EDA with sex and alcohol

# %%
#2009
bp_2009 = GJ_2009[['sex','alcohol','got_ast', 'got_alt', 'gtp']]
bp_2009_male=bp_2009[bp_2009.sex==1]
bp_2009_female=bp_2009[bp_2009.sex==2]
bp_mean_2009_male=bp_2009_male.groupby('alcohol').mean()
bp_mean_2009_female=bp_2009_female.groupby('alcohol').mean()
bp_mean_2009_male=bp_mean_2009_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2009_female=bp_mean_2009_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2009_male = bp_mean_2009_male.drop('sex', axis = 1)
bp_mean_2009_female = bp_mean_2009_female.drop('sex', axis = 1)
c_bp_mean_2009_sex = pd.concat([bp_mean_2009_male, bp_mean_2009_female], axis=1, join='inner')
c_bp_mean_2009_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2010
bp_2010 = GJ_2010[['sex','alcohol','got_ast', 'got_alt', 'gtp']]
bp_2010_male=bp_2010[bp_2010.sex==1]
bp_2010_female=bp_2010[bp_2010.sex==2]
bp_mean_2010_male=bp_2010_male.groupby('alcohol').mean()
bp_mean_2010_female=bp_2010_female.groupby('alcohol').mean()
bp_mean_2010_male=bp_mean_2010_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2010_female=bp_mean_2010_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2010_male = bp_mean_2010_male.drop('sex', axis = 1)
bp_mean_2010_female = bp_mean_2010_female.drop('sex', axis = 1)
c_bp_mean_2010_sex = pd.concat([bp_mean_2010_male, bp_mean_2010_female], axis=1, join='inner')
c_bp_mean_2010_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2011
bp_2011= GJ_2011[['sex','alcohol','got_ast', 'got_alt', 'gtp']]
bp_2011_male=bp_2011[bp_2011.sex==1]
bp_2011_female=bp_2011[bp_2011.sex==2]
bp_mean_2011_male=bp_2011_male.groupby('alcohol').mean()
bp_mean_2011_female=bp_2011_female.groupby('alcohol').mean()
bp_mean_2011_male=bp_mean_2011_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2011_female = bp_mean_2011_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2011_male = bp_mean_2011_male.drop('sex', axis = 1)
bp_mean_2011_female = bp_mean_2011_female.drop('sex', axis = 1)
c_bp_mean_2011_sex = pd.concat([bp_mean_2011_male, bp_mean_2011_female], axis=1, join='inner')
c_bp_mean_2011_sex.plot(kind = 'bar', figsize = (14, 8))

# %%
#2012
bp_2012 = GJ_2012[['sex','alcohol','got_ast', 'got_alt', 'gtp']]
bp_2012_male=bp_2012[bp_2012.sex==1]
bp_2012_female=bp_2012[bp_2012.sex==2]
bp_mean_2012_male=bp_2012_male.groupby('alcohol').mean()
bp_mean_2012_female=bp_2012_female.groupby('alcohol').mean()
bp_mean_2012_male=bp_mean_2012_male.rename(columns={'got_ast':'male_got_ast', 'got_alt' : 'male_got_alt', 'gtp': 'male_gtp'})
bp_mean_2012_female=bp_mean_2012_female.rename(columns={'got_ast':'female_got_ast', 'got_alt' : 'female_got_alt', 'gtp': 'female_gtp'})
bp_mean_2012_male = bp_mean_2012_male.drop('sex', axis = 1)
bp_mean_2012_female = bp_mean_2012_female.drop('sex', axis = 1)
c_bp_mean_2012_sex = pd.concat([bp_mean_2012_male, bp_mean_2012_female], axis=1, join='inner')
c_bp_mean_2012_sex.plot(kind = 'bar', figsize = (14, 8))
