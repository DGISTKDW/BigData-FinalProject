# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Read Data file

# %% [markdown]
# ## 건강검진 파일

# %%
GJ_2009 = pd.read_csv('NHIS_OPEN_GJ_2009.CSV')
GJ_2009 = GJ_2009[GJ_2009['age'] < 13]
GJ_2009 = GJ_2009[GJ_2009['height'] <= 180]
GJ_2009 = GJ_2009[GJ_2009['height'] >= 145]
GJ_2009 = GJ_2009[GJ_2009['weight'] <= 90]
GJ_2009 = GJ_2009[GJ_2009['weight'] >= 45]
GJ_2009.head()
# Out:
#    year  identity  sex  age  city  height  weight  waist  visual_left  \
# 5  2009    856304    2    1    43     145      45     64          1.5
# 6  2009    929881    2    1    41     145      45     68          0.2
# 7  2009    797895    2    1    44     145      50     68          1.5
# 8  2009    714243    2    1    26     145      50     75          1.5
# 9  2009    944774    2    1    41     145      50     79          0.6
#
#    visual_right    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 5           1.5    ...       10    1.0      1.0            1            NaN
# 6           0.1    ...       13    1.0      1.0            0            NaN
# 7           1.5    ...       12    1.0      0.0            1            1.0
# 8           1.5    ...        7    1.0      0.0            1            1.0
# 9           0.6    ...       10    1.0      0.0            1            1.0
#
#    missing_tooth  tooth_abrasion  third_molar  scale  data_year
# ...

# %%
GJ_2010 = pd.read_csv('NHIS_OPEN_GJ_2010.CSV')
GJ_2010 = GJ_2010[GJ_2010['age'] < 13]
GJ_2010 = GJ_2010[GJ_2010['height'] <= 180]
GJ_2010 = GJ_2010[GJ_2010['height'] >= 145]
GJ_2010 = GJ_2010[GJ_2010['weight'] <= 90]
GJ_2010 = GJ_2010[GJ_2010['weight'] >= 45]
GJ_2010.head()
# Out:
#     year  identity  sex  age  city  height  weight  waist  visual_left  \
# 17  2010    267175    2    1    44     145      45     68          1.5
# 18  2010     76146    2    1    28     145      45     60          1.0
# 19  2010     95998    2    1    41     145      45     66          0.8
# 39  2010    211499    2    1    41     150      45     73          0.2
# 40  2010    767814    2    1    47     150      45     58          1.0
#
#     visual_right    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 17           1.5    ...       21    1.0      0.0            1            NaN
# 18           1.5    ...        9    1.0      1.0            1            NaN
# 19           0.9    ...       22    1.0      1.0            1            NaN
# 39           0.4    ...        9    1.0      0.0            0            NaN
# 40           1.5    ...       12    1.0      0.0            1            NaN
#
#     missing_tooth  tooth_abrasion  third_molar  scale  data_year
# ...

# %%
GJ_2011 = pd.read_csv('NHIS_OPEN_GJ_2011.CSV')
GJ_2011 = GJ_2011[GJ_2011['age'] < 13]
GJ_2011 = GJ_2011[GJ_2011['height'] <= 180]
GJ_2011 = GJ_2011[GJ_2011['height'] >= 145]
GJ_2011 = GJ_2011[GJ_2011['weight'] <= 90]
GJ_2011 = GJ_2011[GJ_2011['weight'] >= 45]
GJ_2011.head()
# Out:
#     year  identity  sex  age  city  height  weight  waist  visual_left  \
# 1   2011     56745    2    1    26     145      45     68          0.9
# 2   2011    171067    2    1    26     145      45     65          1.0
# 3   2011    196496    2    1    27     145      45     68          0.9
# 34  2011    273008    2    1    26     150      45     69          0.9
# 35  2011    603760    2    1    42     150      45     64          0.7
#
#     visual_right    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 1            1.0    ...       12    1.0      0.0            0            NaN
# 2            1.5    ...       16    1.0      0.0            0            NaN
# 3            0.9    ...       23    1.0      0.0            1            NaN
# 34           1.0    ...        6    1.0      0.0            0            NaN
# 35           0.8    ...        7    1.0      0.0            1            NaN
#
#     missing_tooth  tooth_abrasion  third_molar  scale  data_year
# ...

# %%
GJ_2012 = pd.read_csv('NHIS_OPEN_GJ_2012.CSV')
GJ_2012 = GJ_2012[GJ_2012['age'] < 13]
GJ_2012 = GJ_2012[GJ_2012['height'] <= 180]
GJ_2012 = GJ_2012[GJ_2012['height'] >= 145]
GJ_2012 = GJ_2012[GJ_2012['weight'] <= 90]
GJ_2012 = GJ_2012[GJ_2012['weight'] >= 45]
GJ_2012.head()
# Out:
#     year  identity  sex  age  city  height  weight  waist  visual_left  \
# 14  2012    923646    1    1    28     145      45     66          0.9
# 15  2012    301712    2    1    44     145      45     69          0.9
# 16  2012    996872    2    1    43     145      45     72          1.2
# 17  2012     84122    2    1    46     145      45     64          1.2
# 38  2012     21159    2    1    11     150      45     65          0.6
#
#     visual_right    ...      gtp  smoke  alcohol  dental_exam  dental_caries  \
# 14           0.8    ...       33    1.0      0.0            1            0.0
# 15           1.2    ...       10    1.0      0.0            1            0.0
# 16           1.2    ...       19    1.0      0.0            1            1.0
# 17           1.2    ...       12    1.0      1.0            0            NaN
# 38           1.2    ...       13    1.0      0.0            1            0.0
#
#     missing_tooth  tooth_abrasion  third_molar  scale  data_year
# ...

# %% [markdown]
# ## (A) blood press

# %% [markdown]
# ### (1) blood press by sex

# %%
#2005
bp_2005=GJ_2009[['sex','b_press_contract','b_press_relax']]
bp_mean_2005=bp_2005.groupby('sex').mean()
bp_mean_2005
# Out:
#      b_press_contract  b_press_relax
# sex
# 1          124.398280      77.896058
# 2          119.610148      74.224187

# %%
bp_mean_2005.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['sex','b_press_contract','b_press_relax']]
bp_mean_2006=bp_2006.groupby('sex').mean()
bp_mean_2006
# Out:
#      b_press_contract  b_press_relax
# sex
# 1          124.416366      77.885050
# 2          119.203413      73.955567

# %%
bp_mean_2006.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['sex','b_press_contract','b_press_relax']]
bp_mean_2007=bp_2007.groupby('sex').mean()
bp_mean_2007
# Out:
#      b_press_contract  b_press_relax
# sex
# 1          124.313204      77.811626
# 2          119.223794      74.005566

# %%
bp_mean_2007.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['sex','b_press_contract','b_press_relax']]
bp_mean_2008=bp_2008.groupby('sex').mean()
bp_mean_2008
# Out:
#      b_press_contract  b_press_relax
# sex
# 1          124.092427      77.783108
# 2          118.909797      73.895334

# %%
bp_mean_2008.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %% [markdown]
# ### (2) blood press by height

# %%
#2005
bp_2005=GJ_2009[['height','b_press_contract','b_press_relax']]
bp_mean_2005=bp_2005.groupby('height').mean()
bp_mean_2005
# Out:
#         b_press_contract  b_press_relax
# height
# 145           126.466512      77.292980
# 150           122.901902      75.782109
# 155           120.355958      74.722724
# 160           120.735911      75.250335
# 165           122.846264      76.930894
# 170           123.401405      77.531237
# 175           123.000187      77.322815
# 180           122.782257      77.017870

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='height',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['height','b_press_contract','b_press_relax']]
bp_mean_2006=bp_2006.groupby('height').mean()
bp_mean_2006
# Out:
#         b_press_contract  b_press_relax
# height
# 145           126.334304      76.985786
# 150           122.719148      75.644277
# 155           120.000548      74.482069
# 160           120.367204      75.005512
# 165           122.693457      76.809098
# 170           123.419991      77.544564
# 175           123.087747      77.325211
# 180           122.804048      76.966055

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='height',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['height','b_press_contract','b_press_relax']]
bp_mean_2007=bp_2007.groupby('height').mean()
bp_mean_2007
# Out:
#         b_press_contract  b_press_relax
# height
# 145           126.140011      76.887084
# 150           122.646831      75.585457
# 155           120.034475      74.525807
# 160           120.287005      74.984100
# 165           122.558910      76.731858
# 170           123.314223      77.464319
# 175           123.142547      77.378102
# 180           122.753431      76.964542

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='height',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['height','b_press_contract','b_press_relax']]
bp_mean_2008=bp_2008.groupby('height').mean()
bp_mean_2008
# Out:
#         b_press_contract  b_press_relax
# height
# 145           125.715061      76.690722
# 150           122.308230      75.447206
# 155           119.772121      74.450750
# 160           119.913929      74.848080
# 165           122.320416      76.671728
# 170           123.156170      77.470082
# 175           122.838686      77.320834
# 180           122.558667      76.940893

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='height',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (3) blood press by weight

# %%
#2005
bp_2005=GJ_2009[['weight','b_press_contract','b_press_relax']]
bp_mean_2005=bp_2005.groupby('weight').mean()
bp_mean_2005
# Out:
#         b_press_contract  b_press_relax
# weight
# 45            115.272210      71.852155
# 50            117.737203      73.172846
# 55            120.339607      74.715270
# 60            122.501825      76.148591
# 65            123.884578      77.275246
# 70            125.023257      78.249425
# 75            125.964333      79.048193
# 80            126.939730      79.879375
# 85            128.144527      80.853779
# 90            129.517699      81.755511

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='weight',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['weight','b_press_contract','b_press_relax']]
bp_mean_2006=bp_2006.groupby('weight').mean()
bp_mean_2006
# Out:
#         b_press_contract  b_press_relax
# weight
# 45            114.819140      71.523311
# 50            117.297087      72.863809
# 55            119.932666      74.430342
# 60            122.341504      76.015884
# 65            123.788698      77.171170
# 70            124.895486      78.196706
# 75            125.979100      79.029185
# 80            127.131162      79.992139
# 85            128.049666      80.736012
# 90            129.268697      81.578125

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='weight',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['weight','b_press_contract','b_press_relax']]
bp_mean_2007=bp_2007.groupby('weight').mean()
bp_mean_2007
# Out:
#         b_press_contract  b_press_relax
# weight
# 45            114.848455      71.621903
# 50            117.255812      72.900366
# 55            119.882537      74.430380
# 60            122.214530      75.967268
# 65            123.692964      77.110829
# 70            124.708698      77.987712
# 75            125.804198      78.878311
# 80            126.998957      79.852635
# 85            128.029835      80.748514
# 90            129.099308      81.449735

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='weight',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['weight','b_press_contract','b_press_relax']]
bp_mean_2008=bp_2008.groupby('weight').mean()
bp_mean_2008
# Out:
#         b_press_contract  b_press_relax
# weight
# 45            114.657120      71.538896
# 50            116.868474      72.732215
# 55            119.549491      74.303033
# 60            121.875025      75.839315
# 65            123.382152      77.029742
# 70            124.540747      77.998893
# 75            125.609910      78.918352
# 80            126.786319      79.833119
# 85            127.857448      80.639381
# 90            129.274599      81.758494

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='weight',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (4) blood press by age

# %%
#2005
bp_2005=GJ_2009[['age','b_press_contract','b_press_relax']]
bp_mean_2005=bp_2005.groupby('age').mean()
bp_mean_2005
# Out:
#      b_press_contract  b_press_relax
# age
# 1          114.071282      71.282880
# 2          116.782600      73.044864
# 3          119.023790      74.747011
# 4          120.315360      75.836632
# 5          119.700731      75.450993
# 6          121.628241      76.734246
# 7          123.248287      77.361390
# 8          125.462427      78.152980
# 9          127.416638      78.279685
# 10         129.396306      78.318438
# 11         130.523593      78.294109
# 12         131.127789      77.983210

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='age',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['age','b_press_contract','b_press_relax']]
bp_mean_2006=bp_2006.groupby('age').mean()
bp_mean_2006
# Out:
#      b_press_contract  b_press_relax
# age
# 1          114.126733      71.282693
# 2          116.335389      72.758754
# 3          118.291907      74.153211
# 4          119.750543      75.439557
# 5          119.540750      75.309819
# 6          121.372757      76.548991
# 7          123.030654      77.314030
# 8          125.077029      77.955216
# 9          127.277435      78.165834
# 10         129.301126      78.250206
# 11         130.648520      78.153063
# 12         131.580706      78.100452

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='age',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['age','b_press_contract','b_press_relax']]
bp_mean_2007=bp_2007.groupby('age').mean()
bp_mean_2007
# Out:
#      b_press_contract  b_press_relax
# age
# 1          113.907977      71.147652
# 2          116.245488      72.745562
# 3          118.512786      74.279654
# 4          120.033143      75.605966
# 5          119.482169      75.358257
# 6          121.415930      76.650032
# 7          122.917901      77.281271
# 8          124.646308      77.731169
# 9          126.923855      77.985330
# 10         128.960625      77.988507
# 11         130.273274      77.716639
# 12         131.212578      77.599535

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='age',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['age','b_press_contract','b_press_relax']]
bp_mean_2008=bp_2008.groupby('age').mean()
bp_mean_2008
# Out:
#      b_press_contract  b_press_relax
# age
# 1          114.167963      71.336019
# 2          115.971186      72.607206
# 3          117.782191      73.962716
# 4          119.249222      75.231202
# 5          119.266455      75.348682
# 6          120.936131      76.511483
# 7          122.528348      77.195405
# 8          124.262822      77.648847
# 9          126.182705      77.594673
# 10         128.428988      77.779757
# 11         129.818692      77.530962
# 12         131.014171      77.556010

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='age',y=['b_press_contract','b_press_relax'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (5) blood press by city

# %%
#2005
bp_2005=GJ_2009[['city','b_press_contract','b_press_relax']]
bp_mean_2005=bp_2005.groupby('city').mean()
bp_mean_2005
# Out:
#       b_press_contract  b_press_relax
# city
# 11          122.105208      75.886413
# 26          121.665874      75.811384
# 27          122.443694      75.811616
# 28          123.034455      76.983153
# 29          120.309648      75.952365
# 30          121.974410      76.684864
# 31          123.027039      76.178113
# 41          122.146405      76.330004
# 42          123.666277      77.085957
# 43          122.648149      76.936039
# 44          122.284530      76.859372
# 45          122.049119      76.405622
# 46          122.873552      76.546297
# 47          123.178041      76.498399
# 48          122.215091      76.059484
# 49          123.183465      77.166592

# %%
bp_mean_2005.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['city','b_press_contract','b_press_relax']]
bp_mean_2006=bp_2006.groupby('city').mean()
bp_mean_2006
# Out:
#       b_press_contract  b_press_relax
# city
# 11          121.831862      75.708305
# 26          121.341621      75.477829
# 27          122.181400      75.733204
# 28          122.514524      76.798949
# 29          120.507205      76.332633
# 30          121.176362      75.977686
# 31          123.295389      76.490650
# 41          122.126996      76.119921
# 42          123.065690      76.843187
# 43          122.096828      76.607153
# 44          122.584135      76.770068
# 45          122.201936      76.788001
# 46          123.018911      76.902525
# 47          122.965129      76.268541
# 48          121.942068      75.939463
# 49          122.669721      77.282148

# %%
bp_mean_2006.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['city','b_press_contract','b_press_relax']]
bp_mean_2007=bp_2007.groupby('city').mean()
bp_mean_2007
# Out:
#       b_press_contract  b_press_relax
# city
# 11          121.396745      75.561374
# 26          121.316819      75.413649
# 27          122.182724      75.589057
# 28          122.366907      76.724729
# 29          120.200544      76.123045
# 30          121.246241      75.965887
# 31          122.720074      76.298055
# 41          121.853239      76.020720
# 42          123.648687      77.310592
# 43          122.261417      76.558056
# 44          123.149088      76.965721
# 45          122.624822      76.765863
# 46          124.161022      77.388664
# 47          123.324150      76.547000
# 48          121.634989      75.769456
# 49          123.064018      77.553294

# %%
bp_mean_2007.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['city','b_press_contract','b_press_relax']]
bp_mean_2008=bp_2008.groupby('city').mean()
bp_mean_2008
# Out:
#       b_press_contract  b_press_relax
# city
# 11          121.071949      75.516880
# 26          120.913355      75.032936
# 27          122.076500      75.738498
# 28          122.331167      76.816890
# 29          119.751889      75.915760
# 30          120.789545      75.790997
# 31          122.682138      76.315796
# 36          122.628810      76.704031
# 41          121.661834      75.992347
# 42          123.322952      77.202289
# 43          122.077297      76.394162
# 44          122.883338      77.255777
# 45          122.341043      76.515442
# 46          123.521585      77.009435
# 47          122.753415      76.282144
# 48          121.150517      75.607969
# 49          123.341163      77.289142

# %%
bp_mean_2008.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %% [markdown]
# ### (6) blood press by smoke

# %%
#2005
bp_2005=GJ_2009[['smoke','b_press_contract','b_press_relax']]
bp_mean_2005=bp_2005.groupby('smoke').mean()
bp_mean_2005
# Out:
#        b_press_contract  b_press_relax
# smoke
# 1.0          121.206707      75.347359
# 2.0          124.907686      78.108082
# 3.0          123.273072      77.360015

# %%
bp_mean_2005.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['smoke','b_press_contract','b_press_relax']]
bp_mean_2006=bp_2006.groupby('smoke').mean()
bp_mean_2006
# Out:
#        b_press_contract  b_press_relax
# smoke
# 1.0          120.854169      75.104152
# 2.0          124.987462      78.126619
# 3.0          123.310044      77.386429

# %%
bp_mean_2006.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['smoke','b_press_contract','b_press_relax']]
bp_mean_2007=bp_2007.groupby('smoke').mean()
bp_mean_2007
# Out:
#        b_press_contract  b_press_relax
# smoke
# 1.0          120.803482      75.083333
# 2.0          124.851173      78.018453
# 3.0          123.208762      77.343277

# %%
bp_mean_2007.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['smoke','b_press_contract','b_press_relax']]
bp_mean_2008=bp_2008.groupby('smoke').mean()
bp_mean_2008
# Out:
#        b_press_contract  b_press_relax
# smoke
# 1.0          120.495021      74.983199
# 2.0          124.673863      78.036539
# 3.0          122.944489      77.281788

# %%
bp_mean_2008.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %% [markdown]
# ### (7) blood press by alcohol

# %%
#2005
bp_2005=GJ_2009[['alcohol','b_press_contract','b_press_relax']]
bp_mean_2005=bp_2005.groupby('alcohol').mean()
bp_mean_2005
# Out:
#          b_press_contract  b_press_relax
# alcohol
# 0.0            121.615547      75.422892
# 1.0            123.018598      77.186520

# %%
bp_mean_2005.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['alcohol','b_press_contract','b_press_relax']]
bp_mean_2006=bp_2006.groupby('alcohol').mean()
bp_mean_2006
# Out:
#          b_press_contract  b_press_relax
# alcohol
# 0.0            121.257206      75.162666
# 1.0            122.994806      77.163764

# %%
bp_mean_2006.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['alcohol','b_press_contract','b_press_relax']]
bp_mean_2007=bp_2007.groupby('alcohol').mean()
bp_mean_2007
# Out:
#          b_press_contract  b_press_relax
# alcohol
# 0.0            121.282232      75.161316
# 1.0            122.826796      77.086560

# %%
bp_mean_2007.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['alcohol','b_press_contract','b_press_relax']]
bp_mean_2008=bp_2008.groupby('alcohol').mean()
bp_mean_2008
# Out:
#          b_press_contract  b_press_relax
# alcohol
# 0.0            120.959567      75.035034
# 1.0            122.591375      77.064987

# %%
bp_mean_2008.plot.bar(y=['b_press_contract','b_press_relax'],figsize=((10,5)))

# %% [markdown]
# ## (B) visual

# %% [markdown]
# ### (1) visual by sex

# %%
#2005
bp_2005=GJ_2009[['sex','visual_left','visual_right']]
bp_mean_2005=bp_2005.groupby('sex').mean()
bp_mean_2005
# Out:
#      visual_left  visual_right
# sex
# 1       1.040859      1.038366
# 2       0.901227      0.899047

# %%
bp_mean_2005.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['sex','visual_left','visual_right']]
bp_mean_2006=bp_2006.groupby('sex').mean()
bp_mean_2006
# Out:
#      visual_left  visual_right
# sex
# 1       1.044509      1.042055
# 2       0.918828      0.916673

# %%
bp_mean_2006.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['sex','visual_left','visual_right']]
bp_mean_2007=bp_2007.groupby('sex').mean()
bp_mean_2007
# Out:
#      visual_left  visual_right
# sex
# 1       1.044338      1.043480
# 2       0.919396      0.914863

# %%
bp_mean_2007.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['sex','visual_left','visual_right']]
bp_mean_2008=bp_2008.groupby('sex').mean()
bp_mean_2008
# Out:
#      visual_left  visual_right
# sex
# 1       1.042565      1.039388
# 2       0.921386      0.917677

# %%
bp_mean_2008.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %% [markdown]
# ### (2) visual by age

# %%
#2005
bp_2005=GJ_2009[['age','visual_left','visual_right']]
bp_mean_2005=bp_2005.groupby('age').mean()
bp_mean_2005
# Out:
#      visual_left  visual_right
# age
# 1       1.038045      1.033658
# 2       1.063906      1.059832
# 3       1.105051      1.102706
# 4       1.134313      1.128487
# 5       1.080617      1.074579
# 6       1.009659      1.004701
# 7       0.945328      0.945573
# 8       0.889939      0.889932
# 9       0.819557      0.819847
# 10      0.749354      0.749006
# 11      0.704998      0.706640
# 12      0.658856      0.680577

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='age',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['age','visual_left','visual_right']]
bp_mean_2006=bp_2006.groupby('age').mean()
bp_mean_2006
# Out:
#      visual_left  visual_right
# age
# 1       1.042470      1.035106
# 2       1.070400      1.063723
# 3       1.106289      1.102340
# 4       1.133106      1.130164
# 5       1.088723      1.084929
# 6       1.018714      1.015115
# 7       0.960681      0.956491
# 8       0.905411      0.905620
# 9       0.840275      0.844342
# 10      0.773352      0.774361
# 11      0.712833      0.719944
# 12      0.705951      0.703094

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='age',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['age','visual_left','visual_right']]
bp_mean_2007=bp_2007.groupby('age').mean()
bp_mean_2007
# Out:
#      visual_left  visual_right
# age
# 1       1.042239      1.038326
# 2       1.067723      1.063413
# 3       1.101988      1.097923
# 4       1.131655      1.128401
# 5       1.087950      1.083117
# 6       1.018727      1.014590
# 7       0.960479      0.959397
# 8       0.908874      0.907478
# 9       0.839937      0.841000
# 10      0.791504      0.794574
# 11      0.735056      0.731122
# 12      0.708722      0.715584

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='age',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['age','visual_left','visual_right']]
bp_mean_2008=bp_2008.groupby('age').mean()
bp_mean_2008
# Out:
#      visual_left  visual_right
# age
# 1       1.055074      1.045065
# 2       1.074997      1.067909
# 3       1.100843      1.095273
# 4       1.132640      1.126611
# 5       1.087359      1.080287
# 6       1.015214      1.014369
# 7       0.967010      0.963992
# 8       0.914914      0.914702
# 9       0.849844      0.849242
# 10      0.797849      0.792177
# 11      0.743796      0.743428
# 12      0.714276      0.734789

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='age',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (3) visual by height

# %%
#2005
bp_2005=GJ_2009[['height','visual_left','visual_right']]
bp_mean_2005=bp_2005.groupby('height').mean()
bp_mean_2005
# Out:
#         visual_left  visual_right
# height
# 145        0.759938      0.762496
# 150        0.844903      0.844558
# 155        0.908702      0.906365
# 160        0.961000      0.956805
# 165        1.015369      1.013234
# 170        1.067815      1.065363
# 175        1.102055      1.098882
# 180        1.120353      1.117426

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='height',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['height','visual_left','visual_right']]
bp_mean_2006=bp_2006.groupby('height').mean()
bp_mean_2006
# Out:
#         visual_left  visual_right
# height
# 145        0.774070      0.778971
# 150        0.859033      0.862808
# 155        0.926184      0.920852
# 160        0.972774      0.968397
# 165        1.018800      1.018013
# 170        1.071011      1.066986
# 175        1.100199      1.097275
# 180        1.120742      1.119742

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='height',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['height','visual_left','visual_right']]
bp_mean_2007=bp_2007.groupby('height').mean()
bp_mean_2007
# Out:
#         visual_left  visual_right
# height
# 145        0.785154      0.788623
# 150        0.865102      0.858637
# 155        0.924120      0.923470
# 160        0.970935      0.964711
# 165        1.019394      1.016764
# 170        1.067751      1.067434
# 175        1.099290      1.098386
# 180        1.114955      1.115145

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='height',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['height','visual_left','visual_right']]
bp_mean_2008=bp_2008.groupby('height').mean()
bp_mean_2008
# Out:
#         visual_left  visual_right
# height
# 145        0.790636      0.796440
# 150        0.864405      0.858786
# 155        0.924679      0.920331
# 160        0.970338      0.968202
# 165        1.019581      1.013044
# 170        1.062695      1.060256
# 175        1.098587      1.096598
# 180        1.121059      1.120704

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='height',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (4) visual by weight

# %%
#2005
bp_2005=GJ_2009[['weight','visual_left','visual_right']]
bp_mean_2005=bp_2005.groupby('weight').mean()
bp_mean_2005
# Out:
#         visual_left  visual_right
# weight
# 45         0.911688      0.912826
# 50         0.920477      0.917810
# 55         0.930933      0.928283
# 60         0.960622      0.958795
# 65         0.997619      0.995123
# 70         1.028198      1.027943
# 75         1.054763      1.047621
# 80         1.070497      1.066841
# 85         1.082479      1.080853
# 90         1.090661      1.086500

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='weight',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['weight','visual_left','visual_right']]
bp_mean_2006=bp_2006.groupby('weight').mean()
bp_mean_2006
# Out:
#         visual_left  visual_right
# weight
# 45         0.930146      0.927854
# 50         0.936989      0.934887
# 55         0.944579      0.942751
# 60         0.967111      0.967658
# 65         1.002006      0.998464
# 70         1.033465      1.030486
# 75         1.055274      1.050628
# 80         1.075543      1.070319
# 85         1.089408      1.089284
# 90         1.100421      1.095444

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='weight',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['weight','visual_left','visual_right']]
bp_mean_2007=bp_2007.groupby('weight').mean()
bp_mean_2007
# Out:
#         visual_left  visual_right
# weight
# 45         0.928912      0.924440
# 50         0.936221      0.932670
# 55         0.943401      0.939922
# 60         0.967350      0.967686
# 65         1.003414      1.000065
# 70         1.032010      1.028349
# 75         1.055774      1.054299
# 80         1.069914      1.071424
# 85         1.087076      1.082534
# 90         1.095230      1.092446

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='weight',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['weight','visual_left','visual_right']]
bp_mean_2008=bp_2008.groupby('weight').mean()
bp_mean_2008
# Out:
#         visual_left  visual_right
# weight
# 45         0.932082      0.930993
# 50         0.936598      0.933186
# 55         0.942747      0.939106
# 60         0.968563      0.964402
# 65         1.000486      0.996594
# 70         1.032044      1.029742
# 75         1.051904      1.049522
# 80         1.068371      1.062098
# 85         1.082690      1.079241
# 90         1.093981      1.090215

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='weight',y=['visual_left','visual_right'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (5) visual by city

# %%
#2005
bp_2005=GJ_2009[['city','visual_left','visual_right']]
bp_mean_2005=bp_2005.groupby('city').mean()
bp_mean_2005
# Out:
#       visual_left  visual_right
# city
# 11       0.947172      0.944794
# 26       0.940500      0.939095
# 27       0.961536      0.954950
# 28       0.990861      0.984972
# 29       0.999449      0.995896
# 30       0.998043      0.993283
# 31       0.970851      0.971742
# 41       0.996563      0.995009
# 42       0.986619      0.984660
# 43       0.996485      0.991792
# 44       1.029518      1.023408
# 45       1.020083      1.012821
# 46       0.972470      0.978911
# 47       0.984178      0.982248
# 48       0.988107      0.987979
# 49       0.960288      0.962234

# %%
bp_mean_2005.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['city','visual_left','visual_right']]
bp_mean_2006=bp_2006.groupby('city').mean()
bp_mean_2006
# Out:
#       visual_left  visual_right
# city
# 11       0.958496      0.958369
# 26       0.952480      0.952900
# 27       0.969423      0.968867
# 28       0.998835      0.988996
# 29       1.012148      1.011912
# 30       1.011817      1.001882
# 31       0.940945      0.937984
# 41       1.005197      1.001070
# 42       0.999111      1.002909
# 43       1.017088      1.015157
# 44       1.038617      1.032606
# 45       1.030339      1.027550
# 46       0.989117      0.987878
# 47       0.993675      0.989062
# 48       0.991896      0.994805
# 49       0.967190      0.967878

# %%
bp_mean_2006.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['city','visual_left','visual_right']]
bp_mean_2007=bp_2007.groupby('city').mean()
bp_mean_2007
# Out:
#       visual_left  visual_right
# city
# 11       0.961059      0.958282
# 26       0.948024      0.947471
# 27       0.957542      0.960322
# 28       1.006060      1.002482
# 29       1.025448      1.025333
# 30       1.004564      0.998271
# 31       0.952207      0.958180
# 41       1.013617      1.008706
# 42       0.982958      0.988772
# 43       1.010712      1.002778
# 44       1.032649      1.034787
# 45       1.023769      1.016262
# 46       0.970655      0.971199
# 47       0.981650      0.972777
# 48       0.994337      0.997449
# 49       0.948025      0.932060

# %%
bp_mean_2007.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['city','visual_left','visual_right']]
bp_mean_2008=bp_2008.groupby('city').mean()
bp_mean_2008
# Out:
#       visual_left  visual_right
# city
# 11       0.959600      0.956863
# 26       0.942971      0.942683
# 27       0.957784      0.957780
# 28       1.021116      1.016065
# 29       1.013635      1.011264
# 30       1.009096      1.002138
# 31       0.980826      0.979443
# 36       1.005900      1.001672
# 41       1.009214      1.005730
# 42       0.991587      0.995667
# 43       1.009015      0.999161
# 44       1.031166      1.023416
# 45       1.015135      1.015289
# 46       0.976064      0.973032
# 47       0.975199      0.966938
# 48       0.995460      0.990960
# 49       0.919298      0.913618

# %%
bp_mean_2008.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %% [markdown]
# ### (6) visual by smoke

# %%
#2005
bp_2005=GJ_2009[['smoke','visual_left','visual_right']]
bp_mean_2005=bp_2005.groupby('smoke').mean()
bp_mean_2005
# Out:
#        visual_left  visual_right
# smoke
# 1.0       0.937023      0.935689
# 2.0       1.018600      1.015247
# 3.0       1.052612      1.048690

# %%
bp_mean_2005.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['smoke','visual_left','visual_right']]
bp_mean_2006=bp_2006.groupby('smoke').mean()
bp_mean_2006
# Out:
#        visual_left  visual_right
# smoke
# 1.0       0.951788      0.949524
# 2.0       1.025706      1.021484
# 3.0       1.053668      1.052337

# %%
bp_mean_2006.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['smoke','visual_left','visual_right']]
bp_mean_2007=bp_2007.groupby('smoke').mean()
bp_mean_2007
# Out:
#        visual_left  visual_right
# smoke
# 1.0       0.952263      0.948685
# 2.0       1.020155      1.021676
# 3.0       1.053608      1.051235

# %%
bp_mean_2007.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['smoke','visual_left','visual_right']]
bp_mean_2008=bp_2008.groupby('smoke').mean()
bp_mean_2008
# Out:
#        visual_left  visual_right
# smoke
# 1.0       0.953803      0.950462
# 2.0       1.017957      1.013408
# 3.0       1.051308      1.048424

# %%
bp_mean_2008.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %% [markdown]
# ### (7) visual by alcohol

# %%
#2005
bp_2005=GJ_2009[['alcohol','visual_left','visual_right']]
bp_mean_2005=bp_2005.groupby('alcohol').mean()
bp_mean_2005
# Out:
#          visual_left  visual_right
# alcohol
# 0.0         0.929647      0.927839
# 1.0         1.030745      1.027770

# %%
bp_mean_2005.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['alcohol','visual_left','visual_right']]
bp_mean_2006=bp_2006.groupby('alcohol').mean()
bp_mean_2006
# Out:
#          visual_left  visual_right
# alcohol
# 0.0         0.943657      0.941882
# 1.0         1.035855      1.032969

# %%
bp_mean_2006.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['alcohol','visual_left','visual_right']]
bp_mean_2007=bp_2007.groupby('alcohol').mean()
bp_mean_2007
# Out:
#          visual_left  visual_right
# alcohol
# 0.0         0.942038      0.940733
# 1.0         1.035914      1.032256

# %%
bp_mean_2007.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['alcohol','visual_left','visual_right']]
bp_mean_2008=bp_2008.groupby('alcohol').mean()
bp_mean_2008
# Out:
#          visual_left  visual_right
# alcohol
# 0.0         0.942811      0.940327
# 1.0         1.034623      1.030250

# %%
bp_mean_2008.plot.bar(y=['visual_left','visual_right'],figsize=((10,5)))

# %% [markdown]
# ## (C) blood sugar

# %% [markdown]
# ### (1) blood sugar by sex

# %%
#2005
bp_2005=GJ_2009[['sex','b_sugar']]
bp_mean_2005=bp_2005.groupby('sex').mean()
bp_mean_2005
# Out:
#        b_sugar
# sex
# 1    98.959872
# 2    95.053738

# %%
bp_mean_2005.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['sex','b_sugar']]
bp_mean_2006=bp_2006.groupby('sex').mean()
bp_mean_2006
# Out:
#        b_sugar
# sex
# 1    99.351760
# 2    94.932271

# %%
bp_mean_2006.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['sex','b_sugar']]
bp_mean_2007=bp_2007.groupby('sex').mean()
bp_mean_2007
# Out:
#        b_sugar
# sex
# 1    99.348118
# 2    94.952267

# %%
bp_mean_2007.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['sex','b_sugar']]
bp_mean_2008=bp_2008.groupby('sex').mean()
bp_mean_2008
# Out:
#        b_sugar
# sex
# 1    99.802924
# 2    95.237524

# %%
bp_mean_2008.plot.bar(y='b_sugar',figsize=((10,5)))

# %% [markdown]
# ### (2) blood sugar by age

# %%
#2005
bp_2005=GJ_2009[['age','b_sugar']]
bp_mean_2005=bp_2005.groupby('age').mean()
bp_mean_2005
# Out:
#         b_sugar
# age
# 1     87.131597
# 2     88.636282
# 3     91.334147
# 4     93.951632
# 5     95.835063
# 6     98.026314
# 7    100.030077
# 8    102.595063
# 9    103.153705
# 10   103.888015
# 11   103.858700
# 12   103.963981

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='age',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['age','b_sugar']]
bp_mean_2006=bp_2006.groupby('age').mean()
bp_mean_2006
# Out:
#         b_sugar
# age
# 1     86.967718
# 2     88.470743
# 3     91.028208
# 4     93.597534
# 5     95.664913
# 6     97.981431
# 7    100.084130
# 8    102.546495
# 9    103.495734
# 10   104.321721
# 11   104.537521
# 12   104.689800

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='age',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['age','b_sugar']]
bp_mean_2007=bp_2007.groupby('age').mean()
bp_mean_2007
# Out:
#         b_sugar
# age
# 1     87.342929
# 2     88.526272
# 3     91.079117
# 4     93.991975
# 5     95.569238
# 6     98.119296
# 7     99.987805
# 8    102.071414
# 9    103.249383
# 10   103.904509
# 11   104.316792
# 12   104.154602

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='age',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['age','b_sugar']]
bp_mean_2008=bp_2008.groupby('age').mean()
bp_mean_2008
# Out:
#         b_sugar
# age
# 1     87.507409
# 2     88.655394
# 3     91.166402
# 4     93.854895
# 5     95.635167
# 6     98.210474
# 7    100.252649
# 8    102.304866
# 9    103.373454
# 10   104.093453
# 11   104.433474
# 12   104.668581

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='age',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (3) blood sugar by weight

# %%
#2005
bp_2005=GJ_2009[['weight','b_sugar']]
bp_mean_2005=bp_2005.groupby('weight').mean()
bp_mean_2005
# Out:
#            b_sugar
# weight
# 45       91.891724
# 50       93.636779
# 55       95.635008
# 60       97.516997
# 65       98.726471
# 70       99.449905
# 75      100.095259
# 80      100.690043
# 85      100.815626
# 90      101.131345

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='weight',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['weight','b_sugar']]
bp_mean_2006=bp_2006.groupby('weight').mean()
bp_mean_2006
# Out:
#            b_sugar
# weight
# 45       91.730350
# 50       93.490872
# 55       95.533122
# 60       97.631674
# 65       98.978320
# 70       99.772883
# 75      100.505773
# 80      101.141238
# 85      101.495094
# 90      101.571717

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='weight',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['weight','b_sugar']]
bp_mean_2007=bp_2007.groupby('weight').mean()
bp_mean_2007
# Out:
#            b_sugar
# weight
# 45       91.771450
# 50       93.418126
# 55       95.628252
# 60       97.563695
# 65       98.858215
# 70       99.758720
# 75      100.432841
# 80      101.189710
# 85      101.349580
# 90      101.682458

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='weight',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['weight','b_sugar']]
bp_mean_2008=bp_2008.groupby('weight').mean()
bp_mean_2008
# Out:
#            b_sugar
# weight
# 45       92.154375
# 50       93.647512
# 55       95.899589
# 60       97.925761
# 65       99.181745
# 70      100.144643
# 75      101.021845
# 80      101.501185
# 85      102.044843
# 90      102.904247

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='weight',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (4) blood sugar by height

# %%
#2005
bp_2005=GJ_2009[['height','b_sugar']]
bp_mean_2005=bp_2005.groupby('height').mean()
bp_mean_2005
# Out:
#           b_sugar
# height
# 145     99.442256
# 150     97.576038
# 155     96.090429
# 160     96.861768
# 165     98.578634
# 170     97.824398
# 175     95.952147
# 180     94.074926

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='height',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['height','b_sugar']]
bp_mean_2006=bp_2006.groupby('height').mean()
bp_mean_2006
# Out:
#            b_sugar
# height
# 145     100.022748
# 150      97.617965
# 155      95.933206
# 160      96.816239
# 165      98.754648
# 170      98.231629
# 175      96.460163
# 180      94.632630

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='height',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['height','b_sugar']]
bp_mean_2007=bp_2007.groupby('height').mean()
bp_mean_2007
# Out:
#           b_sugar
# height
# 145     99.666303
# 150     97.591015
# 155     95.973137
# 160     96.762517
# 165     98.723248
# 170     98.309388
# 175     96.558208
# 180     94.862222

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='height',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['height','b_sugar']]
bp_mean_2008=bp_2008.groupby('height').mean()
bp_mean_2008
# Out:
#            b_sugar
# height
# 145     100.011055
# 150      97.853779
# 155      96.292956
# 160      97.022584
# 165      99.137849
# 170      98.760705
# 175      97.015909
# 180      95.301666

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='height',y='b_sugar',linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (5) blood sugar by city

# %%
#2005
bp_2005=GJ_2009[['city','b_sugar']]
bp_mean_2005=bp_2005.groupby('city').mean()
bp_mean_2005=bp_mean_2005.sort_values('b_sugar',ascending=True)
bp_mean_2005
# Out:
#         b_sugar
# city
# 27    95.208935
# 11    96.610123
# 43    96.679008
# 47    96.765878
# 41    96.776174
# 45    96.889249
# 44    97.199166
# 30    97.454769
# 28    97.640070
# 42    97.922305
# 31    98.075592
# 48    98.118984
# 49    98.495388
# 26    98.572581
# 29    99.326544
# 46    99.699798

# %%
bp_mean_2005.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['city','b_sugar']]
bp_mean_2006=bp_2006.groupby('city').mean()
bp_mean_2006=bp_mean_2006.sort_values('b_sugar',ascending=True)
bp_mean_2006
# Out:
#         b_sugar
# city
# 27    96.216903
# 47    96.411158
# 43    96.689025
# 41    96.702233
# 11    96.730335
# 30    97.172632
# 45    97.746363
# 42    97.788035
# 28    97.912820
# 44    98.220974
# 48    98.325725
# 29    98.580173
# 26    98.635491
# 31    98.962155
# 49    99.842443
# 46    99.974239

# %%
bp_mean_2006.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['city','b_sugar']]
bp_mean_2007=bp_2007.groupby('city').mean()
bp_mean_2007=bp_mean_2007.sort_values('b_sugar',ascending=True)
bp_mean_2007
# Out:
#          b_sugar
# city
# 43     96.503298
# 47     96.580992
# 41     96.670698
# 11     96.685119
# 27     96.688539
# 30     96.755059
# 28     97.232421
# 45     97.855160
# 29     98.226128
# 44     98.291033
# 26     98.303576
# 49     98.318888
# 48     98.368830
# 42     98.437906
# 31     99.268591
# 46    100.993606

# %%
bp_mean_2007.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['city','b_sugar']]
bp_mean_2008=bp_2008.groupby('city').mean()
bp_mean_2008=bp_mean_2008.sort_values('b_sugar',ascending=True)
bp_mean_2008
# Out:
#          b_sugar
# city
# 41     96.935661
# 27     96.978970
# 11     96.984821
# 30     97.102695
# 47     97.341176
# 36     97.514258
# 43     97.517954
# 49     98.027220
# 28     98.106037
# 31     98.273793
# 44     98.314032
# 26     98.352994
# 48     98.478918
# 45     98.505313
# 42     98.776716
# 29     99.103005
# 46    101.911833

# %%
bp_mean_2008.plot.bar(y='b_sugar',figsize=((10,5)))

# %% [markdown]
# ### (6) blood sugar by smoke

# %%
#2005
bp_2005=GJ_2009[['smoke','b_sugar']]
bp_mean_2005=bp_2005.groupby('smoke').mean()
bp_mean_2005
# Out:
#           b_sugar
# smoke
# 1.0     96.157385
# 2.0    100.133701
# 3.0     98.074303

# %%
bp_mean_2005.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['smoke','b_sugar']]
bp_mean_2006=bp_2006.groupby('smoke').mean()
bp_mean_2006
# Out:
#           b_sugar
# smoke
# 1.0     96.077232
# 2.0    100.640490
# 3.0     98.515830

# %%
bp_mean_2006.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['smoke','b_sugar']]
bp_mean_2007=bp_2007.groupby('smoke').mean()
bp_mean_2007
# Out:
#           b_sugar
# smoke
# 1.0     96.026919
# 2.0    100.602536
# 3.0     98.578674

# %%
bp_mean_2007.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['smoke','b_sugar']]
bp_mean_2008=bp_2008.groupby('smoke').mean()
bp_mean_2008
# Out:
#           b_sugar
# smoke
# 1.0     96.305592
# 2.0    101.058948
# 3.0     99.100491

# %%
bp_mean_2008.plot.bar(y='b_sugar',figsize=((10,5)))

# %% [markdown]
# ### (7) blood sugar by alcohol

# %%
#2005
bp_2005=GJ_2009[['alcohol','b_sugar']]
bp_mean_2005=bp_2005.groupby('alcohol').mean()
bp_mean_2005
# Out:
#            b_sugar
# alcohol
# 0.0      97.014851
# 1.0      97.491410

# %%
bp_mean_2005.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['alcohol','b_sugar']]
bp_mean_2006=bp_2006.groupby('alcohol').mean()
bp_mean_2006
# Out:
#            b_sugar
# alcohol
# 0.0      97.029486
# 1.0      97.779209

# %%
bp_mean_2006.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['alcohol','b_sugar']]
bp_mean_2007=bp_2007.groupby('alcohol').mean()
bp_mean_2007
# Out:
#            b_sugar
# alcohol
# 0.0      97.031638
# 1.0      97.761332

# %%
bp_mean_2007.plot.bar(y='b_sugar',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['alcohol','b_sugar']]
bp_mean_2008=bp_2008.groupby('alcohol').mean()
bp_mean_2008
# Out:
#            b_sugar
# alcohol
# 0.0      97.336809
# 1.0      98.180137

# %%
bp_mean_2008.plot.bar(y='b_sugar',figsize=((10,5)))

# %% [markdown]
# ## (D) cholesterol

# %% [markdown]
# ### (1) cholesterol by sex

# %%
#2005
bp_2005=GJ_2009[['sex','cholesterol']]
bp_mean_2005=bp_2005.groupby('sex').mean()
bp_mean_2005
# Out:
#      cholesterol
# sex
# 1     194.311249
# 2     195.966424

# %%
bp_mean_2005.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['sex','cholesterol']]
bp_mean_2006=bp_2006.groupby('sex').mean()
bp_mean_2006
# Out:
#      cholesterol
# sex
# 1     194.358874
# 2     195.522925

# %%
bp_mean_2006.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['sex','cholesterol']]
bp_mean_2007=bp_2007.groupby('sex').mean()
bp_mean_2007
# Out:
#      cholesterol
# sex
# 1     193.718834
# 2     195.091228

# %%
bp_mean_2007.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['sex','cholesterol']]
bp_mean_2008=bp_2008.groupby('sex').mean()
bp_mean_2008
# Out:
#      cholesterol
# sex
# 1      193.97393
# 2      195.62527

# %%
bp_mean_2008.plot.bar(y='cholesterol',figsize=((10,5)))

# %% [markdown]
# ### (2) cholesterol by age

# %%
#2005
bp_2005=GJ_2009[['age','cholesterol']]
bp_mean_2005=bp_2005.groupby('age').mean()
bp_mean_2005
# Out:
#      cholesterol
# age
# 1     171.898256
# 2     180.157967
# 3     188.653013
# 4     193.092803
# 5     194.104570
# 6     198.182734
# 7     203.237657
# 8     203.089023
# 9     201.314598
# 10    198.169456
# 11    196.814480
# 12    196.139413

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='age',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['age','cholesterol']]
bp_mean_2006=bp_2006.groupby('age').mean()
bp_mean_2006
# Out:
#      cholesterol
# age
# 1     170.307692
# 2     179.498318
# 3     187.839737
# 4     192.311093
# 5     194.164602
# 6     198.025036
# 7     202.804629
# 8     202.786885
# 9     200.002146
# 10    197.611451
# 11    196.023535
# 12    195.056504

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='age',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['age','cholesterol']]
bp_mean_2007=bp_2007.groupby('age').mean()
bp_mean_2007
# Out:
#      cholesterol
# age
# 1     170.073715
# 2     179.315362
# 3     187.921362
# 4     192.699165
# 5     193.983838
# 6     197.591390
# 7     202.190867
# 8     201.798730
# 9     198.886346
# 10    195.353176
# 11    193.514233
# 12    192.321096

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='age',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['age','cholesterol']]
bp_mean_2008=bp_2008.groupby('age').mean()
bp_mean_2008
# Out:
#      cholesterol
# age
# 1     170.775123
# 2     179.766767
# 3     188.112064
# 4     193.022466
# 5     194.993421
# 6     198.178062
# 7     202.244120
# 8     201.210700
# 9     198.208977
# 10    194.649408
# 11    192.349779
# 12    190.525470

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='age',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (3) cholesterol by weight

# %%
#2005
bp_2005=GJ_2009[['weight','cholesterol']]
bp_mean_2005=bp_2005.groupby('weight').mean()
bp_mean_2005
# Out:
#         cholesterol
# weight
# 45       187.484938
# 50       190.838886
# 55       193.594092
# 60       194.784120
# 65       195.844270
# 70       197.536474
# 75       198.937788
# 80       201.011575
# 85       202.239509
# 90       203.631025

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='weight',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['weight','cholesterol']]
bp_mean_2006=bp_2006.groupby('weight').mean()
bp_mean_2006
# Out:
#         cholesterol
# weight
# 45       187.563720
# 50       190.856678
# 55       193.196645
# 60       194.704952
# 65       195.761681
# 70       197.041619
# 75       198.683066
# 80       200.434119
# 85       202.242881
# 90       203.704793

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='weight',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['weight','cholesterol']]
bp_mean_2007=bp_2007.groupby('weight').mean()
bp_mean_2007
# Out:
#         cholesterol
# weight
# 45       187.461224
# 50       190.632164
# 55       192.869029
# 60       193.917935
# 65       195.153852
# 70       196.110600
# 75       197.944312
# 80       199.630143
# 85       201.256931
# 90       202.615303

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='weight',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['weight','cholesterol']]
bp_mean_2008=bp_2008.groupby('weight').mean()
bp_mean_2008
# Out:
#         cholesterol
# weight
# 45       188.659952
# 50       191.353433
# 55       193.419841
# 60       194.334978
# 65       195.235483
# 70       196.385783
# 75       197.994518
# 80       199.545214
# 85       201.267953
# 90       203.118349

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='weight',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (4) cholesterol by height

# %%
#2005
bp_2005=GJ_2009[['height','cholesterol']]
bp_mean_2005=bp_2005.groupby('height').mean()
bp_mean_2005
# Out:
#         cholesterol
# height
# 145      206.552554
# 150      202.262239
# 155      196.397037
# 160      192.480368
# 165      193.490994
# 170      193.899979
# 175      191.831409
# 180      188.871887

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='height',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['height','cholesterol']]
bp_mean_2006=bp_2006.groupby('height').mean()
bp_mean_2006
# Out:
#         cholesterol
# height
# 145      206.038923
# 150      201.692424
# 155      196.288747
# 160      192.381258
# 165      193.283812
# 170      194.059990
# 175      192.194694
# 180      188.584429

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='height',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['height','cholesterol']]
bp_mean_2007=bp_2007.groupby('height').mean()
bp_mean_2007
# Out:
#         cholesterol
# height
# 145      204.474082
# 150      200.944409
# 155      195.724914
# 160      191.816970
# 165      192.710086
# 170      193.645752
# 175      191.901177
# 180      188.881111

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='height',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['height','cholesterol']]
bp_mean_2008=bp_2008.groupby('height').mean()
bp_mean_2008
# Out:
#         cholesterol
# height
# 145      203.593015
# 150      201.109761
# 155      196.239328
# 160      192.403371
# 165      193.029084
# 170      194.084722
# 175      192.505346
# 180      189.362208

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='height',y='cholesterol',linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (5) cholesterol by city

# %%
#2005
bp_2005=GJ_2009[['city','cholesterol']]
bp_mean_2005=bp_2005.groupby('city').mean()
bp_mean_2005
# Out:
#       cholesterol
# city
# 11     195.588756
# 26     196.720791
# 27     193.966171
# 28     195.119704
# 29     193.768575
# 30     194.640092
# 31     196.317369
# 41     194.968196
# 42     193.345213
# 43     193.807985
# 44     193.671587
# 45     193.656571
# 46     197.151452
# 47     195.002076
# 48     194.859775
# 49     192.043082

# %%
bp_mean_2005.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['city','cholesterol']]
bp_mean_2006=bp_2006.groupby('city').mean()
bp_mean_2006
# Out:
#       cholesterol
# city
# 11     195.025917
# 26     196.746362
# 27     192.988295
# 28     195.088184
# 29     193.942952
# 30     193.403132
# 31     195.638084
# 41     194.909175
# 42     193.085011
# 43     195.629777
# 44     193.420370
# 45     194.153245
# 46     197.419769
# 47     193.821651
# 48     195.439910
# 49     194.725224

# %%
bp_mean_2006.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['city','cholesterol']]
bp_mean_2007=bp_2007.groupby('city').mean()
bp_mean_2007
# Out:
#       cholesterol
# city
# 11     194.240922
# 26     196.504381
# 27     192.404349
# 28     194.502238
# 29     193.350924
# 30     192.256780
# 31     196.219632
# 41     193.921305
# 42     192.330918
# 43     194.771343
# 44     193.492856
# 45     194.152008
# 46     196.811336
# 47     193.626168
# 48     195.726449
# 49     195.782885

# %%
bp_mean_2007.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['city','cholesterol']]
bp_mean_2008=bp_2008.groupby('city').mean()
bp_mean_2008
# Out:
#       cholesterol
# city
# 11     194.441720
# 26     196.726212
# 27     193.255241
# 28     194.265511
# 29     194.280295
# 30     191.895346
# 31     196.918101
# 36     191.719272
# 41     194.458087
# 42     192.688458
# 43     194.816369
# 44     193.579489
# 45     194.571827
# 46     197.625880
# 47     194.317263
# 48     196.393446
# 49     195.878718

# %%
bp_mean_2008.plot.bar(y='cholesterol',figsize=((10,5)))

# %% [markdown]
# ### (6) cholesterol by smoke

# %%
#2005
bp_2005=GJ_2009[['smoke','cholesterol']]
bp_mean_2005=bp_2005.groupby('smoke').mean()
bp_mean_2005
# Out:
#        cholesterol
# smoke
# 1.0     195.035313
# 2.0     196.171811
# 3.0     194.441996

# %%
bp_mean_2005.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['smoke','cholesterol']]
bp_mean_2006=bp_2006.groupby('smoke').mean()
bp_mean_2006
# Out:
#        cholesterol
# smoke
# 1.0     194.615264
# 2.0     195.998479
# 3.0     194.789341

# %%
bp_mean_2006.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['smoke','cholesterol']]
bp_mean_2007=bp_2007.groupby('smoke').mean()
bp_mean_2007
# Out:
#        cholesterol
# smoke
# 1.0     194.097141
# 2.0     195.185193
# 3.0     194.332471

# %%
bp_mean_2007.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['smoke','cholesterol']]
bp_mean_2008=bp_2008.groupby('smoke').mean()
bp_mean_2008
# Out:
#        cholesterol
# smoke
# 1.0     194.525739
# 2.0     195.319837
# 3.0     194.779774

# %%
bp_mean_2008.plot.bar(y='cholesterol',figsize=((10,5)))

# %% [markdown]
# ### (7) cholesterol by alcohol

# %%
#2005
bp_2005=GJ_2009[['alcohol','cholesterol']]
bp_mean_2005=bp_2005.groupby('alcohol').mean()
bp_mean_2005
# Out:
#          cholesterol
# alcohol
# 0.0       196.091038
# 1.0       194.029643

# %%
bp_mean_2005.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['alcohol','cholesterol']]
bp_mean_2006=bp_2006.groupby('alcohol').mean()
bp_mean_2006
# Out:
#          cholesterol
# alcohol
# 0.0       195.578453
# 1.0       194.146942

# %%
bp_mean_2006.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['alcohol','cholesterol']]
bp_mean_2007=bp_2007.groupby('alcohol').mean()
bp_mean_2007
# Out:
#          cholesterol
# alcohol
# 0.0       194.979755
# 1.0       193.671201

# %%
bp_mean_2007.plot.bar(y='cholesterol',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['alcohol','cholesterol']]
bp_mean_2008=bp_2008.groupby('alcohol').mean()
bp_mean_2008
# Out:
#          cholesterol
# alcohol
# 0.0       195.170798
# 1.0       194.248216

# %%
bp_mean_2008.plot.bar(y='cholesterol',figsize=((10,5)))

# %% [markdown]
# ## (E) liver function

# %% [markdown]
# ### (1) liver function by sex

# %%
#2005
bp_2005=GJ_2009[['sex','got_ast','got_alt','gtp']]
bp_mean_2005=bp_2005.groupby('sex').mean()
bp_mean_2005
# Out:
#        got_ast    got_alt        gtp
# sex
# 1    27.263373  29.478649  48.515228
# 2    22.845835  20.081812  22.047980

# %%
bp_mean_2005.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['sex','got_ast','got_alt','gtp']]
bp_mean_2006=bp_2006.groupby('sex').mean()
bp_mean_2006
# Out:
#        got_ast    got_alt        gtp
# sex
# 1    27.035813  29.154941  48.018875
# 2    22.727596  19.913975  21.883895

# %%
bp_mean_2006.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['sex','got_ast','got_alt','gtp']]
bp_mean_2007=bp_2007.groupby('sex').mean()
bp_mean_2007
# Out:
#        got_ast    got_alt        gtp
# sex
# 1    27.000959  28.855199  48.287592
# 2    22.738296  19.642549  22.065295

# %%
bp_mean_2007.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['sex','got_ast','got_alt','gtp']]
bp_mean_2008=bp_2008.groupby('sex').mean()
bp_mean_2008
# Out:
#       got_ast    got_alt        gtp
# sex
# 1    27.08849  28.773758  47.963981
# 2    22.98428  19.870136  22.268591

# %%
bp_mean_2008.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((10,5)))

# %% [markdown]
# ### (2) liver function by age

# %%
#2005
bp_2005=GJ_2009[['age','got_ast','got_alt','gtp']]
bp_mean_2005=bp_2005.groupby('age').mean()
bp_mean_2005
# Out:
#        got_ast    got_alt        gtp
# age
# 1    20.833409  17.414972  18.998820
# 2    22.447211  22.189059  26.639202
# 3    24.189178  27.036662  35.050187
# 4    25.054952  28.037830  40.101723
# 5    24.561079  25.514105  37.469874
# 6    25.502652  25.643340  40.059358
# 7    26.473818  26.274926  40.391751
# 8    27.195906  26.562537  41.197064
# 9    27.075542  25.635693  38.630143
# 10   26.912267  24.355893  36.983495
# 11   26.610562  22.959282  34.988209
# 12   26.107627  21.444572  31.970438

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='age',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['age','got_ast','got_alt','gtp']]
bp_mean_2006=bp_2006.groupby('age').mean()
bp_mean_2006
# Out:
#        got_ast    got_alt        gtp
# age
# 1    20.808280  17.477327  18.903999
# 2    22.196761  21.735754  25.767904
# 3    23.594181  26.012592  33.328668
# 4    24.478261  27.194960  38.353398
# 5    24.325655  25.176138  37.173712
# 6    25.264410  25.413608  39.537482
# 7    26.316704  26.020576  40.313882
# 8    27.045836  26.404560  40.917886
# 9    26.894486  25.441891  38.112784
# 10   26.826331  24.221529  36.401063
# 11   26.568686  22.923790  34.347164
# 12   26.042598  21.230338  31.405252

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='age',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['age','got_ast','got_alt','gtp']]
bp_mean_2007=bp_2007.groupby('age').mean()
bp_mean_2007
# Out:
#        got_ast    got_alt        gtp
# age
# 1    20.635093  17.325197  19.306403
# 2    22.072530  21.505783  26.191416
# 3    23.699678  26.037183  34.134587
# 4    24.673908  27.380485  39.702917
# 5    24.237951  24.796421  37.396862
# 6    25.125565  25.086545  39.699092
# 7    26.369115  25.665758  40.310010
# 8    26.845782  25.770842  40.497141
# 9    26.958645  25.055975  37.718658
# 10   26.724577  23.804323  36.080211
# 11   26.395712  22.471940  33.658899
# 12   25.913715  20.757562  31.043563

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='age',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['age','got_ast','got_alt','gtp']]
bp_mean_2008=bp_2008.groupby('age').mean()
bp_mean_2008
# Out:
#        got_ast    got_alt        gtp
# age
# 1    20.740206  17.288043  19.366444
# 2    21.954130  21.244193  25.434458
# 3    23.393116  25.365047  32.853406
# 4    24.152792  26.467243  37.645885
# 5    24.367608  24.979515  37.311725
# 6    25.319556  25.187899  39.637813
# 7    26.589905  25.860361  40.631879
# 8    27.184399  26.141714  40.614156
# 9    27.214859  25.305825  37.753104
# 10   26.856396  24.061382  35.240281
# 11   26.546418  22.506346  33.505308
# 12   25.806560  20.785243  30.776692

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='age',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (3) liver function by city

# %%
#2005
bp_2005=GJ_2009[['city','got_ast','got_alt','gtp']]
bp_mean_2005=bp_2005.groupby('city').mean()
bp_mean_2005
# Out:
#         got_ast    got_alt        gtp
# city
# 11    24.915748  24.648406  35.418762
# 26    25.540719  25.060400  37.708352
# 27    24.909725  25.201425  35.307818
# 28    25.282383  25.607468  38.909428
# 29    24.981142  24.937618  36.408878
# 30    24.917775  25.202182  36.029250
# 31    25.478431  25.506238  36.496030
# 41    25.218153  25.667214  36.670315
# 42    26.455284  26.462340  40.612411
# 43    25.441430  25.477828  37.277373
# 44    25.181026  25.568981  37.886331
# 45    25.533618  25.346386  36.512482
# 46    26.944883  26.224713  39.669419
# 47    25.705839  25.533658  37.025886
# 48    25.420811  25.250458  37.293107
# 49    25.451069  25.846232  36.738133

# %%
bp_mean_2005.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((20,10)))

# %%
#2006
bp_2006=GJ_2010[['city','got_ast','got_alt','gtp']]
bp_mean_2006=bp_2006.groupby('city').mean()
bp_mean_2006
# Out:
#         got_ast    got_alt        gtp
# city
# 11    24.697249  24.284736  35.193489
# 26    25.424105  24.959439  36.658722
# 27    24.606873  24.866302  34.493342
# 28    25.284271  25.550002  38.283537
# 29    25.199963  25.291063  35.376083
# 30    24.495984  24.660651  34.590248
# 31    25.176488  25.268941  36.077293
# 41    25.083891  25.236171  36.436497
# 42    25.927425  25.823234  39.820037
# 43    25.794508  25.577783  37.340344
# 44    24.861728  25.181427  36.924030
# 45    25.226813  25.167881  35.770974
# 46    26.629758  26.307195  39.910507
# 47    25.443857  25.215236  36.488474
# 48    25.141987  25.033983  37.619332
# 49    24.896051  25.661611  37.245498

# %%
bp_mean_2006.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((20,10)))

# %%
#2007
bp_2007=GJ_2011[['city','got_ast','got_alt','gtp']]
bp_mean_2007=bp_2007.groupby('city').mean()
bp_mean_2007
# Out:
#         got_ast    got_alt        gtp
# city
# 11    24.509047  24.047490  35.411536
# 26    25.441483  24.892167  37.249936
# 27    24.869983  24.707168  34.647526
# 28    25.134447  25.052031  38.669605
# 29    25.151385  24.963168  35.501192
# 30    24.104202  24.312781  34.542299
# 31    25.045904  25.125894  36.389662
# 41    24.938126  24.851517  36.685943
# 42    26.194541  25.924429  39.999657
# 43    25.642923  24.859176  37.435916
# 44    25.015677  24.689463  37.534572
# 45    25.368525  24.694157  36.090611
# 46    27.062823  26.160491  40.193466
# 47    25.498157  24.945537  36.094986
# 48    25.362266  24.775131  36.740222
# 49    24.699387  23.879405  36.927665

# %%
bp_mean_2007.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((20,10)))

# %%
#2008
bp_2008=GJ_2012[['city','got_ast','got_alt','gtp']]
bp_mean_2008=bp_2008.groupby('city').mean()
bp_mean_2008
# Out:
#         got_ast    got_alt        gtp
# city
# 11    24.686051  24.210873  35.092733
# 26    25.367642  24.619733  37.529173
# 27    24.884284  24.367371  34.464922
# 28    25.354041  25.079884  38.658138
# 29    25.272848  25.221346  35.606120
# 30    24.731055  24.366878  34.526915
# 31    25.039301  24.708047  35.652970
# 36    24.756146  24.604228  34.827925
# 41    25.021259  24.904020  36.478177
# 42    26.226700  25.651277  39.334163
# 43    25.517552  24.682609  36.687562
# 44    25.371584  24.955623  36.814422
# 45    25.612536  24.579334  36.128281
# 46    26.886995  26.048761  39.279179
# 47    25.922859  24.994067  36.139012
# 48    25.479716  24.860050  36.680601
# 49    25.119569  24.658131  37.996774

# %%
bp_mean_2008.plot.bar(y=['got_ast','got_alt','gtp',],figsize=((20,10)))

# %% [markdown]
# ### (4) liver function by weight

# %%
#2005
bp_2005=GJ_2009[['weight','got_ast','got_alt','gtp']]
bp_mean_2005=bp_2005.groupby('weight').mean()
bp_mean_2005
# Out:
#           got_ast    got_alt        gtp
# weight
# 45      22.396065  17.387559  21.292250
# 50      23.039043  18.844239  24.557356
# 55      23.910256  20.885512  28.580779
# 60      24.865768  23.491001  34.237757
# 65      25.725111  26.305211  40.153393
# 70      26.598443  29.340611  45.612024
# 75      27.676315  32.663667  50.557657
# 80      29.052426  36.675161  54.789320
# 85      30.477281  41.191065  59.492949
# 90      31.958108  45.685265  62.594896

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='weight',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['weight','got_ast','got_alt','gtp']]
bp_mean_2006=bp_2006.groupby('weight').mean()
bp_mean_2006
# Out:
#           got_ast    got_alt        gtp
# weight
# 45      22.313276  17.226626  21.162763
# 50      22.753470  18.523591  23.563301
# 55      23.646525  20.554412  28.055234
# 60      24.676608  23.197505  33.919028
# 65      25.550858  25.936914  39.704862
# 70      26.409573  28.949126  44.767263
# 75      27.438375  32.241298  49.936954
# 80      28.778410  36.122639  54.522064
# 85      30.194977  40.441102  59.284896
# 90      31.841555  45.136324  62.246928

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='weight',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['weight','got_ast','got_alt','gtp']]
bp_mean_2007=bp_2007.groupby('weight').mean()
bp_mean_2007
# Out:
#           got_ast    got_alt        gtp
# weight
# 45      22.310243  16.953104  21.331717
# 50      22.864619  18.366466  23.845784
# 55      23.646092  20.217365  28.106867
# 60      24.621060  22.800847  33.873052
# 65      25.383929  25.426918  39.756642
# 70      26.346761  28.491428  44.979673
# 75      27.368921  31.835951  49.784969
# 80      28.558144  35.502446  54.337437
# 85      30.102849  39.920466  58.608774
# 90      31.648514  44.616931  62.302564

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='weight',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['weight','got_ast','got_alt','gtp']]
bp_mean_2008=bp_2008.groupby('weight').mean()
bp_mean_2008
# Out:
#           got_ast    got_alt        gtp
# weight
# 45      22.573249  17.125989  21.522284
# 50      22.991876  18.386640  23.812207
# 55      23.872598  20.439447  28.106534
# 60      24.763223  22.869523  33.566486
# 65      25.544031  25.508077  39.353020
# 70      26.450607  28.395644  44.704249
# 75      27.374201  31.617061  49.395453
# 80      28.648952  35.311175  54.148892
# 85      30.091100  39.410542  58.091253
# 90      31.734535  44.391907  62.369551

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='weight',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (5) liver function by height

# %%
#2005
bp_2005=GJ_2009[['height','got_ast','got_alt','gtp']]
bp_mean_2005=bp_2005.groupby('height').mean()
bp_mean_2005
# Out:
#           got_ast    got_alt        gtp
# height
# 145     25.302786  22.680497  25.941683
# 150     24.314358  21.920271  24.999488
# 155     23.710593  21.265510  26.298458
# 160     24.583801  23.173742  34.515727
# 165     26.330028  27.288878  44.570065
# 170     26.689683  29.343057  46.277924
# 175     26.153895  29.392130  44.119782
# 180     25.361228  28.567891  40.129133

# %%
bp_mean_2005=bp_mean_2005.reset_index()
bp_mean_2005.plot(x='height',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['height','got_ast','got_alt','gtp']]
bp_mean_2006=bp_2006.groupby('height').mean()
bp_mean_2006
# Out:
#           got_ast    got_alt        gtp
# height
# 145     25.229501  22.486593  25.732153
# 150     24.230462  21.728311  24.760738
# 155     23.532316  21.005358  25.852651
# 160     24.330333  22.808671  33.640743
# 165     26.080939  26.880351  43.530996
# 170     26.523178  29.105380  46.267874
# 175     25.934854  29.090115  43.978970
# 180     25.150865  28.172526  39.839273

# %%
bp_mean_2006=bp_mean_2006.reset_index()
bp_mean_2006.plot(x='height',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['height','got_ast','got_alt','gtp']]
bp_mean_2007=bp_2007.groupby('height').mean()
bp_mean_2007
# Out:
#           got_ast    got_alt        gtp
# height
# 145     24.948249  21.986969  25.386711
# 150     24.239682  21.376515  24.884403
# 155     23.548087  20.779273  25.904611
# 160     24.330440  22.451376  33.548153
# 165     26.033399  26.462873  43.846358
# 170     26.484804  28.839797  46.592286
# 175     25.946574  28.911324  44.370603
# 180     25.079052  27.858725  40.667712

# %%
bp_mean_2007=bp_mean_2007.reset_index()
bp_mean_2007.plot(x='height',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['height','got_ast','got_alt','gtp']]
bp_mean_2008=bp_2008.groupby('height').mean()
bp_mean_2008
# Out:
#           got_ast    got_alt        gtp
# height
# 145     25.204944  22.065275  25.775614
# 150     24.540421  21.688000  25.159007
# 155     23.832857  21.034737  26.014060
# 160     24.418807  22.472202  32.961265
# 165     26.151383  26.454144  43.364890
# 170     26.549954  28.628110  46.440660
# 175     25.952122  28.744713  44.230135
# 180     25.143514  27.784566  40.292929

# %%
bp_mean_2008=bp_mean_2008.reset_index()
bp_mean_2008.plot(x='height',y=['got_ast','got_alt','gtp'],linestyle='-',marker='o',figsize=((10,5)))

# %% [markdown]
# ### (6) liver function by smoke

# %%
#2005
bp_2005=GJ_2009[['smoke','got_ast','got_alt','gtp']]
bp_mean_2005=bp_2005.groupby('smoke').mean()
bp_mean_2005
# Out:
#          got_ast    got_alt        gtp
# smoke
# 1.0    24.043798  22.587683  27.527280
# 2.0    27.231285  29.136084  45.820355
# 3.0    27.111901  29.390826  52.709266

# %%
bp_mean_2005.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['smoke','got_ast','got_alt','gtp']]
bp_mean_2006=bp_2006.groupby('smoke').mean()
bp_mean_2006
# Out:
#          got_ast    got_alt        gtp
# smoke
# 1.0    23.842973  22.322561  26.939608
# 2.0    27.240091  29.065807  45.804312
# 3.0    26.855430  29.051155  52.999329

# %%
bp_mean_2006.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['smoke','got_ast','got_alt','gtp']]
bp_mean_2007=bp_2007.groupby('smoke').mean()
bp_mean_2007
# Out:
#          got_ast    got_alt        gtp
# smoke
# 1.0    23.829576  21.997870  26.887746
# 2.0    27.143099  28.632316  46.146639
# 3.0    26.795832  28.742567  53.204181

# %%
bp_mean_2007.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['smoke','got_ast','got_alt','gtp']]
bp_mean_2008=bp_2008.groupby('smoke').mean()
bp_mean_2008
# Out:
#          got_ast    got_alt        gtp
# smoke
# 1.0    24.003621  22.141603  26.868078
# 2.0    27.292534  28.604287  45.455599
# 3.0    26.907799  28.628869  53.513243

# %%
bp_mean_2008.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))

# %% [markdown]
# ### (7) liver function by alcohol

# %%
#2005
bp_2005=GJ_2009[['alcohol','got_ast','got_alt','gtp']]
bp_mean_2005=bp_2005.groupby('alcohol').mean()
bp_mean_2005
# Out:
#            got_ast    got_alt        gtp
# alcohol
# 0.0      24.251742  23.696052  26.762679
# 1.0      26.451453  27.079093  47.393738

# %%
bp_mean_2005.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))

# %%
#2006
bp_2006=GJ_2010[['alcohol','got_ast','got_alt','gtp']]
bp_mean_2006=bp_2006.groupby('alcohol').mean()
bp_mean_2006
# Out:
#            got_ast    got_alt        gtp
# alcohol
# 0.0      24.062209  23.407704  26.088802
# 1.0      26.232549  26.782859  47.149746

# %%
bp_mean_2006.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))

# %%
#2007
bp_2007=GJ_2011[['alcohol','got_ast','got_alt','gtp']]
bp_mean_2007=bp_2007.groupby('alcohol').mean()
bp_mean_2007
# Out:
#            got_ast    got_alt        gtp
# alcohol
# 0.0      24.011462  23.090673  26.173988
# 1.0      26.209262  26.443198  47.164694

# %%
bp_mean_2007.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))

# %%
#2008
bp_2008=GJ_2012[['alcohol','got_ast','got_alt','gtp']]
bp_mean_2008=bp_2008.groupby('alcohol').mean()
bp_mean_2008
# Out:
#            got_ast    got_alt        gtp
# alcohol
# 0.0      24.219833  23.192159  26.027493
# 1.0      26.296834  26.399225  47.076704

# %%
bp_mean_2008.plot.bar(y=['got_ast','got_alt','gtp'],figsize=((10,5)))

# %% [markdown]
# # EDA by two columns with 건강검진 file

# %% [markdown]
# ## (A) blood press

# %% [markdown]
# ### (1) blood press by sex & age

# %%
#2005
bp_2005=GJ_2005[['sex','age','b_press_contract','b_press_relax']]
bp_2005_male=bp_2005[bp_2005.sex==1]
bp_2005_female=bp_2005[bp_2005.sex==2]
bp_mean_2005_male=bp_2005_male.groupby('age').mean()
bp_mean_2005_female=bp_2005_female.groupby('age').mean()
bp_mean_2005_male=bp_mean_2005_male.rename(columns={'b_press_contract':'male_contract'})
bp_mean_2005_male=bp_mean_2005_male.rename(columns={'b_press_relax':'male_relax'})
bp_mean_2005_female=bp_mean_2005_female.rename(columns={'b_press_contract':'female_contract'})
bp_mean_2005_female=bp_mean_2005_female.rename(columns={'b_press_relax':'male_relax'})

bp_mean_2005_male
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-286-20adcdf00bff> in <module>()
#       1 #2005
# ----> 2 bp_2005=GJ_2005[['sex','age','b_press_contract','b_press_relax']]
#       3 bp_2005_male=bp_2005[bp_2005.sex==1]
#       4 bp_2005_female=bp_2005[bp_2005.sex==2]
#       5 bp_mean_2005_male=bp_2005_male.groupby('age').mean()
#
# NameError: name 'GJ_2005' is not defined
